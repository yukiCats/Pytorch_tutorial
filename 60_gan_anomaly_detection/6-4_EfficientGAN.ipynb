# %% [markdown]
# # 6.4 Efficient GANの作成
#
# - 本ファイルでは、Efficient GANのネットワークを実装し、学習をします。

# %% [markdown]
# # 6.4 学習目標
#
# 1.	Efficient GANを実装し、手書き数字画像で異常検知が生成できる

# %% [markdown]
# # 事前準備
# 書籍の指示に従い、本章で使用するデータを用意します

# %%
# パッケージのimport
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
torch.cuda.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # Generatorの実装

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Linear(z_dim, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            nn.Linear(1024, 7*7*128),
            nn.BatchNorm1d(7*7*128),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=128, out_channels=64,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True))

        self.last = nn.Sequential(
            nn.ConvTranspose2d(in_channels=64, out_channels=1,
                               kernel_size=4, stride=2, padding=1),
            nn.Tanh())
        # 注意：白黒画像なので出力チャネルは1つだけ

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)

        # 転置畳み込み層に入れるためにテンソルの形を整形
        out = out.view(z.shape[0], 128, 7, 7)
        out = self.layer3(out)
        out = self.last(out)

        return out

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20)
G.train()

# 入力する乱数
# バッチノーマライゼーションがあるのでミニバッチ数は2以上
input_z = torch.randn(2, 20)

# 偽画像を出力
fake_images = G(input_z)  # torch.Size([2, 1, 28, 28])
img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()
# Out:
# findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # Discriminatorの実装

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20):
        super(Discriminator, self).__init__()

        # 画像側の入力処理
        self.x_layer1 = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.x_layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=4,
                      stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True))

        # 乱数側の入力処理
        self.z_layer1 = nn.Linear(z_dim, 512)

        # 最後の判定
        self.last1 = nn.Sequential(
            nn.Linear(3648, 1024),
            nn.LeakyReLU(0.1, inplace=True))

        self.last2 = nn.Linear(1024, 1)

    def forward(self, x, z):

        # 画像側の入力処理
        x_out = self.x_layer1(x)
        x_out = self.x_layer2(x_out)

        # 乱数側の入力処理
        z = z.view(z.shape[0], -1)
        z_out = self.z_layer1(z)

        # x_outとz_outを結合し、全結合層で判定
        x_out = x_out.view(-1, 64 * 7 * 7)
        out = torch.cat([x_out, z_out], dim=1)
        out = self.last1(out)

        feature = out  # 最後にチャネルを1つに集約する手前の情報
        feature = feature.view(feature.size()[0], -1)  # 2次元に変換

        out = self.last2(out)

        return out, feature

# %%
# 動作確認
D = Discriminator(z_dim=20)

# 偽画像を生成
input_z = torch.randn(2, 20)
fake_images = G(input_z)

# 偽画像をDに入力
d_out, _ = D(fake_images, input_z)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[0.4322],
#         [0.4629]], grad_fn=<SigmoidBackward>)

# %% [markdown]
# # Encoderの実装
#
# 画像をzに変換する

# %%
class Encoder(nn.Module):

    def __init__(self, z_dim=20):
        super(Encoder, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3,
                      stride=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3,
                      stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3,
                      stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1, inplace=True))

        # ここまでで画像のサイズは7×7になっている
        self.last = nn.Linear(128 * 7 * 7, z_dim)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)

        # FCに入れるためにテンソルの形を整形
        out = out.view(-1, 128 * 7 * 7)
        out = self.last(out)

        return out

# %%
# 動作確認
E = Encoder(z_dim=20)

# 入力する画像データ
x = fake_images  # fake_imagesは上のGで作成したもの

# 画像からzをEncode
z = E(x)

print(z.shape)
print(z)
# Out:
# torch.Size([2, 20])
# tensor([[-0.0669, -0.2844, -0.3601,  0.1404, -0.2922, -0.4834, -0.0025,  0.0258,
#          -0.1298, -0.2613, -0.4292, -0.2584, -0.6141, -0.1440,  0.1142,  0.2175,
#           0.0730,  0.0323, -0.7176, -0.7410],
#         [ 0.4822,  0.3682, -0.0647, -0.0773,  0.0989,  0.3012,  0.8054,  0.4399,
#           1.0848, -0.2809,  0.0619, -0.3179, -0.2963, -0.1192,  0.6562, -0.1707,
#           0.1287, -0.6156,  0.3127, -0.4819]], grad_fn=<AddmmBackward>)

# %% [markdown]
# # DataLoaderの作成

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78_28size/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78_28size/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 28, 28])

# %% [markdown]
# # 学習させる

# %%
# モデルを学習させる関数を作成


def train_model(G, D, E, dataloader, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    lr_ge = 0.0001
    lr_d = 0.0001/4
    beta1, beta2 = 0.5, 0.999
    g_optimizer = torch.optim.Adam(G.parameters(), lr_ge, [beta1, beta2])
    e_optimizer = torch.optim.Adam(E.parameters(), lr_ge, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), lr_d, [beta1, beta2])

    # 誤差関数を定義
    # BCEWithLogitsLossは入力にシグモイド（logit）をかけてから、
    # バイナリークロスエントロピーを計算
    criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    E.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    E.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イテレーションカウンタをセット
    iteration = 1
    logs = []

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_e_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('（train）')

        # データローダーからminibatchずつ取り出すループ
        for imges in dataloader:

            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            if imges.size()[0] == 1:
                continue

            # ミニバッチサイズの1もしくは0のラベル役のテンソルを作成
            # 正解ラベルと偽ラベルを作成
            # epochの最後のイテレーションはミニバッチの数が少なくなる
            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)

            # GPUが使えるならGPUにデータを送る
            imges = imges.to(device)

            # --------------------
            # 1. Discriminatorの学習
            # --------------------
            # 真の画像を判定　
            z_out_real = E(imges)
            d_out_real, _ = D(imges, z_out_real)

            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images, input_z)

            # 誤差を計算
            label_real = label_real.type_as(d_out_real.view(-1))
            label_fake = label_fake.type_as(d_out_fake.view(-1))
            d_loss_real = criterion(d_out_real.view(-1), label_real)
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            d_loss = d_loss_real + d_loss_fake

            # バックプロパゲーション
            d_optimizer.zero_grad()
            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generatorの学習
            # --------------------
            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images, input_z)

            # 誤差を計算
            g_loss = criterion(d_out_fake.view(-1), label_real)

            # バックプロパゲーション
            g_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. Encoderの学習
            # --------------------
            # 真の画像のzを推定
            z_out_real = E(imges)
            d_out_real, _ = D(imges, z_out_real)

            # 誤差を計算
            e_loss = criterion(d_out_real.view(-1), label_fake)

            # バックプロパゲーション
            e_optimizer.zero_grad()
            e_loss.backward()
            e_optimizer.step()

            # --------------------
            # 4. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            epoch_e_loss += e_loss.item()
            iteration += 1

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f} ||Epoch_E_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size, epoch_e_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    print("総イテレーション回数:", iteration)

    return G, D, E

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # conv2dとConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('Linear') != -1:
        # 全結合層Linearの初期化
        m.bias.data.fill_(0)


# 初期化の実施
G.apply(weights_init)
E.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
# 学習・検証を実行する
# 15分ほどかかる
num_epochs = 1500
G_update, D_update, E_update = train_model(
    G, D, E, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/1500
# -------------
# （train）
# -------------
# epoch 0 || Epoch_D_Loss:0.1484 ||Epoch_G_Loss:0.0788 ||Epoch_E_Loss:0.0767
# timer:  1.3931 sec.
# -------------
# Epoch 1/1500
# -------------
# （train）
# -------------
# epoch 1 || Epoch_D_Loss:0.1448 ||Epoch_G_Loss:0.0812 ||Epoch_E_Loss:0.0784
# timer:  0.2953 sec.
# -------------
# Epoch 2/1500
# -------------
# （train）
# -------------
# epoch 2 || Epoch_D_Loss:0.1407 ||Epoch_G_Loss:0.0830 ||Epoch_E_Loss:0.0809
# timer:  0.2667 sec.
# -------------
# Epoch 3/1500
# -------------
# （train）
# -------------
# epoch 3 || Epoch_D_Loss:0.1361 ||Epoch_G_Loss:0.0849 ||Epoch_E_Loss:0.0842
# timer:  0.2603 sec.
# -------------
# Epoch 4/1500
# -------------
# （train）
# -------------
# epoch 4 || Epoch_D_Loss:0.1333 ||Epoch_G_Loss:0.0866 ||Epoch_E_Loss:0.0863
# timer:  0.2635 sec.
# -------------
# Epoch 5/1500
# -------------
# （train）
# -------------
# epoch 5 || Epoch_D_Loss:0.1305 ||Epoch_G_Loss:0.0883 ||Epoch_E_Loss:0.0882
# timer:  0.2633 sec.
# -------------
# Epoch 6/1500
# -------------
# （train）
# -------------
# epoch 6 || Epoch_D_Loss:0.1264 ||Epoch_G_Loss:0.0893 ||Epoch_E_Loss:0.0926
# timer:  0.2748 sec.
# -------------
# Epoch 7/1500
# -------------
# （train）
# -------------
# epoch 7 || Epoch_D_Loss:0.1211 ||Epoch_G_Loss:0.0903 ||Epoch_E_Loss:0.0979
# timer:  0.2654 sec.
# -------------
# Epoch 8/1500
# -------------
# （train）
# -------------
# epoch 8 || Epoch_D_Loss:0.1191 ||Epoch_G_Loss:0.0919 ||Epoch_E_Loss:0.0993
# timer:  0.2638 sec.
# -------------
# Epoch 9/1500
# -------------
# （train）
# -------------
# epoch 9 || Epoch_D_Loss:0.1195 ||Epoch_G_Loss:0.0938 ||Epoch_E_Loss:0.0988
# timer:  0.2698 sec.
# -------------
# Epoch 10/1500
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.1156 ||Epoch_G_Loss:0.0956 ||Epoch_E_Loss:0.1043
# timer:  0.2701 sec.
# -------------
# Epoch 11/1500
# -------------
# （train）
# -------------
# epoch 11 || Epoch_D_Loss:0.1090 ||Epoch_G_Loss:0.0977 ||Epoch_E_Loss:0.1121
# timer:  0.2708 sec.
# -------------
# Epoch 12/1500
# -------------
# （train）
# -------------
# epoch 12 || Epoch_D_Loss:0.1078 ||Epoch_G_Loss:0.0983 ||Epoch_E_Loss:0.1122
# timer:  0.2718 sec.
# -------------
# Epoch 13/1500
# -------------
# （train）
# -------------
# epoch 13 || Epoch_D_Loss:0.1050 ||Epoch_G_Loss:0.1014 ||Epoch_E_Loss:0.1146
# timer:  0.2715 sec.
# -------------
# Epoch 14/1500
# -------------
# （train）
# -------------
# epoch 14 || Epoch_D_Loss:0.0981 ||Epoch_G_Loss:0.1051 ||Epoch_E_Loss:0.1238
# timer:  0.2709 sec.
# -------------
# Epoch 15/1500
# -------------
# （train）
# -------------
# epoch 15 || Epoch_D_Loss:0.0920 ||Epoch_G_Loss:0.1081 ||Epoch_E_Loss:0.1330
# timer:  0.2692 sec.
# -------------
# Epoch 16/1500
# -------------
# （train）
# -------------
# epoch 16 || Epoch_D_Loss:0.0891 ||Epoch_G_Loss:0.1126 ||Epoch_E_Loss:0.1346
# timer:  0.2657 sec.
# -------------
# Epoch 17/1500
# -------------
# （train）
# -------------
# epoch 17 || Epoch_D_Loss:0.0881 ||Epoch_G_Loss:0.1167 ||Epoch_E_Loss:0.1334
# timer:  0.2624 sec.
# -------------
# Epoch 18/1500
# -------------
# （train）
# -------------
# epoch 18 || Epoch_D_Loss:0.0837 ||Epoch_G_Loss:0.1237 ||Epoch_E_Loss:0.1400
# timer:  0.2613 sec.
# -------------
# Epoch 19/1500
# -------------
# （train）
# -------------
# epoch 19 || Epoch_D_Loss:0.0734 ||Epoch_G_Loss:0.1289 ||Epoch_E_Loss:0.1563
# timer:  0.2632 sec.
# -------------
# Epoch 20/1500
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.0671 ||Epoch_G_Loss:0.1381 ||Epoch_E_Loss:0.1647
# timer:  0.2584 sec.
# -------------
# Epoch 21/1500
# -------------
# （train）
# -------------
# epoch 21 || Epoch_D_Loss:0.0632 ||Epoch_G_Loss:0.1469 ||Epoch_E_Loss:0.1692
# timer:  0.2629 sec.
# -------------
# Epoch 22/1500
# -------------
# （train）
# -------------
# epoch 22 || Epoch_D_Loss:0.0588 ||Epoch_G_Loss:0.1554 ||Epoch_E_Loss:0.1774
# timer:  0.2679 sec.
# -------------
# Epoch 23/1500
# -------------
# （train）
# -------------
# epoch 23 || Epoch_D_Loss:0.0534 ||Epoch_G_Loss:0.1663 ||Epoch_E_Loss:0.1869
# timer:  0.2769 sec.
# -------------
# Epoch 24/1500
# -------------
# （train）
# -------------
# epoch 24 || Epoch_D_Loss:0.0486 ||Epoch_G_Loss:0.1735 ||Epoch_E_Loss:0.1959
# timer:  0.2730 sec.
# -------------
# Epoch 25/1500
# -------------
# （train）
# -------------
# epoch 25 || Epoch_D_Loss:0.0443 ||Epoch_G_Loss:0.1832 ||Epoch_E_Loss:0.2066
# timer:  0.2776 sec.
# -------------
# Epoch 26/1500
# -------------
# （train）
# -------------
# epoch 26 || Epoch_D_Loss:0.0397 ||Epoch_G_Loss:0.1940 ||Epoch_E_Loss:0.2195
# timer:  0.2750 sec.
# -------------
# Epoch 27/1500
# -------------
# （train）
# -------------
# epoch 27 || Epoch_D_Loss:0.0357 ||Epoch_G_Loss:0.2043 ||Epoch_E_Loss:0.2274
# timer:  0.2787 sec.
# -------------
# Epoch 28/1500
# -------------
# （train）
# -------------
# epoch 28 || Epoch_D_Loss:0.0336 ||Epoch_G_Loss:0.2124 ||Epoch_E_Loss:0.2322
# timer:  0.2724 sec.
# -------------
# Epoch 29/1500
# -------------
# （train）
# -------------
# epoch 29 || Epoch_D_Loss:0.0309 ||Epoch_G_Loss:0.2219 ||Epoch_E_Loss:0.2423
# timer:  0.2762 sec.
# -------------
# Epoch 30/1500
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.0277 ||Epoch_G_Loss:0.2340 ||Epoch_E_Loss:0.2576
# timer:  0.2670 sec.
# -------------
# Epoch 31/1500
# -------------
# （train）
# -------------
# epoch 31 || Epoch_D_Loss:0.0257 ||Epoch_G_Loss:0.2395 ||Epoch_E_Loss:0.2672
# timer:  0.2700 sec.
# -------------
# Epoch 32/1500
# -------------
# （train）
# -------------
# epoch 32 || Epoch_D_Loss:0.0257 ||Epoch_G_Loss:0.2485 ||Epoch_E_Loss:0.2643
# timer:  0.2653 sec.
# -------------
# Epoch 33/1500
# -------------
# （train）
# -------------
# epoch 33 || Epoch_D_Loss:0.0212 ||Epoch_G_Loss:0.2595 ||Epoch_E_Loss:0.2979
# timer:  0.2701 sec.
# -------------
# Epoch 34/1500
# -------------
# （train）
# -------------
# epoch 34 || Epoch_D_Loss:0.0183 ||Epoch_G_Loss:0.2718 ||Epoch_E_Loss:0.3167
# timer:  0.2648 sec.
# -------------
# Epoch 35/1500
# -------------
# （train）
# -------------
# epoch 35 || Epoch_D_Loss:0.0185 ||Epoch_G_Loss:0.2779 ||Epoch_E_Loss:0.3132
# timer:  0.2692 sec.
# -------------
# Epoch 36/1500
# -------------
# （train）
# -------------
# epoch 36 || Epoch_D_Loss:0.0195 ||Epoch_G_Loss:0.2814 ||Epoch_E_Loss:0.2995
# timer:  0.2660 sec.
# -------------
# Epoch 37/1500
# -------------
# （train）
# -------------
# epoch 37 || Epoch_D_Loss:0.0208 ||Epoch_G_Loss:0.2864 ||Epoch_E_Loss:0.2858
# timer:  0.2773 sec.
# -------------
# Epoch 38/1500
# -------------
# （train）
# -------------
# epoch 38 || Epoch_D_Loss:0.0197 ||Epoch_G_Loss:0.2938 ||Epoch_E_Loss:0.2941
# timer:  0.2727 sec.
# -------------
# Epoch 39/1500
# -------------
# （train）
# -------------
# epoch 39 || Epoch_D_Loss:0.0161 ||Epoch_G_Loss:0.3050 ||Epoch_E_Loss:0.3261
# timer:  0.2684 sec.
# -------------
# Epoch 40/1500
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.0136 ||Epoch_G_Loss:0.3138 ||Epoch_E_Loss:0.3444
# timer:  0.2673 sec.
# -------------
# Epoch 41/1500
# -------------
# （train）
# -------------
# epoch 41 || Epoch_D_Loss:0.0141 ||Epoch_G_Loss:0.3207 ||Epoch_E_Loss:0.3365
# timer:  0.2688 sec.
# -------------
# Epoch 42/1500
# -------------
# （train）
# -------------
# epoch 42 || Epoch_D_Loss:0.0159 ||Epoch_G_Loss:0.3196 ||Epoch_E_Loss:0.3150
# timer:  0.2699 sec.
# -------------
# Epoch 43/1500
# -------------
# （train）
# -------------
# epoch 43 || Epoch_D_Loss:0.0164 ||Epoch_G_Loss:0.3229 ||Epoch_E_Loss:0.3094
# timer:  0.2714 sec.
# -------------
# Epoch 44/1500
# -------------
# （train）
# -------------
# epoch 44 || Epoch_D_Loss:0.0145 ||Epoch_G_Loss:0.3359 ||Epoch_E_Loss:0.3196
# timer:  0.2680 sec.
# -------------
# Epoch 45/1500
# -------------
# （train）
# -------------
# epoch 45 || Epoch_D_Loss:0.0141 ||Epoch_G_Loss:0.3352 ||Epoch_E_Loss:0.3240
# timer:  0.2678 sec.
# -------------
# Epoch 46/1500
# -------------
# （train）
# -------------
# epoch 46 || Epoch_D_Loss:0.0142 ||Epoch_G_Loss:0.3368 ||Epoch_E_Loss:0.3203
# timer:  0.2705 sec.
# -------------
# Epoch 47/1500
# -------------
# （train）
# -------------
# epoch 47 || Epoch_D_Loss:0.0136 ||Epoch_G_Loss:0.3484 ||Epoch_E_Loss:0.3269
# timer:  0.2728 sec.
# -------------
# Epoch 48/1500
# -------------
# （train）
# -------------
# epoch 48 || Epoch_D_Loss:0.0111 ||Epoch_G_Loss:0.3626 ||Epoch_E_Loss:0.3592
# timer:  0.2699 sec.
# -------------
# Epoch 49/1500
# -------------
# （train）
# -------------
# epoch 49 || Epoch_D_Loss:0.0088 ||Epoch_G_Loss:0.3720 ||Epoch_E_Loss:0.3940
# timer:  0.2704 sec.
# -------------
# Epoch 50/1500
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.0081 ||Epoch_G_Loss:0.3808 ||Epoch_E_Loss:0.4070
# timer:  0.2626 sec.
# -------------
# Epoch 51/1500
# -------------
# （train）
# -------------
# epoch 51 || Epoch_D_Loss:0.0087 ||Epoch_G_Loss:0.3769 ||Epoch_E_Loss:0.3895
# timer:  0.2648 sec.
# -------------
# Epoch 52/1500
# -------------
# （train）
# -------------
# epoch 52 || Epoch_D_Loss:0.0093 ||Epoch_G_Loss:0.3843 ||Epoch_E_Loss:0.3840
# timer:  0.2663 sec.
# -------------
# Epoch 53/1500
# -------------
# （train）
# -------------
# epoch 53 || Epoch_D_Loss:0.0077 ||Epoch_G_Loss:0.3896 ||Epoch_E_Loss:0.4024
# timer:  0.2626 sec.
# -------------
# Epoch 54/1500
# -------------
# （train）
# -------------
# epoch 54 || Epoch_D_Loss:0.0080 ||Epoch_G_Loss:0.3919 ||Epoch_E_Loss:0.3963
# timer:  0.2683 sec.
# -------------
# Epoch 55/1500
# -------------
# （train）
# -------------
# epoch 55 || Epoch_D_Loss:0.0087 ||Epoch_G_Loss:0.3968 ||Epoch_E_Loss:0.3860
# timer:  0.2662 sec.
# -------------
# Epoch 56/1500
# -------------
# （train）
# -------------
# epoch 56 || Epoch_D_Loss:0.0083 ||Epoch_G_Loss:0.3979 ||Epoch_E_Loss:0.3886
# timer:  0.2741 sec.
# -------------
# Epoch 57/1500
# -------------
# （train）
# -------------
# epoch 57 || Epoch_D_Loss:0.0076 ||Epoch_G_Loss:0.4046 ||Epoch_E_Loss:0.4001
# timer:  0.2700 sec.
# -------------
# Epoch 58/1500
# -------------
# （train）
# -------------
# epoch 58 || Epoch_D_Loss:0.0058 ||Epoch_G_Loss:0.4139 ||Epoch_E_Loss:0.4431
# timer:  0.2623 sec.
# -------------
# Epoch 59/1500
# -------------
# （train）
# -------------
# epoch 59 || Epoch_D_Loss:0.0051 ||Epoch_G_Loss:0.4242 ||Epoch_E_Loss:0.4614
# timer:  0.2687 sec.
# -------------
# Epoch 60/1500
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.0056 ||Epoch_G_Loss:0.4169 ||Epoch_E_Loss:0.4432
# timer:  0.2674 sec.
# -------------
# Epoch 61/1500
# -------------
# （train）
# -------------
# epoch 61 || Epoch_D_Loss:0.0060 ||Epoch_G_Loss:0.4193 ||Epoch_E_Loss:0.4365
# timer:  0.2743 sec.
# -------------
# Epoch 62/1500
# -------------
# （train）
# -------------
# epoch 62 || Epoch_D_Loss:0.0061 ||Epoch_G_Loss:0.4227 ||Epoch_E_Loss:0.4381
# timer:  0.2739 sec.
# -------------
# Epoch 63/1500
# -------------
# （train）
# -------------
# epoch 63 || Epoch_D_Loss:0.0060 ||Epoch_G_Loss:0.4332 ||Epoch_E_Loss:0.4419
# timer:  0.2615 sec.
# -------------
# Epoch 64/1500
# -------------
# （train）
# -------------
# epoch 64 || Epoch_D_Loss:0.0053 ||Epoch_G_Loss:0.4350 ||Epoch_E_Loss:0.4484
# timer:  0.2604 sec.
# -------------
# Epoch 65/1500
# -------------
# （train）
# -------------
# epoch 65 || Epoch_D_Loss:0.0057 ||Epoch_G_Loss:0.4473 ||Epoch_E_Loss:0.4376
# timer:  0.2602 sec.
# -------------
# Epoch 66/1500
# -------------
# （train）
# -------------
# epoch 66 || Epoch_D_Loss:0.0058 ||Epoch_G_Loss:0.4507 ||Epoch_E_Loss:0.4330
# timer:  0.2668 sec.
# -------------
# Epoch 67/1500
# -------------
# （train）
# -------------
# epoch 67 || Epoch_D_Loss:0.0054 ||Epoch_G_Loss:0.4505 ||Epoch_E_Loss:0.4440
# timer:  0.2653 sec.
# -------------
# Epoch 68/1500
# -------------
# （train）
# -------------
# epoch 68 || Epoch_D_Loss:0.0052 ||Epoch_G_Loss:0.4575 ||Epoch_E_Loss:0.4502
# timer:  0.2621 sec.
# -------------
# Epoch 69/1500
# -------------
# （train）
# -------------
# epoch 69 || Epoch_D_Loss:0.0048 ||Epoch_G_Loss:0.4596 ||Epoch_E_Loss:0.4551
# timer:  0.2648 sec.
# -------------
# Epoch 70/1500
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.0053 ||Epoch_G_Loss:0.4617 ||Epoch_E_Loss:0.4428
# timer:  0.2680 sec.
# -------------
# Epoch 71/1500
# -------------
# （train）
# -------------
# epoch 71 || Epoch_D_Loss:0.0061 ||Epoch_G_Loss:0.4503 ||Epoch_E_Loss:0.4320
# timer:  0.2714 sec.
# -------------
# Epoch 72/1500
# -------------
# （train）
# -------------
# epoch 72 || Epoch_D_Loss:0.0067 ||Epoch_G_Loss:0.4520 ||Epoch_E_Loss:0.4155
# timer:  0.2646 sec.
# -------------
# Epoch 73/1500
# -------------
# （train）
# -------------
# epoch 73 || Epoch_D_Loss:0.0069 ||Epoch_G_Loss:0.4521 ||Epoch_E_Loss:0.4118
# timer:  0.2613 sec.
# -------------
# Epoch 74/1500
# -------------
# （train）
# -------------
# epoch 74 || Epoch_D_Loss:0.0065 ||Epoch_G_Loss:0.4489 ||Epoch_E_Loss:0.4184
# timer:  0.2615 sec.
# -------------
# Epoch 75/1500
# -------------
# （train）
# -------------
# epoch 75 || Epoch_D_Loss:0.0066 ||Epoch_G_Loss:0.4541 ||Epoch_E_Loss:0.4193
# timer:  0.2621 sec.
# -------------
# Epoch 76/1500
# -------------
# （train）
# -------------
# epoch 76 || Epoch_D_Loss:0.0069 ||Epoch_G_Loss:0.4430 ||Epoch_E_Loss:0.4148
# timer:  0.2739 sec.
# -------------
# Epoch 77/1500
# -------------
# （train）
# -------------
# epoch 77 || Epoch_D_Loss:0.0081 ||Epoch_G_Loss:0.4210 ||Epoch_E_Loss:0.4013
# timer:  0.2643 sec.
# -------------
# Epoch 78/1500
# -------------
# （train）
# -------------
# epoch 78 || Epoch_D_Loss:0.0079 ||Epoch_G_Loss:0.4313 ||Epoch_E_Loss:0.4079
# timer:  0.2679 sec.
# -------------
# Epoch 79/1500
# -------------
# （train）
# -------------
# epoch 79 || Epoch_D_Loss:0.0064 ||Epoch_G_Loss:0.4413 ||Epoch_E_Loss:0.4272
# timer:  0.2663 sec.
# -------------
# Epoch 80/1500
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.0065 ||Epoch_G_Loss:0.4368 ||Epoch_E_Loss:0.4154
# timer:  0.2694 sec.
# -------------
# Epoch 81/1500
# -------------
# （train）
# -------------
# epoch 81 || Epoch_D_Loss:0.0058 ||Epoch_G_Loss:0.4325 ||Epoch_E_Loss:0.4305
# timer:  0.2654 sec.
# -------------
# Epoch 82/1500
# -------------
# （train）
# -------------
# epoch 82 || Epoch_D_Loss:0.0047 ||Epoch_G_Loss:0.4615 ||Epoch_E_Loss:0.4525
# timer:  0.2648 sec.
# -------------
# Epoch 83/1500
# -------------
# （train）
# -------------
# epoch 83 || Epoch_D_Loss:0.0049 ||Epoch_G_Loss:0.4371 ||Epoch_E_Loss:0.4537
# timer:  0.2623 sec.
# -------------
# Epoch 84/1500
# -------------
# （train）
# -------------
# epoch 84 || Epoch_D_Loss:0.0051 ||Epoch_G_Loss:0.4419 ||Epoch_E_Loss:0.4405
# timer:  0.2580 sec.
# -------------
# Epoch 85/1500
# -------------
# （train）
# -------------
# epoch 85 || Epoch_D_Loss:0.0052 ||Epoch_G_Loss:0.4380 ||Epoch_E_Loss:0.4575
# timer:  0.2618 sec.
# -------------
# Epoch 86/1500
# -------------
# （train）
# -------------
# epoch 86 || Epoch_D_Loss:0.0062 ||Epoch_G_Loss:0.4268 ||Epoch_E_Loss:0.4389
# timer:  0.2749 sec.
# -------------
# Epoch 87/1500
# -------------
# （train）
# -------------
# epoch 87 || Epoch_D_Loss:0.0066 ||Epoch_G_Loss:0.4531 ||Epoch_E_Loss:0.4310
# timer:  0.2727 sec.
# -------------
# Epoch 88/1500
# -------------
# （train）
# -------------
# epoch 88 || Epoch_D_Loss:0.0058 ||Epoch_G_Loss:0.4334 ||Epoch_E_Loss:0.4514
# timer:  0.2652 sec.
# -------------
# Epoch 89/1500
# -------------
# （train）
# -------------
# epoch 89 || Epoch_D_Loss:0.0051 ||Epoch_G_Loss:0.4658 ||Epoch_E_Loss:0.4601
# timer:  0.2637 sec.
# -------------
# Epoch 90/1500
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.0055 ||Epoch_G_Loss:0.4454 ||Epoch_E_Loss:0.4586
# timer:  0.2613 sec.
# -------------
# Epoch 91/1500
# -------------
# （train）
# -------------
# epoch 91 || Epoch_D_Loss:0.0136 ||Epoch_G_Loss:0.4398 ||Epoch_E_Loss:0.4525
# timer:  0.2623 sec.
# -------------
# Epoch 92/1500
# -------------
# （train）
# -------------
# epoch 92 || Epoch_D_Loss:0.0076 ||Epoch_G_Loss:0.4472 ||Epoch_E_Loss:0.4330
# timer:  0.2624 sec.
# -------------
# Epoch 93/1500
# -------------
# （train）
# -------------
# epoch 93 || Epoch_D_Loss:0.0073 ||Epoch_G_Loss:0.4373 ||Epoch_E_Loss:0.4299
# timer:  0.2650 sec.
# -------------
# Epoch 94/1500
# -------------
# （train）
# -------------
# epoch 94 || Epoch_D_Loss:0.0103 ||Epoch_G_Loss:0.4151 ||Epoch_E_Loss:0.4037
# timer:  0.2673 sec.
# -------------
# Epoch 95/1500
# -------------
# （train）
# -------------
# epoch 95 || Epoch_D_Loss:0.0145 ||Epoch_G_Loss:0.3983 ||Epoch_E_Loss:0.3663
# timer:  0.2613 sec.
# -------------
# Epoch 96/1500
# -------------
# （train）
# -------------
# epoch 96 || Epoch_D_Loss:0.0213 ||Epoch_G_Loss:0.4123 ||Epoch_E_Loss:0.4272
# timer:  0.2706 sec.
# -------------
# Epoch 97/1500
# -------------
# （train）
# -------------
# epoch 97 || Epoch_D_Loss:0.0137 ||Epoch_G_Loss:0.3867 ||Epoch_E_Loss:0.3866
# timer:  0.2799 sec.
# -------------
# Epoch 98/1500
# -------------
# （train）
# -------------
# epoch 98 || Epoch_D_Loss:0.0143 ||Epoch_G_Loss:0.3709 ||Epoch_E_Loss:0.3857
# timer:  0.2643 sec.
# -------------
# Epoch 99/1500
# -------------
# （train）
# -------------
# epoch 99 || Epoch_D_Loss:0.0157 ||Epoch_G_Loss:0.3980 ||Epoch_E_Loss:0.3637
# timer:  0.2669 sec.
# -------------
# Epoch 100/1500
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.0179 ||Epoch_G_Loss:0.3679 ||Epoch_E_Loss:0.3900
# timer:  0.2664 sec.
# -------------
# Epoch 101/1500
# -------------
# （train）
# -------------
# epoch 101 || Epoch_D_Loss:0.0267 ||Epoch_G_Loss:0.3276 ||Epoch_E_Loss:0.3738
# timer:  0.2590 sec.
# -------------
# Epoch 102/1500
# -------------
# （train）
# -------------
# epoch 102 || Epoch_D_Loss:0.0198 ||Epoch_G_Loss:0.3516 ||Epoch_E_Loss:0.3684
# timer:  0.2597 sec.
# -------------
# Epoch 103/1500
# -------------
# （train）
# -------------
# epoch 103 || Epoch_D_Loss:0.0299 ||Epoch_G_Loss:0.3666 ||Epoch_E_Loss:0.3943
# timer:  0.2643 sec.
# -------------
# Epoch 104/1500
# -------------
# （train）
# -------------
# epoch 104 || Epoch_D_Loss:0.0173 ||Epoch_G_Loss:0.3660 ||Epoch_E_Loss:0.3883
# timer:  0.2693 sec.
# -------------
# Epoch 105/1500
# -------------
# （train）
# -------------
# epoch 105 || Epoch_D_Loss:0.0260 ||Epoch_G_Loss:0.3448 ||Epoch_E_Loss:0.3512
# timer:  0.2684 sec.
# -------------
# Epoch 106/1500
# -------------
# （train）
# -------------
# epoch 106 || Epoch_D_Loss:0.0309 ||Epoch_G_Loss:0.3090 ||Epoch_E_Loss:0.3406
# timer:  0.2679 sec.
# -------------
# Epoch 107/1500
# -------------
# （train）
# -------------
# epoch 107 || Epoch_D_Loss:0.0284 ||Epoch_G_Loss:0.3014 ||Epoch_E_Loss:0.3417
# timer:  0.2596 sec.
# -------------
# Epoch 108/1500
# -------------
# （train）
# -------------
# epoch 108 || Epoch_D_Loss:0.0270 ||Epoch_G_Loss:0.3200 ||Epoch_E_Loss:0.3532
# timer:  0.2714 sec.
# -------------
# Epoch 109/1500
# -------------
# （train）
# -------------
# epoch 109 || Epoch_D_Loss:0.0303 ||Epoch_G_Loss:0.3136 ||Epoch_E_Loss:0.3471
# timer:  0.2645 sec.
# -------------
# Epoch 110/1500
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.0363 ||Epoch_G_Loss:0.2950 ||Epoch_E_Loss:0.3180
# timer:  0.2615 sec.
# -------------
# Epoch 111/1500
# -------------
# （train）
# -------------
# epoch 111 || Epoch_D_Loss:0.0458 ||Epoch_G_Loss:0.2924 ||Epoch_E_Loss:0.3485
# timer:  0.2605 sec.
# -------------
# Epoch 112/1500
# -------------
# （train）
# -------------
# epoch 112 || Epoch_D_Loss:0.0310 ||Epoch_G_Loss:0.2897 ||Epoch_E_Loss:0.3578
# timer:  0.2643 sec.
# -------------
# Epoch 113/1500
# -------------
# （train）
# -------------
# epoch 113 || Epoch_D_Loss:0.0372 ||Epoch_G_Loss:0.2996 ||Epoch_E_Loss:0.3342
# timer:  0.2623 sec.
# -------------
# Epoch 114/1500
# -------------
# （train）
# -------------
# epoch 114 || Epoch_D_Loss:0.0428 ||Epoch_G_Loss:0.2955 ||Epoch_E_Loss:0.3328
# timer:  0.2653 sec.
# -------------
# Epoch 115/1500
# -------------
# （train）
# -------------
# epoch 115 || Epoch_D_Loss:0.0742 ||Epoch_G_Loss:0.2357 ||Epoch_E_Loss:0.3141
# timer:  0.2684 sec.
# -------------
# Epoch 116/1500
# -------------
# （train）
# -------------
# epoch 116 || Epoch_D_Loss:0.0581 ||Epoch_G_Loss:0.2641 ||Epoch_E_Loss:0.2884
# timer:  0.2619 sec.
# -------------
# Epoch 117/1500
# -------------
# （train）
# -------------
# epoch 117 || Epoch_D_Loss:0.0764 ||Epoch_G_Loss:0.2060 ||Epoch_E_Loss:0.2532
# timer:  0.2660 sec.
# -------------
# Epoch 118/1500
# -------------
# （train）
# -------------
# epoch 118 || Epoch_D_Loss:0.0457 ||Epoch_G_Loss:0.2499 ||Epoch_E_Loss:0.2877
# timer:  0.2611 sec.
# -------------
# Epoch 119/1500
# -------------
# （train）
# -------------
# epoch 119 || Epoch_D_Loss:0.0353 ||Epoch_G_Loss:0.2575 ||Epoch_E_Loss:0.2925
# timer:  0.2633 sec.
# -------------
# Epoch 120/1500
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.0462 ||Epoch_G_Loss:0.2268 ||Epoch_E_Loss:0.2604
# timer:  0.2674 sec.
# -------------
# Epoch 121/1500
# -------------
# （train）
# -------------
# epoch 121 || Epoch_D_Loss:0.0573 ||Epoch_G_Loss:0.2143 ||Epoch_E_Loss:0.2540
# timer:  0.2679 sec.
# -------------
# Epoch 122/1500
# -------------
# （train）
# -------------
# epoch 122 || Epoch_D_Loss:0.0335 ||Epoch_G_Loss:0.2856 ||Epoch_E_Loss:0.2939
# timer:  0.2658 sec.
# -------------
# Epoch 123/1500
# -------------
# （train）
# -------------
# epoch 123 || Epoch_D_Loss:0.0264 ||Epoch_G_Loss:0.3202 ||Epoch_E_Loss:0.3237
# timer:  0.2657 sec.
# -------------
# Epoch 124/1500
# -------------
# （train）
# -------------
# epoch 124 || Epoch_D_Loss:0.0308 ||Epoch_G_Loss:0.3180 ||Epoch_E_Loss:0.3027
# timer:  0.2658 sec.
# -------------
# Epoch 125/1500
# -------------
# （train）
# -------------
# epoch 125 || Epoch_D_Loss:0.0358 ||Epoch_G_Loss:0.2848 ||Epoch_E_Loss:0.2927
# timer:  0.2655 sec.
# -------------
# Epoch 126/1500
# -------------
# （train）
# -------------
# epoch 126 || Epoch_D_Loss:0.0473 ||Epoch_G_Loss:0.2515 ||Epoch_E_Loss:0.2658
# timer:  0.2662 sec.
# -------------
# Epoch 127/1500
# -------------
# （train）
# -------------
# epoch 127 || Epoch_D_Loss:0.0588 ||Epoch_G_Loss:0.2139 ||Epoch_E_Loss:0.2602
# timer:  0.2713 sec.
# -------------
# Epoch 128/1500
# -------------
# （train）
# -------------
# epoch 128 || Epoch_D_Loss:0.0532 ||Epoch_G_Loss:0.2236 ||Epoch_E_Loss:0.2813
# timer:  0.2692 sec.
# -------------
# Epoch 129/1500
# -------------
# （train）
# -------------
# epoch 129 || Epoch_D_Loss:0.0414 ||Epoch_G_Loss:0.2555 ||Epoch_E_Loss:0.2940
# timer:  0.2623 sec.
# -------------
# Epoch 130/1500
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.0435 ||Epoch_G_Loss:0.2441 ||Epoch_E_Loss:0.2764
# timer:  0.2666 sec.
# -------------
# Epoch 131/1500
# -------------
# （train）
# -------------
# epoch 131 || Epoch_D_Loss:0.0472 ||Epoch_G_Loss:0.2267 ||Epoch_E_Loss:0.2902
# timer:  0.2624 sec.
# -------------
# Epoch 132/1500
# -------------
# （train）
# -------------
# epoch 132 || Epoch_D_Loss:0.0547 ||Epoch_G_Loss:0.2732 ||Epoch_E_Loss:0.2743
# timer:  0.2650 sec.
# -------------
# Epoch 133/1500
# -------------
# （train）
# -------------
# epoch 133 || Epoch_D_Loss:0.0419 ||Epoch_G_Loss:0.2480 ||Epoch_E_Loss:0.2992
# timer:  0.2659 sec.
# -------------
# Epoch 134/1500
# -------------
# （train）
# -------------
# epoch 134 || Epoch_D_Loss:0.0448 ||Epoch_G_Loss:0.2394 ||Epoch_E_Loss:0.2968
# timer:  0.2660 sec.
# -------------
# Epoch 135/1500
# -------------
# （train）
# -------------
# epoch 135 || Epoch_D_Loss:0.0603 ||Epoch_G_Loss:0.2529 ||Epoch_E_Loss:0.2757
# timer:  0.2584 sec.
# -------------
# Epoch 136/1500
# -------------
# （train）
# -------------
# epoch 136 || Epoch_D_Loss:0.0561 ||Epoch_G_Loss:0.2283 ||Epoch_E_Loss:0.2772
# timer:  0.2654 sec.
# -------------
# Epoch 137/1500
# -------------
# （train）
# -------------
# epoch 137 || Epoch_D_Loss:0.0503 ||Epoch_G_Loss:0.2508 ||Epoch_E_Loss:0.2953
# timer:  0.2658 sec.
# -------------
# Epoch 138/1500
# -------------
# （train）
# -------------
# epoch 138 || Epoch_D_Loss:0.0449 ||Epoch_G_Loss:0.2619 ||Epoch_E_Loss:0.3200
# timer:  0.2608 sec.
# -------------
# Epoch 139/1500
# -------------
# （train）
# -------------
# epoch 139 || Epoch_D_Loss:0.0504 ||Epoch_G_Loss:0.2421 ||Epoch_E_Loss:0.2757
# timer:  0.2650 sec.
# -------------
# Epoch 140/1500
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.0787 ||Epoch_G_Loss:0.2063 ||Epoch_E_Loss:0.2521
# timer:  0.2621 sec.
# -------------
# Epoch 141/1500
# -------------
# （train）
# -------------
# epoch 141 || Epoch_D_Loss:0.0736 ||Epoch_G_Loss:0.1950 ||Epoch_E_Loss:0.2556
# timer:  0.2624 sec.
# -------------
# Epoch 142/1500
# -------------
# （train）
# -------------
# epoch 142 || Epoch_D_Loss:0.0584 ||Epoch_G_Loss:0.2199 ||Epoch_E_Loss:0.2703
# timer:  0.2721 sec.
# -------------
# Epoch 143/1500
# -------------
# （train）
# -------------
# epoch 143 || Epoch_D_Loss:0.0360 ||Epoch_G_Loss:0.2584 ||Epoch_E_Loss:0.3239
# timer:  0.2623 sec.
# -------------
# Epoch 144/1500
# -------------
# （train）
# -------------
# epoch 144 || Epoch_D_Loss:0.0389 ||Epoch_G_Loss:0.2526 ||Epoch_E_Loss:0.3063
# timer:  0.2605 sec.
# -------------
# Epoch 145/1500
# -------------
# （train）
# -------------
# epoch 145 || Epoch_D_Loss:0.0588 ||Epoch_G_Loss:0.2213 ||Epoch_E_Loss:0.2796
# timer:  0.2623 sec.
# -------------
# Epoch 146/1500
# -------------
# （train）
# -------------
# epoch 146 || Epoch_D_Loss:0.0730 ||Epoch_G_Loss:0.2034 ||Epoch_E_Loss:0.2376
# timer:  0.2580 sec.
# -------------
# Epoch 147/1500
# -------------
# （train）
# -------------
# epoch 147 || Epoch_D_Loss:0.0767 ||Epoch_G_Loss:0.2005 ||Epoch_E_Loss:0.2415
# timer:  0.2612 sec.
# -------------
# Epoch 148/1500
# -------------
# （train）
# -------------
# epoch 148 || Epoch_D_Loss:0.0524 ||Epoch_G_Loss:0.2424 ||Epoch_E_Loss:0.2759
# timer:  0.2789 sec.
# -------------
# Epoch 149/1500
# -------------
# （train）
# -------------
# epoch 149 || Epoch_D_Loss:0.0466 ||Epoch_G_Loss:0.2710 ||Epoch_E_Loss:0.2844
# timer:  0.2618 sec.
# -------------
# Epoch 150/1500
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.0454 ||Epoch_G_Loss:0.2806 ||Epoch_E_Loss:0.2884
# timer:  0.2627 sec.
# -------------
# Epoch 151/1500
# -------------
# （train）
# -------------
# epoch 151 || Epoch_D_Loss:0.0566 ||Epoch_G_Loss:0.2380 ||Epoch_E_Loss:0.2714
# timer:  0.2784 sec.
# -------------
# Epoch 152/1500
# -------------
# （train）
# -------------
# epoch 152 || Epoch_D_Loss:0.0728 ||Epoch_G_Loss:0.2177 ||Epoch_E_Loss:0.2332
# timer:  0.2603 sec.
# -------------
# Epoch 153/1500
# -------------
# （train）
# -------------
# epoch 153 || Epoch_D_Loss:0.0811 ||Epoch_G_Loss:0.2098 ||Epoch_E_Loss:0.2155
# timer:  0.2638 sec.
# -------------
# Epoch 154/1500
# -------------
# （train）
# -------------
# epoch 154 || Epoch_D_Loss:0.0838 ||Epoch_G_Loss:0.2092 ||Epoch_E_Loss:0.2109
# timer:  0.2633 sec.
# -------------
# Epoch 155/1500
# -------------
# （train）
# -------------
# epoch 155 || Epoch_D_Loss:0.0909 ||Epoch_G_Loss:0.1841 ||Epoch_E_Loss:0.2420
# timer:  0.2673 sec.
# -------------
# Epoch 156/1500
# -------------
# （train）
# -------------
# epoch 156 || Epoch_D_Loss:0.0739 ||Epoch_G_Loss:0.1995 ||Epoch_E_Loss:0.2344
# timer:  0.2642 sec.
# -------------
# Epoch 157/1500
# -------------
# （train）
# -------------
# epoch 157 || Epoch_D_Loss:0.0842 ||Epoch_G_Loss:0.1958 ||Epoch_E_Loss:0.2379
# timer:  0.2617 sec.
# -------------
# Epoch 158/1500
# -------------
# （train）
# -------------
# epoch 158 || Epoch_D_Loss:0.0821 ||Epoch_G_Loss:0.1800 ||Epoch_E_Loss:0.2297
# timer:  0.2644 sec.
# -------------
# Epoch 159/1500
# -------------
# （train）
# -------------
# epoch 159 || Epoch_D_Loss:0.1062 ||Epoch_G_Loss:0.1717 ||Epoch_E_Loss:0.1910
# timer:  0.2600 sec.
# -------------
# Epoch 160/1500
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.1117 ||Epoch_G_Loss:0.1422 ||Epoch_E_Loss:0.1932
# timer:  0.2644 sec.
# -------------
# Epoch 161/1500
# -------------
# （train）
# -------------
# epoch 161 || Epoch_D_Loss:0.1033 ||Epoch_G_Loss:0.1473 ||Epoch_E_Loss:0.2010
# timer:  0.2629 sec.
# -------------
# Epoch 162/1500
# -------------
# （train）
# -------------
# epoch 162 || Epoch_D_Loss:0.0848 ||Epoch_G_Loss:0.1925 ||Epoch_E_Loss:0.2156
# timer:  0.2634 sec.
# -------------
# Epoch 163/1500
# -------------
# （train）
# -------------
# epoch 163 || Epoch_D_Loss:0.0697 ||Epoch_G_Loss:0.2107 ||Epoch_E_Loss:0.2570
# timer:  0.2643 sec.
# -------------
# Epoch 164/1500
# -------------
# （train）
# -------------
# epoch 164 || Epoch_D_Loss:0.0563 ||Epoch_G_Loss:0.2202 ||Epoch_E_Loss:0.2703
# timer:  0.2600 sec.
# -------------
# Epoch 165/1500
# -------------
# （train）
# -------------
# epoch 165 || Epoch_D_Loss:0.0627 ||Epoch_G_Loss:0.2095 ||Epoch_E_Loss:0.2426
# timer:  0.2644 sec.
# -------------
# Epoch 166/1500
# -------------
# （train）
# -------------
# epoch 166 || Epoch_D_Loss:0.0627 ||Epoch_G_Loss:0.2100 ||Epoch_E_Loss:0.2488
# timer:  0.2608 sec.
# -------------
# Epoch 167/1500
# -------------
# （train）
# -------------
# epoch 167 || Epoch_D_Loss:0.0706 ||Epoch_G_Loss:0.2203 ||Epoch_E_Loss:0.2245
# timer:  0.2606 sec.
# -------------
# Epoch 168/1500
# -------------
# （train）
# -------------
# epoch 168 || Epoch_D_Loss:0.0650 ||Epoch_G_Loss:0.1981 ||Epoch_E_Loss:0.2316
# timer:  0.2601 sec.
# -------------
# Epoch 169/1500
# -------------
# （train）
# -------------
# epoch 169 || Epoch_D_Loss:0.0899 ||Epoch_G_Loss:0.1904 ||Epoch_E_Loss:0.2016
# timer:  0.2683 sec.
# -------------
# Epoch 170/1500
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.0759 ||Epoch_G_Loss:0.1881 ||Epoch_E_Loss:0.2304
# timer:  0.2598 sec.
# -------------
# Epoch 171/1500
# -------------
# （train）
# -------------
# epoch 171 || Epoch_D_Loss:0.0896 ||Epoch_G_Loss:0.1881 ||Epoch_E_Loss:0.2146
# timer:  0.2637 sec.
# -------------
# Epoch 172/1500
# -------------
# （train）
# -------------
# epoch 172 || Epoch_D_Loss:0.0946 ||Epoch_G_Loss:0.1677 ||Epoch_E_Loss:0.2050
# timer:  0.2624 sec.
# -------------
# Epoch 173/1500
# -------------
# （train）
# -------------
# epoch 173 || Epoch_D_Loss:0.1025 ||Epoch_G_Loss:0.1703 ||Epoch_E_Loss:0.1918
# timer:  0.2622 sec.
# -------------
# Epoch 174/1500
# -------------
# （train）
# -------------
# epoch 174 || Epoch_D_Loss:0.0866 ||Epoch_G_Loss:0.1860 ||Epoch_E_Loss:0.2011
# timer:  0.2575 sec.
# -------------
# Epoch 175/1500
# -------------
# （train）
# -------------
# epoch 175 || Epoch_D_Loss:0.0816 ||Epoch_G_Loss:0.1878 ||Epoch_E_Loss:0.2042
# timer:  0.2612 sec.
# -------------
# Epoch 176/1500
# -------------
# （train）
# -------------
# epoch 176 || Epoch_D_Loss:0.0839 ||Epoch_G_Loss:0.1880 ||Epoch_E_Loss:0.1992
# timer:  0.2636 sec.
# -------------
# Epoch 177/1500
# -------------
# （train）
# -------------
# epoch 177 || Epoch_D_Loss:0.0878 ||Epoch_G_Loss:0.1888 ||Epoch_E_Loss:0.2065
# timer:  0.2590 sec.
# -------------
# Epoch 178/1500
# -------------
# （train）
# -------------
# epoch 178 || Epoch_D_Loss:0.0791 ||Epoch_G_Loss:0.1753 ||Epoch_E_Loss:0.2168
# timer:  0.2600 sec.
# -------------
# Epoch 179/1500
# -------------
# （train）
# -------------
# epoch 179 || Epoch_D_Loss:0.0850 ||Epoch_G_Loss:0.1834 ||Epoch_E_Loss:0.2091
# timer:  0.2668 sec.
# -------------
# Epoch 180/1500
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.0766 ||Epoch_G_Loss:0.1795 ||Epoch_E_Loss:0.2205
# timer:  0.2630 sec.
# -------------
# Epoch 181/1500
# -------------
# （train）
# -------------
# epoch 181 || Epoch_D_Loss:0.0887 ||Epoch_G_Loss:0.2021 ||Epoch_E_Loss:0.2006
# timer:  0.2623 sec.
# -------------
# Epoch 182/1500
# -------------
# （train）
# -------------
# epoch 182 || Epoch_D_Loss:0.0789 ||Epoch_G_Loss:0.2085 ||Epoch_E_Loss:0.2028
# timer:  0.2593 sec.
# -------------
# Epoch 183/1500
# -------------
# （train）
# -------------
# epoch 183 || Epoch_D_Loss:0.0806 ||Epoch_G_Loss:0.1928 ||Epoch_E_Loss:0.2065
# timer:  0.2619 sec.
# -------------
# Epoch 184/1500
# -------------
# （train）
# -------------
# epoch 184 || Epoch_D_Loss:0.0779 ||Epoch_G_Loss:0.1973 ||Epoch_E_Loss:0.2067
# timer:  0.2638 sec.
# -------------
# Epoch 185/1500
# -------------
# （train）
# -------------
# epoch 185 || Epoch_D_Loss:0.0724 ||Epoch_G_Loss:0.2057 ||Epoch_E_Loss:0.2098
# timer:  0.2599 sec.
# -------------
# Epoch 186/1500
# -------------
# （train）
# -------------
# epoch 186 || Epoch_D_Loss:0.0896 ||Epoch_G_Loss:0.1799 ||Epoch_E_Loss:0.1915
# timer:  0.2624 sec.
# -------------
# Epoch 187/1500
# -------------
# （train）
# -------------
# epoch 187 || Epoch_D_Loss:0.0989 ||Epoch_G_Loss:0.1731 ||Epoch_E_Loss:0.1847
# timer:  0.2662 sec.
# -------------
# Epoch 188/1500
# -------------
# （train）
# -------------
# epoch 188 || Epoch_D_Loss:0.1004 ||Epoch_G_Loss:0.1574 ||Epoch_E_Loss:0.1795
# timer:  0.2603 sec.
# -------------
# Epoch 189/1500
# -------------
# （train）
# -------------
# epoch 189 || Epoch_D_Loss:0.0885 ||Epoch_G_Loss:0.1689 ||Epoch_E_Loss:0.1920
# timer:  0.2643 sec.
# -------------
# Epoch 190/1500
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.0835 ||Epoch_G_Loss:0.1884 ||Epoch_E_Loss:0.1895
# timer:  0.2654 sec.
# -------------
# Epoch 191/1500
# -------------
# （train）
# -------------
# epoch 191 || Epoch_D_Loss:0.0746 ||Epoch_G_Loss:0.1899 ||Epoch_E_Loss:0.2016
# timer:  0.2633 sec.
# -------------
# Epoch 192/1500
# -------------
# （train）
# -------------
# epoch 192 || Epoch_D_Loss:0.0821 ||Epoch_G_Loss:0.1915 ||Epoch_E_Loss:0.1924
# timer:  0.2653 sec.
# -------------
# Epoch 193/1500
# -------------
# （train）
# -------------
# epoch 193 || Epoch_D_Loss:0.0990 ||Epoch_G_Loss:0.1768 ||Epoch_E_Loss:0.1727
# timer:  0.2645 sec.
# -------------
# Epoch 194/1500
# -------------
# （train）
# -------------
# epoch 194 || Epoch_D_Loss:0.1075 ||Epoch_G_Loss:0.1559 ||Epoch_E_Loss:0.1693
# timer:  0.2867 sec.
# -------------
# Epoch 195/1500
# -------------
# （train）
# -------------
# epoch 195 || Epoch_D_Loss:0.1172 ||Epoch_G_Loss:0.1518 ||Epoch_E_Loss:0.1573
# timer:  0.2733 sec.
# -------------
# Epoch 196/1500
# -------------
# （train）
# -------------
# epoch 196 || Epoch_D_Loss:0.1081 ||Epoch_G_Loss:0.1445 ||Epoch_E_Loss:0.1812
# timer:  0.2724 sec.
# -------------
# Epoch 197/1500
# -------------
# （train）
# -------------
# epoch 197 || Epoch_D_Loss:0.1008 ||Epoch_G_Loss:0.1698 ||Epoch_E_Loss:0.1727
# timer:  0.2743 sec.
# -------------
# Epoch 198/1500
# -------------
# （train）
# -------------
# epoch 198 || Epoch_D_Loss:0.1018 ||Epoch_G_Loss:0.1539 ||Epoch_E_Loss:0.1719
# timer:  0.2925 sec.
# -------------
# Epoch 199/1500
# -------------
# （train）
# -------------
# epoch 199 || Epoch_D_Loss:0.0968 ||Epoch_G_Loss:0.1524 ||Epoch_E_Loss:0.1729
# timer:  0.2599 sec.
# -------------
# Epoch 200/1500
# -------------
# （train）
# -------------
# epoch 200 || Epoch_D_Loss:0.0970 ||Epoch_G_Loss:0.1370 ||Epoch_E_Loss:0.1812
# timer:  0.2626 sec.
# -------------
# Epoch 201/1500
# -------------
# （train）
# -------------
# epoch 201 || Epoch_D_Loss:0.1235 ||Epoch_G_Loss:0.1538 ||Epoch_E_Loss:0.1493
# timer:  0.2577 sec.
# -------------
# Epoch 202/1500
# -------------
# （train）
# -------------
# epoch 202 || Epoch_D_Loss:0.1577 ||Epoch_G_Loss:0.1232 ||Epoch_E_Loss:0.1255
# timer:  0.2675 sec.
# -------------
# Epoch 203/1500
# -------------
# （train）
# -------------
# epoch 203 || Epoch_D_Loss:0.1825 ||Epoch_G_Loss:0.0919 ||Epoch_E_Loss:0.1224
# timer:  0.2663 sec.
# -------------
# Epoch 204/1500
# -------------
# （train）
# -------------
# epoch 204 || Epoch_D_Loss:0.1756 ||Epoch_G_Loss:0.0966 ||Epoch_E_Loss:0.1107
# timer:  0.2633 sec.
# -------------
# Epoch 205/1500
# -------------
# （train）
# -------------
# epoch 205 || Epoch_D_Loss:0.1196 ||Epoch_G_Loss:0.1342 ||Epoch_E_Loss:0.1450
# timer:  0.2663 sec.
# -------------
# Epoch 206/1500
# -------------
# （train）
# -------------
# epoch 206 || Epoch_D_Loss:0.0959 ||Epoch_G_Loss:0.1655 ||Epoch_E_Loss:0.1628
# timer:  0.2687 sec.
# -------------
# Epoch 207/1500
# -------------
# （train）
# -------------
# epoch 207 || Epoch_D_Loss:0.0900 ||Epoch_G_Loss:0.1765 ||Epoch_E_Loss:0.1710
# timer:  0.2637 sec.
# -------------
# Epoch 208/1500
# -------------
# （train）
# -------------
# epoch 208 || Epoch_D_Loss:0.0786 ||Epoch_G_Loss:0.1846 ||Epoch_E_Loss:0.1778
# timer:  0.2624 sec.
# -------------
# Epoch 209/1500
# -------------
# （train）
# -------------
# epoch 209 || Epoch_D_Loss:0.0818 ||Epoch_G_Loss:0.1663 ||Epoch_E_Loss:0.1784
# timer:  0.2702 sec.
# -------------
# Epoch 210/1500
# -------------
# （train）
# -------------
# epoch 210 || Epoch_D_Loss:0.0954 ||Epoch_G_Loss:0.1646 ||Epoch_E_Loss:0.1568
# timer:  0.2687 sec.
# -------------
# Epoch 211/1500
# -------------
# （train）
# -------------
# epoch 211 || Epoch_D_Loss:0.1121 ||Epoch_G_Loss:0.1395 ||Epoch_E_Loss:0.1443
# timer:  0.2804 sec.
# -------------
# Epoch 212/1500
# -------------
# （train）
# -------------
# epoch 212 || Epoch_D_Loss:0.1285 ||Epoch_G_Loss:0.1189 ||Epoch_E_Loss:0.1334
# timer:  0.2742 sec.
# -------------
# Epoch 213/1500
# -------------
# （train）
# -------------
# epoch 213 || Epoch_D_Loss:0.1339 ||Epoch_G_Loss:0.1206 ||Epoch_E_Loss:0.1275
# timer:  0.2700 sec.
# -------------
# Epoch 214/1500
# -------------
# （train）
# -------------
# epoch 214 || Epoch_D_Loss:0.1304 ||Epoch_G_Loss:0.1234 ||Epoch_E_Loss:0.1275
# timer:  0.2802 sec.
# -------------
# Epoch 215/1500
# -------------
# （train）
# -------------
# epoch 215 || Epoch_D_Loss:0.1355 ||Epoch_G_Loss:0.1294 ||Epoch_E_Loss:0.1284
# timer:  0.2829 sec.
# -------------
# Epoch 216/1500
# -------------
# （train）
# -------------
# epoch 216 || Epoch_D_Loss:0.1293 ||Epoch_G_Loss:0.1173 ||Epoch_E_Loss:0.1390
# timer:  0.2619 sec.
# -------------
# Epoch 217/1500
# -------------
# （train）
# -------------
# epoch 217 || Epoch_D_Loss:0.1249 ||Epoch_G_Loss:0.1257 ||Epoch_E_Loss:0.1345
# timer:  0.2740 sec.
# -------------
# Epoch 218/1500
# -------------
# （train）
# -------------
# epoch 218 || Epoch_D_Loss:0.1032 ||Epoch_G_Loss:0.1433 ||Epoch_E_Loss:0.1524
# timer:  0.2793 sec.
# -------------
# Epoch 219/1500
# -------------
# （train）
# -------------
# epoch 219 || Epoch_D_Loss:0.0871 ||Epoch_G_Loss:0.1640 ||Epoch_E_Loss:0.1649
# timer:  0.2786 sec.
# -------------
# Epoch 220/1500
# -------------
# （train）
# -------------
# epoch 220 || Epoch_D_Loss:0.0871 ||Epoch_G_Loss:0.1614 ||Epoch_E_Loss:0.1693
# timer:  0.2784 sec.
# -------------
# Epoch 221/1500
# -------------
# （train）
# -------------
# epoch 221 || Epoch_D_Loss:0.0851 ||Epoch_G_Loss:0.1486 ||Epoch_E_Loss:0.1689
# timer:  0.2623 sec.
# -------------
# Epoch 222/1500
# -------------
# （train）
# -------------
# epoch 222 || Epoch_D_Loss:0.1025 ||Epoch_G_Loss:0.1417 ||Epoch_E_Loss:0.1490
# timer:  0.2782 sec.
# -------------
# Epoch 223/1500
# -------------
# （train）
# -------------
# epoch 223 || Epoch_D_Loss:0.1376 ||Epoch_G_Loss:0.1229 ||Epoch_E_Loss:0.1219
# timer:  0.2580 sec.
# -------------
# Epoch 224/1500
# -------------
# （train）
# -------------
# epoch 224 || Epoch_D_Loss:0.1321 ||Epoch_G_Loss:0.1180 ||Epoch_E_Loss:0.1281
# timer:  0.2548 sec.
# -------------
# Epoch 225/1500
# -------------
# （train）
# -------------
# epoch 225 || Epoch_D_Loss:0.1359 ||Epoch_G_Loss:0.1262 ||Epoch_E_Loss:0.1225
# timer:  0.2673 sec.
# -------------
# Epoch 226/1500
# -------------
# （train）
# -------------
# epoch 226 || Epoch_D_Loss:0.1308 ||Epoch_G_Loss:0.1352 ||Epoch_E_Loss:0.1258
# timer:  0.2633 sec.
# -------------
# Epoch 227/1500
# -------------
# （train）
# -------------
# epoch 227 || Epoch_D_Loss:0.1233 ||Epoch_G_Loss:0.1224 ||Epoch_E_Loss:0.1329
# timer:  0.2673 sec.
# -------------
# Epoch 228/1500
# -------------
# （train）
# -------------
# epoch 228 || Epoch_D_Loss:0.1323 ||Epoch_G_Loss:0.1199 ||Epoch_E_Loss:0.1227
# timer:  0.2608 sec.
# -------------
# Epoch 229/1500
# -------------
# （train）
# -------------
# epoch 229 || Epoch_D_Loss:0.1424 ||Epoch_G_Loss:0.1163 ||Epoch_E_Loss:0.1171
# timer:  0.2855 sec.
# -------------
# Epoch 230/1500
# -------------
# （train）
# -------------
# epoch 230 || Epoch_D_Loss:0.1220 ||Epoch_G_Loss:0.1335 ||Epoch_E_Loss:0.1296
# timer:  0.2681 sec.
# -------------
# Epoch 231/1500
# -------------
# （train）
# -------------
# epoch 231 || Epoch_D_Loss:0.1108 ||Epoch_G_Loss:0.1387 ||Epoch_E_Loss:0.1386
# timer:  0.2671 sec.
# -------------
# Epoch 232/1500
# -------------
# （train）
# -------------
# epoch 232 || Epoch_D_Loss:0.1033 ||Epoch_G_Loss:0.1391 ||Epoch_E_Loss:0.1471
# timer:  0.2721 sec.
# -------------
# Epoch 233/1500
# -------------
# （train）
# -------------
# epoch 233 || Epoch_D_Loss:0.1064 ||Epoch_G_Loss:0.1313 ||Epoch_E_Loss:0.1418
# timer:  0.2775 sec.
# -------------
# Epoch 234/1500
# -------------
# （train）
# -------------
# epoch 234 || Epoch_D_Loss:0.1144 ||Epoch_G_Loss:0.1380 ||Epoch_E_Loss:0.1358
# timer:  0.2829 sec.
# -------------
# Epoch 235/1500
# -------------
# （train）
# -------------
# epoch 235 || Epoch_D_Loss:0.1271 ||Epoch_G_Loss:0.1313 ||Epoch_E_Loss:0.1240
# timer:  0.2756 sec.
# -------------
# Epoch 236/1500
# -------------
# （train）
# -------------
# epoch 236 || Epoch_D_Loss:0.1387 ||Epoch_G_Loss:0.1242 ||Epoch_E_Loss:0.1168
# timer:  0.2674 sec.
# -------------
# Epoch 237/1500
# -------------
# （train）
# -------------
# epoch 237 || Epoch_D_Loss:0.1344 ||Epoch_G_Loss:0.1240 ||Epoch_E_Loss:0.1240
# timer:  0.2756 sec.
# -------------
# Epoch 238/1500
# -------------
# （train）
# -------------
# epoch 238 || Epoch_D_Loss:0.1276 ||Epoch_G_Loss:0.1199 ||Epoch_E_Loss:0.1272
# timer:  0.2763 sec.
# -------------
# Epoch 239/1500
# -------------
# （train）
# -------------
# epoch 239 || Epoch_D_Loss:0.1355 ||Epoch_G_Loss:0.1132 ||Epoch_E_Loss:0.1261
# timer:  0.2725 sec.
# -------------
# Epoch 240/1500
# -------------
# （train）
# -------------
# epoch 240 || Epoch_D_Loss:0.1208 ||Epoch_G_Loss:0.1222 ||Epoch_E_Loss:0.1302
# timer:  0.2768 sec.
# -------------
# Epoch 241/1500
# -------------
# （train）
# -------------
# epoch 241 || Epoch_D_Loss:0.1271 ||Epoch_G_Loss:0.1318 ||Epoch_E_Loss:0.1300
# timer:  0.2860 sec.
# -------------
# Epoch 242/1500
# -------------
# （train）
# -------------
# epoch 242 || Epoch_D_Loss:0.1143 ||Epoch_G_Loss:0.1548 ||Epoch_E_Loss:0.1360
# timer:  0.2925 sec.
# -------------
# Epoch 243/1500
# -------------
# （train）
# -------------
# epoch 243 || Epoch_D_Loss:0.1061 ||Epoch_G_Loss:0.1428 ||Epoch_E_Loss:0.1437
# timer:  0.2901 sec.
# -------------
# Epoch 244/1500
# -------------
# （train）
# -------------
# epoch 244 || Epoch_D_Loss:0.1138 ||Epoch_G_Loss:0.1333 ||Epoch_E_Loss:0.1406
# timer:  0.2783 sec.
# -------------
# Epoch 245/1500
# -------------
# （train）
# -------------
# epoch 245 || Epoch_D_Loss:0.1235 ||Epoch_G_Loss:0.1323 ||Epoch_E_Loss:0.1300
# timer:  0.2683 sec.
# -------------
# Epoch 246/1500
# -------------
# （train）
# -------------
# epoch 246 || Epoch_D_Loss:0.1238 ||Epoch_G_Loss:0.1220 ||Epoch_E_Loss:0.1289
# timer:  0.2757 sec.
# -------------
# Epoch 247/1500
# -------------
# （train）
# -------------
# epoch 247 || Epoch_D_Loss:0.1328 ||Epoch_G_Loss:0.1381 ||Epoch_E_Loss:0.1243
# timer:  0.2773 sec.
# -------------
# Epoch 248/1500
# -------------
# （train）
# -------------
# epoch 248 || Epoch_D_Loss:0.1239 ||Epoch_G_Loss:0.1316 ||Epoch_E_Loss:0.1331
# timer:  0.2700 sec.
# -------------
# Epoch 249/1500
# -------------
# （train）
# -------------
# epoch 249 || Epoch_D_Loss:0.1206 ||Epoch_G_Loss:0.1468 ||Epoch_E_Loss:0.1330
# timer:  0.2727 sec.
# -------------
# Epoch 250/1500
# -------------
# （train）
# -------------
# epoch 250 || Epoch_D_Loss:0.1072 ||Epoch_G_Loss:0.1334 ||Epoch_E_Loss:0.1457
# timer:  0.2819 sec.
# -------------
# Epoch 251/1500
# -------------
# （train）
# -------------
# epoch 251 || Epoch_D_Loss:0.1121 ||Epoch_G_Loss:0.1433 ||Epoch_E_Loss:0.1395
# timer:  0.2733 sec.
# -------------
# Epoch 252/1500
# -------------
# （train）
# -------------
# epoch 252 || Epoch_D_Loss:0.1064 ||Epoch_G_Loss:0.1286 ||Epoch_E_Loss:0.1433
# timer:  0.2755 sec.
# -------------
# Epoch 253/1500
# -------------
# （train）
# -------------
# epoch 253 || Epoch_D_Loss:0.1188 ||Epoch_G_Loss:0.1235 ||Epoch_E_Loss:0.1333
# timer:  0.2673 sec.
# -------------
# Epoch 254/1500
# -------------
# （train）
# -------------
# epoch 254 || Epoch_D_Loss:0.1233 ||Epoch_G_Loss:0.1320 ||Epoch_E_Loss:0.1340
# timer:  0.2798 sec.
# -------------
# Epoch 255/1500
# -------------
# （train）
# -------------
# epoch 255 || Epoch_D_Loss:0.1179 ||Epoch_G_Loss:0.1377 ||Epoch_E_Loss:0.1329
# timer:  0.2691 sec.
# -------------
# Epoch 256/1500
# -------------
# （train）
# -------------
# epoch 256 || Epoch_D_Loss:0.1125 ||Epoch_G_Loss:0.1437 ||Epoch_E_Loss:0.1389
# timer:  0.2702 sec.
# -------------
# Epoch 257/1500
# -------------
# （train）
# -------------
# epoch 257 || Epoch_D_Loss:0.1193 ||Epoch_G_Loss:0.1453 ||Epoch_E_Loss:0.1325
# timer:  0.2817 sec.
# -------------
# Epoch 258/1500
# -------------
# （train）
# -------------
# epoch 258 || Epoch_D_Loss:0.1171 ||Epoch_G_Loss:0.1284 ||Epoch_E_Loss:0.1315
# timer:  0.2698 sec.
# -------------
# Epoch 259/1500
# -------------
# （train）
# -------------
# epoch 259 || Epoch_D_Loss:0.1377 ||Epoch_G_Loss:0.1488 ||Epoch_E_Loss:0.1198
# timer:  0.2655 sec.
# -------------
# Epoch 260/1500
# -------------
# （train）
# -------------
# epoch 260 || Epoch_D_Loss:0.1260 ||Epoch_G_Loss:0.1239 ||Epoch_E_Loss:0.1335
# timer:  0.2663 sec.
# -------------
# Epoch 261/1500
# -------------
# （train）
# -------------
# epoch 261 || Epoch_D_Loss:0.1257 ||Epoch_G_Loss:0.1290 ||Epoch_E_Loss:0.1293
# timer:  0.2703 sec.
# -------------
# Epoch 262/1500
# -------------
# （train）
# -------------
# epoch 262 || Epoch_D_Loss:0.1094 ||Epoch_G_Loss:0.1298 ||Epoch_E_Loss:0.1428
# timer:  0.2702 sec.
# -------------
# Epoch 263/1500
# -------------
# （train）
# -------------
# epoch 263 || Epoch_D_Loss:0.1141 ||Epoch_G_Loss:0.1378 ||Epoch_E_Loss:0.1370
# timer:  0.2708 sec.
# -------------
# Epoch 264/1500
# -------------
# （train）
# -------------
# epoch 264 || Epoch_D_Loss:0.1098 ||Epoch_G_Loss:0.1332 ||Epoch_E_Loss:0.1444
# timer:  0.2696 sec.
# -------------
# Epoch 265/1500
# -------------
# （train）
# -------------
# epoch 265 || Epoch_D_Loss:0.1056 ||Epoch_G_Loss:0.1248 ||Epoch_E_Loss:0.1433
# timer:  0.2763 sec.
# -------------
# Epoch 266/1500
# -------------
# （train）
# -------------
# epoch 266 || Epoch_D_Loss:0.1264 ||Epoch_G_Loss:0.1381 ||Epoch_E_Loss:0.1332
# timer:  0.3151 sec.
# -------------
# Epoch 267/1500
# -------------
# （train）
# -------------
# epoch 267 || Epoch_D_Loss:0.1374 ||Epoch_G_Loss:0.1228 ||Epoch_E_Loss:0.1245
# timer:  0.2840 sec.
# -------------
# Epoch 268/1500
# -------------
# （train）
# -------------
# epoch 268 || Epoch_D_Loss:0.1340 ||Epoch_G_Loss:0.1224 ||Epoch_E_Loss:0.1295
# timer:  0.2749 sec.
# -------------
# Epoch 269/1500
# -------------
# （train）
# -------------
# epoch 269 || Epoch_D_Loss:0.1484 ||Epoch_G_Loss:0.1280 ||Epoch_E_Loss:0.1198
# timer:  0.2680 sec.
# -------------
# Epoch 270/1500
# -------------
# （train）
# -------------
# epoch 270 || Epoch_D_Loss:0.1330 ||Epoch_G_Loss:0.1225 ||Epoch_E_Loss:0.1256
# timer:  0.2799 sec.
# -------------
# Epoch 271/1500
# -------------
# （train）
# -------------
# epoch 271 || Epoch_D_Loss:0.1154 ||Epoch_G_Loss:0.1484 ||Epoch_E_Loss:0.1398
# timer:  0.2753 sec.
# -------------
# Epoch 272/1500
# -------------
# （train）
# -------------
# epoch 272 || Epoch_D_Loss:0.1031 ||Epoch_G_Loss:0.1540 ||Epoch_E_Loss:0.1470
# timer:  0.2795 sec.
# -------------
# Epoch 273/1500
# -------------
# （train）
# -------------
# epoch 273 || Epoch_D_Loss:0.1040 ||Epoch_G_Loss:0.1343 ||Epoch_E_Loss:0.1480
# timer:  0.2790 sec.
# -------------
# Epoch 274/1500
# -------------
# （train）
# -------------
# epoch 274 || Epoch_D_Loss:0.1111 ||Epoch_G_Loss:0.1445 ||Epoch_E_Loss:0.1378
# timer:  0.2794 sec.
# -------------
# Epoch 275/1500
# -------------
# （train）
# -------------
# epoch 275 || Epoch_D_Loss:0.1034 ||Epoch_G_Loss:0.1394 ||Epoch_E_Loss:0.1450
# timer:  0.2850 sec.
# -------------
# Epoch 276/1500
# -------------
# （train）
# -------------
# epoch 276 || Epoch_D_Loss:0.1042 ||Epoch_G_Loss:0.1429 ||Epoch_E_Loss:0.1428
# timer:  0.2648 sec.
# -------------
# Epoch 277/1500
# -------------
# （train）
# -------------
# epoch 277 || Epoch_D_Loss:0.1096 ||Epoch_G_Loss:0.1541 ||Epoch_E_Loss:0.1412
# timer:  0.2643 sec.
# -------------
# Epoch 278/1500
# -------------
# （train）
# -------------
# epoch 278 || Epoch_D_Loss:0.1099 ||Epoch_G_Loss:0.1447 ||Epoch_E_Loss:0.1417
# timer:  0.2856 sec.
# -------------
# Epoch 279/1500
# -------------
# （train）
# -------------
# epoch 279 || Epoch_D_Loss:0.1241 ||Epoch_G_Loss:0.1532 ||Epoch_E_Loss:0.1285
# timer:  0.2713 sec.
# -------------
# Epoch 280/1500
# -------------
# （train）
# -------------
# epoch 280 || Epoch_D_Loss:0.1235 ||Epoch_G_Loss:0.1385 ||Epoch_E_Loss:0.1324
# timer:  0.2663 sec.
# -------------
# Epoch 281/1500
# -------------
# （train）
# -------------
# epoch 281 || Epoch_D_Loss:0.1408 ||Epoch_G_Loss:0.1363 ||Epoch_E_Loss:0.1196
# timer:  0.2677 sec.
# -------------
# Epoch 282/1500
# -------------
# （train）
# -------------
# epoch 282 || Epoch_D_Loss:0.1213 ||Epoch_G_Loss:0.1346 ||Epoch_E_Loss:0.1334
# timer:  0.2733 sec.
# -------------
# Epoch 283/1500
# -------------
# （train）
# -------------
# epoch 283 || Epoch_D_Loss:0.1186 ||Epoch_G_Loss:0.1335 ||Epoch_E_Loss:0.1305
# timer:  0.2680 sec.
# -------------
# Epoch 284/1500
# -------------
# （train）
# -------------
# epoch 284 || Epoch_D_Loss:0.1194 ||Epoch_G_Loss:0.1431 ||Epoch_E_Loss:0.1371
# timer:  0.2648 sec.
# -------------
# Epoch 285/1500
# -------------
# （train）
# -------------
# epoch 285 || Epoch_D_Loss:0.1091 ||Epoch_G_Loss:0.1423 ||Epoch_E_Loss:0.1409
# timer:  0.2637 sec.
# -------------
# Epoch 286/1500
# -------------
# （train）
# -------------
# epoch 286 || Epoch_D_Loss:0.1157 ||Epoch_G_Loss:0.1440 ||Epoch_E_Loss:0.1379
# timer:  0.2673 sec.
# -------------
# Epoch 287/1500
# -------------
# （train）
# -------------
# epoch 287 || Epoch_D_Loss:0.1121 ||Epoch_G_Loss:0.1381 ||Epoch_E_Loss:0.1443
# timer:  0.2613 sec.
# -------------
# Epoch 288/1500
# -------------
# （train）
# -------------
# epoch 288 || Epoch_D_Loss:0.1136 ||Epoch_G_Loss:0.1412 ||Epoch_E_Loss:0.1387
# timer:  0.2663 sec.
# -------------
# Epoch 289/1500
# -------------
# （train）
# -------------
# epoch 289 || Epoch_D_Loss:0.1144 ||Epoch_G_Loss:0.1211 ||Epoch_E_Loss:0.1416
# timer:  0.2667 sec.
# -------------
# Epoch 290/1500
# -------------
# （train）
# -------------
# epoch 290 || Epoch_D_Loss:0.1246 ||Epoch_G_Loss:0.1361 ||Epoch_E_Loss:0.1287
# timer:  0.2662 sec.
# -------------
# Epoch 291/1500
# -------------
# （train）
# -------------
# epoch 291 || Epoch_D_Loss:0.1272 ||Epoch_G_Loss:0.1370 ||Epoch_E_Loss:0.1293
# timer:  0.2689 sec.
# -------------
# Epoch 292/1500
# -------------
# （train）
# -------------
# epoch 292 || Epoch_D_Loss:0.1221 ||Epoch_G_Loss:0.1228 ||Epoch_E_Loss:0.1375
# timer:  0.2663 sec.
# -------------
# Epoch 293/1500
# -------------
# （train）
# -------------
# epoch 293 || Epoch_D_Loss:0.1263 ||Epoch_G_Loss:0.1288 ||Epoch_E_Loss:0.1282
# timer:  0.2634 sec.
# -------------
# Epoch 294/1500
# -------------
# （train）
# -------------
# epoch 294 || Epoch_D_Loss:0.1255 ||Epoch_G_Loss:0.1317 ||Epoch_E_Loss:0.1330
# timer:  0.2663 sec.
# -------------
# Epoch 295/1500
# -------------
# （train）
# -------------
# epoch 295 || Epoch_D_Loss:0.1229 ||Epoch_G_Loss:0.1525 ||Epoch_E_Loss:0.1305
# timer:  0.2630 sec.
# -------------
# Epoch 296/1500
# -------------
# （train）
# -------------
# epoch 296 || Epoch_D_Loss:0.1149 ||Epoch_G_Loss:0.1397 ||Epoch_E_Loss:0.1400
# timer:  0.2725 sec.
# -------------
# Epoch 297/1500
# -------------
# （train）
# -------------
# ...
# timer:  0.2492 sec.
# -------------
# Epoch 1403/1500
# -------------
# （train）
# -------------
# epoch 1403 || Epoch_D_Loss:0.1069 ||Epoch_G_Loss:0.1305 ||Epoch_E_Loss:0.1545
# timer:  0.2473 sec.
# -------------
# Epoch 1404/1500
# -------------
# （train）
# -------------
# epoch 1404 || Epoch_D_Loss:0.1025 ||Epoch_G_Loss:0.1459 ||Epoch_E_Loss:0.1535
# timer:  0.2513 sec.
# -------------
# Epoch 1405/1500
# -------------
# （train）
# -------------
# epoch 1405 || Epoch_D_Loss:0.0874 ||Epoch_G_Loss:0.1578 ||Epoch_E_Loss:0.1712
# timer:  0.2503 sec.
# -------------
# Epoch 1406/1500
# -------------
# （train）
# -------------
# epoch 1406 || Epoch_D_Loss:0.0858 ||Epoch_G_Loss:0.1608 ||Epoch_E_Loss:0.1756
# timer:  0.2520 sec.
# -------------
# Epoch 1407/1500
# -------------
# （train）
# -------------
# epoch 1407 || Epoch_D_Loss:0.0858 ||Epoch_G_Loss:0.1521 ||Epoch_E_Loss:0.1780
# timer:  0.2514 sec.
# -------------
# Epoch 1408/1500
# -------------
# （train）
# -------------
# epoch 1408 || Epoch_D_Loss:0.1006 ||Epoch_G_Loss:0.1607 ||Epoch_E_Loss:0.1586
# timer:  0.2558 sec.
# -------------
# Epoch 1409/1500
# -------------
# （train）
# -------------
# epoch 1409 || Epoch_D_Loss:0.0925 ||Epoch_G_Loss:0.1481 ||Epoch_E_Loss:0.1667
# timer:  0.2565 sec.
# -------------
# Epoch 1410/1500
# -------------
# （train）
# -------------
# epoch 1410 || Epoch_D_Loss:0.0893 ||Epoch_G_Loss:0.1559 ||Epoch_E_Loss:0.1664
# timer:  0.2513 sec.
# -------------
# Epoch 1411/1500
# -------------
# （train）
# -------------
# epoch 1411 || Epoch_D_Loss:0.1020 ||Epoch_G_Loss:0.1491 ||Epoch_E_Loss:0.1610
# timer:  0.2533 sec.
# -------------
# Epoch 1412/1500
# -------------
# （train）
# -------------
# epoch 1412 || Epoch_D_Loss:0.0930 ||Epoch_G_Loss:0.1503 ||Epoch_E_Loss:0.1645
# timer:  0.2494 sec.
# -------------
# Epoch 1413/1500
# -------------
# （train）
# -------------
# epoch 1413 || Epoch_D_Loss:0.0890 ||Epoch_G_Loss:0.1441 ||Epoch_E_Loss:0.1580
# timer:  0.2503 sec.
# -------------
# Epoch 1414/1500
# -------------
# （train）
# -------------
# epoch 1414 || Epoch_D_Loss:0.1046 ||Epoch_G_Loss:0.1306 ||Epoch_E_Loss:0.1667
# timer:  0.2556 sec.
# -------------
# Epoch 1415/1500
# -------------
# （train）
# -------------
# epoch 1415 || Epoch_D_Loss:0.1006 ||Epoch_G_Loss:0.1707 ||Epoch_E_Loss:0.1550
# timer:  0.2528 sec.
# -------------
# Epoch 1416/1500
# -------------
# （train）
# -------------
# epoch 1416 || Epoch_D_Loss:0.0869 ||Epoch_G_Loss:0.1595 ||Epoch_E_Loss:0.1744
# timer:  0.2536 sec.
# -------------
# Epoch 1417/1500
# -------------
# （train）
# -------------
# epoch 1417 || Epoch_D_Loss:0.0859 ||Epoch_G_Loss:0.1565 ||Epoch_E_Loss:0.1779
# timer:  0.2573 sec.
# -------------
# Epoch 1418/1500
# -------------
# （train）
# -------------
# epoch 1418 || Epoch_D_Loss:0.0918 ||Epoch_G_Loss:0.1530 ||Epoch_E_Loss:0.1714
# timer:  0.2503 sec.
# -------------
# Epoch 1419/1500
# -------------
# （train）
# -------------
# epoch 1419 || Epoch_D_Loss:0.0953 ||Epoch_G_Loss:0.1603 ||Epoch_E_Loss:0.1652
# timer:  0.2503 sec.
# -------------
# Epoch 1420/1500
# -------------
# （train）
# -------------
# epoch 1420 || Epoch_D_Loss:0.1025 ||Epoch_G_Loss:0.1538 ||Epoch_E_Loss:0.1626
# timer:  0.2511 sec.
# -------------
# Epoch 1421/1500
# -------------
# （train）
# -------------
# epoch 1421 || Epoch_D_Loss:0.0978 ||Epoch_G_Loss:0.1355 ||Epoch_E_Loss:0.1675
# timer:  0.2558 sec.
# -------------
# Epoch 1422/1500
# -------------
# （train）
# -------------
# epoch 1422 || Epoch_D_Loss:0.1124 ||Epoch_G_Loss:0.1326 ||Epoch_E_Loss:0.1525
# timer:  0.2583 sec.
# -------------
# Epoch 1423/1500
# -------------
# （train）
# -------------
# epoch 1423 || Epoch_D_Loss:0.1124 ||Epoch_G_Loss:0.1327 ||Epoch_E_Loss:0.1499
# timer:  0.2509 sec.
# -------------
# Epoch 1424/1500
# -------------
# （train）
# -------------
# epoch 1424 || Epoch_D_Loss:0.1038 ||Epoch_G_Loss:0.1403 ||Epoch_E_Loss:0.1638
# timer:  0.2563 sec.
# -------------
# Epoch 1425/1500
# -------------
# （train）
# -------------
# epoch 1425 || Epoch_D_Loss:0.0965 ||Epoch_G_Loss:0.1630 ||Epoch_E_Loss:0.1488
# timer:  0.2483 sec.
# -------------
# Epoch 1426/1500
# -------------
# （train）
# -------------
# epoch 1426 || Epoch_D_Loss:0.0918 ||Epoch_G_Loss:0.1490 ||Epoch_E_Loss:0.1635
# timer:  0.2503 sec.
# -------------
# Epoch 1427/1500
# -------------
# （train）
# -------------
# epoch 1427 || Epoch_D_Loss:0.1011 ||Epoch_G_Loss:0.1328 ||Epoch_E_Loss:0.1481
# timer:  0.2553 sec.
# -------------
# Epoch 1428/1500
# -------------
# （train）
# -------------
# epoch 1428 || Epoch_D_Loss:0.1156 ||Epoch_G_Loss:0.1334 ||Epoch_E_Loss:0.1407
# timer:  0.2546 sec.
# -------------
# Epoch 1429/1500
# -------------
# （train）
# -------------
# epoch 1429 || Epoch_D_Loss:0.1117 ||Epoch_G_Loss:0.1478 ||Epoch_E_Loss:0.1276
# timer:  0.2502 sec.
# -------------
# Epoch 1430/1500
# -------------
# （train）
# -------------
# epoch 1430 || Epoch_D_Loss:0.1025 ||Epoch_G_Loss:0.1367 ||Epoch_E_Loss:0.1593
# timer:  0.2493 sec.
# -------------
# Epoch 1431/1500
# -------------
# （train）
# -------------
# epoch 1431 || Epoch_D_Loss:0.0770 ||Epoch_G_Loss:0.1537 ||Epoch_E_Loss:0.1665
# timer:  0.2573 sec.
# -------------
# Epoch 1432/1500
# -------------
# （train）
# -------------
# epoch 1432 || Epoch_D_Loss:0.0729 ||Epoch_G_Loss:0.1564 ||Epoch_E_Loss:0.1809
# timer:  0.2494 sec.
# -------------
# Epoch 1433/1500
# -------------
# （train）
# -------------
# epoch 1433 || Epoch_D_Loss:0.0709 ||Epoch_G_Loss:0.1853 ||Epoch_E_Loss:0.1780
# timer:  0.2593 sec.
# -------------
# Epoch 1434/1500
# -------------
# （train）
# -------------
# epoch 1434 || Epoch_D_Loss:0.0731 ||Epoch_G_Loss:0.1735 ||Epoch_E_Loss:0.1731
# timer:  0.2494 sec.
# -------------
# Epoch 1435/1500
# -------------
# （train）
# -------------
# epoch 1435 || Epoch_D_Loss:0.0864 ||Epoch_G_Loss:0.1591 ||Epoch_E_Loss:0.1663
# timer:  0.2503 sec.
# -------------
# Epoch 1436/1500
# -------------
# （train）
# -------------
# epoch 1436 || Epoch_D_Loss:0.1064 ||Epoch_G_Loss:0.1396 ||Epoch_E_Loss:0.1346
# timer:  0.2561 sec.
# -------------
# Epoch 1437/1500
# -------------
# （train）
# -------------
# epoch 1437 || Epoch_D_Loss:0.1186 ||Epoch_G_Loss:0.1205 ||Epoch_E_Loss:0.1303
# timer:  0.2508 sec.
# -------------
# Epoch 1438/1500
# -------------
# （train）
# -------------
# epoch 1438 || Epoch_D_Loss:0.1116 ||Epoch_G_Loss:0.1384 ||Epoch_E_Loss:0.1299
# timer:  0.2509 sec.
# -------------
# Epoch 1439/1500
# -------------
# （train）
# -------------
# epoch 1439 || Epoch_D_Loss:0.0777 ||Epoch_G_Loss:0.1626 ||Epoch_E_Loss:0.1587
# timer:  0.2473 sec.
# -------------
# Epoch 1440/1500
# -------------
# （train）
# -------------
# epoch 1440 || Epoch_D_Loss:0.0651 ||Epoch_G_Loss:0.1760 ||Epoch_E_Loss:0.1841
# timer:  0.2483 sec.
# -------------
# Epoch 1441/1500
# -------------
# （train）
# -------------
# epoch 1441 || Epoch_D_Loss:0.0640 ||Epoch_G_Loss:0.1867 ||Epoch_E_Loss:0.1784
# timer:  0.2493 sec.
# -------------
# Epoch 1442/1500
# -------------
# （train）
# -------------
# epoch 1442 || Epoch_D_Loss:0.0685 ||Epoch_G_Loss:0.1642 ||Epoch_E_Loss:0.1778
# timer:  0.2524 sec.
# -------------
# Epoch 1443/1500
# -------------
# （train）
# -------------
# epoch 1443 || Epoch_D_Loss:0.0864 ||Epoch_G_Loss:0.1594 ||Epoch_E_Loss:0.1529
# timer:  0.2503 sec.
# -------------
# Epoch 1444/1500
# -------------
# （train）
# -------------
# epoch 1444 || Epoch_D_Loss:0.0946 ||Epoch_G_Loss:0.1515 ||Epoch_E_Loss:0.1402
# timer:  0.2553 sec.
# -------------
# Epoch 1445/1500
# -------------
# （train）
# -------------
# epoch 1445 || Epoch_D_Loss:0.0992 ||Epoch_G_Loss:0.1408 ||Epoch_E_Loss:0.1422
# timer:  0.2557 sec.
# -------------
# Epoch 1446/1500
# -------------
# （train）
# -------------
# epoch 1446 || Epoch_D_Loss:0.0961 ||Epoch_G_Loss:0.1339 ||Epoch_E_Loss:0.1523
# timer:  0.2513 sec.
# -------------
# Epoch 1447/1500
# -------------
# （train）
# -------------
# epoch 1447 || Epoch_D_Loss:0.0822 ||Epoch_G_Loss:0.1423 ||Epoch_E_Loss:0.1632
# timer:  0.2493 sec.
# -------------
# Epoch 1448/1500
# -------------
# （train）
# -------------
# epoch 1448 || Epoch_D_Loss:0.0832 ||Epoch_G_Loss:0.1632 ||Epoch_E_Loss:0.1591
# timer:  0.2554 sec.
# -------------
# Epoch 1449/1500
# -------------
# （train）
# -------------
# epoch 1449 || Epoch_D_Loss:0.0762 ||Epoch_G_Loss:0.1655 ||Epoch_E_Loss:0.1597
# timer:  0.2523 sec.
# -------------
# Epoch 1450/1500
# -------------
# （train）
# -------------
# epoch 1450 || Epoch_D_Loss:0.0823 ||Epoch_G_Loss:0.1558 ||Epoch_E_Loss:0.1655
# timer:  0.2513 sec.
# -------------
# Epoch 1451/1500
# -------------
# （train）
# -------------
# epoch 1451 || Epoch_D_Loss:0.0887 ||Epoch_G_Loss:0.1477 ||Epoch_E_Loss:0.1576
# timer:  0.2518 sec.
# -------------
# Epoch 1452/1500
# -------------
# （train）
# -------------
# epoch 1452 || Epoch_D_Loss:0.0852 ||Epoch_G_Loss:0.1595 ||Epoch_E_Loss:0.1568
# timer:  0.2473 sec.
# -------------
# Epoch 1453/1500
# -------------
# （train）
# -------------
# epoch 1453 || Epoch_D_Loss:0.0802 ||Epoch_G_Loss:0.1559 ||Epoch_E_Loss:0.1668
# timer:  0.2484 sec.
# -------------
# Epoch 1454/1500
# -------------
# （train）
# -------------
# epoch 1454 || Epoch_D_Loss:0.0799 ||Epoch_G_Loss:0.1623 ||Epoch_E_Loss:0.1699
# timer:  0.2523 sec.
# -------------
# Epoch 1455/1500
# -------------
# （train）
# -------------
# epoch 1455 || Epoch_D_Loss:0.0903 ||Epoch_G_Loss:0.1694 ||Epoch_E_Loss:0.1519
# timer:  0.2513 sec.
# -------------
# Epoch 1456/1500
# -------------
# （train）
# -------------
# epoch 1456 || Epoch_D_Loss:0.0820 ||Epoch_G_Loss:0.1425 ||Epoch_E_Loss:0.1660
# timer:  0.2495 sec.
# -------------
# Epoch 1457/1500
# -------------
# （train）
# -------------
# epoch 1457 || Epoch_D_Loss:0.0985 ||Epoch_G_Loss:0.1559 ||Epoch_E_Loss:0.1457
# timer:  0.2533 sec.
# -------------
# Epoch 1458/1500
# -------------
# （train）
# -------------
# epoch 1458 || Epoch_D_Loss:0.0986 ||Epoch_G_Loss:0.1456 ||Epoch_E_Loss:0.1509
# timer:  0.2533 sec.
# -------------
# Epoch 1459/1500
# -------------
# （train）
# -------------
# epoch 1459 || Epoch_D_Loss:0.0933 ||Epoch_G_Loss:0.1548 ||Epoch_E_Loss:0.1495
# timer:  0.2453 sec.
# -------------
# Epoch 1460/1500
# -------------
# （train）
# -------------
# epoch 1460 || Epoch_D_Loss:0.0877 ||Epoch_G_Loss:0.1495 ||Epoch_E_Loss:0.1696
# timer:  0.2513 sec.
# -------------
# Epoch 1461/1500
# -------------
# （train）
# -------------
# epoch 1461 || Epoch_D_Loss:0.0873 ||Epoch_G_Loss:0.1563 ||Epoch_E_Loss:0.1595
# timer:  0.2515 sec.
# -------------
# Epoch 1462/1500
# -------------
# （train）
# -------------
# epoch 1462 || Epoch_D_Loss:0.0812 ||Epoch_G_Loss:0.1571 ||Epoch_E_Loss:0.1644
# timer:  0.2543 sec.
# -------------
# Epoch 1463/1500
# -------------
# （train）
# -------------
# epoch 1463 || Epoch_D_Loss:0.0822 ||Epoch_G_Loss:0.1704 ||Epoch_E_Loss:0.1613
# timer:  0.2507 sec.
# -------------
# Epoch 1464/1500
# -------------
# （train）
# -------------
# epoch 1464 || Epoch_D_Loss:0.0809 ||Epoch_G_Loss:0.1435 ||Epoch_E_Loss:0.1659
# timer:  0.2483 sec.
# -------------
# Epoch 1465/1500
# -------------
# （train）
# -------------
# epoch 1465 || Epoch_D_Loss:0.0926 ||Epoch_G_Loss:0.1589 ||Epoch_E_Loss:0.1480
# timer:  0.2493 sec.
# -------------
# Epoch 1466/1500
# -------------
# （train）
# -------------
# epoch 1466 || Epoch_D_Loss:0.0882 ||Epoch_G_Loss:0.1472 ||Epoch_E_Loss:0.1554
# timer:  0.2493 sec.
# -------------
# Epoch 1467/1500
# -------------
# （train）
# -------------
# epoch 1467 || Epoch_D_Loss:0.1016 ||Epoch_G_Loss:0.1428 ||Epoch_E_Loss:0.1399
# timer:  0.2498 sec.
# -------------
# Epoch 1468/1500
# -------------
# （train）
# -------------
# epoch 1468 || Epoch_D_Loss:0.1027 ||Epoch_G_Loss:0.1236 ||Epoch_E_Loss:0.1432
# timer:  0.2565 sec.
# -------------
# Epoch 1469/1500
# -------------
# （train）
# -------------
# epoch 1469 || Epoch_D_Loss:0.0944 ||Epoch_G_Loss:0.1429 ||Epoch_E_Loss:0.1566
# timer:  0.2509 sec.
# -------------
# Epoch 1470/1500
# -------------
# （train）
# -------------
# epoch 1470 || Epoch_D_Loss:0.0826 ||Epoch_G_Loss:0.1674 ||Epoch_E_Loss:0.1630
# timer:  0.2487 sec.
# -------------
# Epoch 1471/1500
# -------------
# （train）
# -------------
# epoch 1471 || Epoch_D_Loss:0.0688 ||Epoch_G_Loss:0.1800 ||Epoch_E_Loss:0.1772
# timer:  0.2551 sec.
# -------------
# Epoch 1472/1500
# -------------
# （train）
# -------------
# epoch 1472 || Epoch_D_Loss:0.0655 ||Epoch_G_Loss:0.1914 ||Epoch_E_Loss:0.1859
# timer:  0.2548 sec.
# -------------
# Epoch 1473/1500
# -------------
# （train）
# -------------
# epoch 1473 || Epoch_D_Loss:0.0782 ||Epoch_G_Loss:0.1757 ||Epoch_E_Loss:0.1658
# timer:  0.2533 sec.
# -------------
# Epoch 1474/1500
# -------------
# （train）
# -------------
# epoch 1474 || Epoch_D_Loss:0.0994 ||Epoch_G_Loss:0.1422 ||Epoch_E_Loss:0.1479
# timer:  0.2521 sec.
# -------------
# Epoch 1475/1500
# -------------
# （train）
# -------------
# epoch 1475 || Epoch_D_Loss:0.1034 ||Epoch_G_Loss:0.1416 ||Epoch_E_Loss:0.1476
# timer:  0.2459 sec.
# -------------
# Epoch 1476/1500
# -------------
# （train）
# -------------
# epoch 1476 || Epoch_D_Loss:0.0993 ||Epoch_G_Loss:0.1300 ||Epoch_E_Loss:0.1533
# timer:  0.2633 sec.
# -------------
# Epoch 1477/1500
# -------------
# （train）
# -------------
# epoch 1477 || Epoch_D_Loss:0.0960 ||Epoch_G_Loss:0.1533 ||Epoch_E_Loss:0.1555
# timer:  0.2540 sec.
# -------------
# Epoch 1478/1500
# -------------
# （train）
# -------------
# epoch 1478 || Epoch_D_Loss:0.0872 ||Epoch_G_Loss:0.1539 ||Epoch_E_Loss:0.1562
# timer:  0.2508 sec.
# -------------
# Epoch 1479/1500
# -------------
# （train）
# -------------
# epoch 1479 || Epoch_D_Loss:0.0797 ||Epoch_G_Loss:0.1644 ||Epoch_E_Loss:0.1726
# timer:  0.2503 sec.
# -------------
# Epoch 1480/1500
# -------------
# （train）
# -------------
# epoch 1480 || Epoch_D_Loss:0.0821 ||Epoch_G_Loss:0.1721 ||Epoch_E_Loss:0.1721
# timer:  0.2493 sec.
# -------------
# Epoch 1481/1500
# -------------
# （train）
# -------------
# epoch 1481 || Epoch_D_Loss:0.0813 ||Epoch_G_Loss:0.1773 ||Epoch_E_Loss:0.1660
# timer:  0.2564 sec.
# -------------
# Epoch 1482/1500
# -------------
# （train）
# -------------
# epoch 1482 || Epoch_D_Loss:0.0829 ||Epoch_G_Loss:0.1448 ||Epoch_E_Loss:0.1667
# timer:  0.2483 sec.
# -------------
# Epoch 1483/1500
# -------------
# （train）
# -------------
# epoch 1483 || Epoch_D_Loss:0.0935 ||Epoch_G_Loss:0.1397 ||Epoch_E_Loss:0.1611
# timer:  0.2495 sec.
# -------------
# Epoch 1484/1500
# -------------
# （train）
# -------------
# epoch 1484 || Epoch_D_Loss:0.0981 ||Epoch_G_Loss:0.1580 ||Epoch_E_Loss:0.1514
# timer:  0.2583 sec.
# -------------
# Epoch 1485/1500
# -------------
# （train）
# -------------
# epoch 1485 || Epoch_D_Loss:0.0907 ||Epoch_G_Loss:0.1530 ||Epoch_E_Loss:0.1576
# timer:  0.2589 sec.
# -------------
# Epoch 1486/1500
# -------------
# （train）
# -------------
# epoch 1486 || Epoch_D_Loss:0.0865 ||Epoch_G_Loss:0.1614 ||Epoch_E_Loss:0.1565
# timer:  0.2523 sec.
# -------------
# Epoch 1487/1500
# -------------
# （train）
# -------------
# epoch 1487 || Epoch_D_Loss:0.0973 ||Epoch_G_Loss:0.1472 ||Epoch_E_Loss:0.1737
# timer:  0.2523 sec.
# -------------
# Epoch 1488/1500
# -------------
# （train）
# -------------
# epoch 1488 || Epoch_D_Loss:0.1000 ||Epoch_G_Loss:0.1630 ||Epoch_E_Loss:0.1524
# timer:  0.2538 sec.
# -------------
# Epoch 1489/1500
# -------------
# （train）
# -------------
# epoch 1489 || Epoch_D_Loss:0.0883 ||Epoch_G_Loss:0.1621 ||Epoch_E_Loss:0.1561
# timer:  0.2555 sec.
# -------------
# Epoch 1490/1500
# -------------
# （train）
# -------------
# epoch 1490 || Epoch_D_Loss:0.0877 ||Epoch_G_Loss:0.1487 ||Epoch_E_Loss:0.1563
# timer:  0.2488 sec.
# -------------
# Epoch 1491/1500
# -------------
# （train）
# -------------
# epoch 1491 || Epoch_D_Loss:0.0942 ||Epoch_G_Loss:0.1436 ||Epoch_E_Loss:0.1643
# timer:  0.2523 sec.
# -------------
# Epoch 1492/1500
# -------------
# （train）
# -------------
# epoch 1492 || Epoch_D_Loss:0.0899 ||Epoch_G_Loss:0.1360 ||Epoch_E_Loss:0.1675
# timer:  0.2453 sec.
# -------------
# Epoch 1493/1500
# -------------
# （train）
# -------------
# epoch 1493 || Epoch_D_Loss:0.0923 ||Epoch_G_Loss:0.1470 ||Epoch_E_Loss:0.1583
# timer:  0.2504 sec.
# -------------
# Epoch 1494/1500
# -------------
# （train）
# -------------
# epoch 1494 || Epoch_D_Loss:0.0987 ||Epoch_G_Loss:0.1309 ||Epoch_E_Loss:0.1659
# timer:  0.2503 sec.
# -------------
# Epoch 1495/1500
# -------------
# （train）
# -------------
# epoch 1495 || Epoch_D_Loss:0.1149 ||Epoch_G_Loss:0.1321 ||Epoch_E_Loss:0.1553
# timer:  0.2493 sec.
# -------------
# Epoch 1496/1500
# -------------
# （train）
# -------------
# epoch 1496 || Epoch_D_Loss:0.1042 ||Epoch_G_Loss:0.1443 ||Epoch_E_Loss:0.1669
# timer:  0.2503 sec.
# -------------
# Epoch 1497/1500
# -------------
# （train）
# -------------
# epoch 1497 || Epoch_D_Loss:0.0912 ||Epoch_G_Loss:0.1587 ||Epoch_E_Loss:0.1660
# timer:  0.2552 sec.
# -------------
# Epoch 1498/1500
# -------------
# （train）
# -------------
# epoch 1498 || Epoch_D_Loss:0.1009 ||Epoch_G_Loss:0.1237 ||Epoch_E_Loss:0.1583
# timer:  0.2541 sec.
# -------------
# Epoch 1499/1500
# -------------
# （train）
# -------------
# epoch 1499 || Epoch_D_Loss:0.1024 ||Epoch_G_Loss:0.1322 ||Epoch_E_Loss:0.1618
# timer:  0.2503 sec.
# 総イテレーション回数: 10501

# %%
# 生成画像と訓練データを可視化する
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
G_update.eval()
fake_images = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %% [markdown]
# # テスト画像で異常検知する

# %%
# テスト用のDataLoaderの作成


def make_test_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(5):
        img_path = "./data/test_28size/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test_28size/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test_28size/img_2_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list


# ファイルリストを作成
test_img_list = make_test_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
test_dataset = GAN_Img_Dataset(
    file_list=test_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 5

test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False)

# %%
# テストデータの確認
batch_iterator = iter(test_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す

fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

# %%
def Anomaly_score(x, fake_img, z_out_real, D, Lambda=0.1):

    # テスト画像xと生成画像fake_imgのピクセルレベルの差の絶対値を求めて、ミニバッチごとに和を求める
    residual_loss = torch.abs(x-fake_img)
    residual_loss = residual_loss.view(residual_loss.size()[0], -1)
    residual_loss = torch.sum(residual_loss, dim=1)

    # テスト画像xと生成画像fake_imgを識別器Dに入力し、特徴量マップを取り出す

    _, x_feature = D(x, z_out_real)
    _, G_feature = D(fake_img, z_out_real)

    # テスト画像xと生成画像fake_imgの特徴量の差の絶対値を求めて、ミニバッチごとに和を求める
    discrimination_loss = torch.abs(x_feature-G_feature)
    discrimination_loss = discrimination_loss.view(
        discrimination_loss.size()[0], -1)
    discrimination_loss = torch.sum(discrimination_loss, dim=1)

    # ミニバッチごとに2種類の損失を足し算する
    loss_each = (1-Lambda)*residual_loss + Lambda*discrimination_loss

    # ミニバッチ全部の損失を求める
    total_loss = torch.sum(loss_each)

    return total_loss, loss_each, residual_loss

# %%
# 異常検知したい画像
x = imges[0:5]
x = x.to(device)

# 教師データの画像をエンコードしてzにしてから、Gで生成
E_update.eval()
G_update.eval()
z_out_real = E_update(imges.to(device))
imges_reconstract = G_update(z_out_real)

# 損失を求める
loss, loss_each, residual_loss_each = Anomaly_score(
    x, imges_reconstract, z_out_real, D_update, Lambda=0.1)

# 損失の計算。トータルの損失
loss_each = loss_each.cpu().detach().numpy()
print("total loss：", np.round(loss_each, 0))

# 画像を可視化
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(imges_reconstract[i][0].cpu().detach().numpy(), 'gray')
# Out:
# total loss： [202. 205. 264. 218. 214.]
