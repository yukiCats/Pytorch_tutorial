# %% [markdown]
# # 5.1-2 DCGANの作成
#
# - 本ファイルでは、DCGANのネットワークを実装とDCGANの学習をします。

# %% [markdown]
# # 5.1 学習目標
#
# 1.	Generatorが画像を生成するためにどのようなニューラルネットワークの構造になっているのかを理解する
# 2.	Discriminatorが画像の識別をするためにどのようなニューラルネットワークの構造になっているのかを理解する
# 3.	GANの一般的な損失関数の形とニューラルネットワークの学習の流れを理解する
# 4.	DCGANのネットワークを実装できるようになる

# %% [markdown]
# # 5.2 学習目標
#
# 1.	GANの損失関数の形を理解する
# 2.	DCGANを実装し、手書き数字画像が生成できる

# %%
# パッケージのimport
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # 転置畳み込みの例

# %%
input = torch.tensor([[[[1., 1.], [2., 2.]]]])
print("入力データ")
print(input)
print("-----")

print("通常の畳み込み")
m = nn.Conv2d(1, 1, 2, stride=1, bias=False)
m.weight[0, 0, 0, 0] = 1
m.weight[0, 0, 0, 1] = 2
m.weight[0, 0, 1, 0] = 3
m.weight[0, 0, 1, 1] = 4
print("カーネル")
print(m.weight)
print("出力")
print(m(input))

print("-----")
print("転置畳み込み")
m = nn.ConvTranspose2d(1, 1, 2, stride=1, bias=False)
m.weight[0, 0, 0, 0] = 1
m.weight[0, 0, 0, 1] = 2
m.weight[0, 0, 1, 0] = 3
m.weight[0, 0, 1, 1] = 4
print("カーネル")
print(m.weight)
print("出力")
print(m(input))
# Out:
# 入力データ
# tensor([[[[1., 1.],
#           [2., 2.]]]])
# -----
# 通常の畳み込み
# カーネル
# Parameter containing:
# tensor([[[[1., 2.],
#           [3., 4.]]]], grad_fn=<CopySlices>)
# 出力
# tensor([[[[17.]]]], grad_fn=<ThnnConv2DBackward>)
# -----
# 転置畳み込み
# カーネル
# Parameter containing:
# tensor([[[[1., 2.],
#           [3., 4.]]]], grad_fn=<CopySlices>)
# 出力
# tensor([[[[ 1.,  3.,  2.],
#           [ 5., 13.,  8.],
#           [ 6., 14.,  8.]]]], grad_fn=<SlowConvTranspose2DBackward>)

# %% [markdown]
# # Generatorの実装

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.ConvTranspose2d(z_dim, image_size * 8,
                               kernel_size=4, stride=1),
            nn.BatchNorm2d(image_size * 8),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 8, image_size * 4,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 4),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 4, image_size * 2,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 2),
            nn.ReLU(inplace=True))

        self.layer4 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 2, image_size,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True))

        self.last = nn.Sequential(
            nn.ConvTranspose2d(image_size, 1, kernel_size=4,
                               stride=2, padding=1),
            nn.Tanh())
        # 注意：白黒画像なので出力チャネルは1つだけ

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20, image_size=64)

# 入力する乱数
input_z = torch.randn(1, 20)

# テンソルサイズを(1, 20, 1, 1)に変形
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

# 偽画像を出力
fake_images = G(input_z)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()
# Out:
# findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # Discriminatorの実装

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Discriminator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, image_size, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            nn.Conv2d(image_size, image_size*2, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            nn.Conv2d(image_size*2, image_size*4, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer4 = nn.Sequential(
            nn.Conv2d(image_size*4, image_size*8, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
# 動作確認
D = Discriminator(z_dim=20, image_size=64)

# 偽画像を生成
input_z = torch.randn(1, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)

# 偽画像をDに入力
d_out = D(fake_images)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[[[0.5014]]]], grad_fn=<SigmoidBackward>)

# %% [markdown]
# # GANの損失関数

# %%
# Dの誤差関数のイメージ実装
# maximize log(D(x)) + log(1 - D(G(z)))


# ※ xが未定義なので動作はエラーになります
#---------------


# 正解ラベルを作成
mini_batch_size = 2
label_real = torch.full((mini_batch_size,), 1)

# 偽ラベルを作成
label_fake = torch.full((mini_batch_size,), 0)

# 誤差関数を定義
criterion = nn.BCEWithLogitsLoss(reduction='mean')

# 真の画像を判定
d_out_real = D(x)

# 偽の画像を生成して判定
input_z = torch.randn(mini_batch_size, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)
d_out_fake = D(fake_images)

# 誤差を計算
d_loss_real = criterion(d_out_real.view(-1), label_real)
d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
d_loss = d_loss_real + d_loss_fake
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4a037485d485> in <module>
#      18
#      19 # 真の画像を判定
# ---> 20 d_out_real = D(x)
#      21
#      22 # 偽の画像を生成して判定
#
# NameError: name 'x' is not defined

# %%
# Gの誤差関数のイメージ実装
# maximize log(D(G(z)))


# ※ xが未定義なので動作はエラーになります
#---------------


# 偽の画像を生成して判定
input_z = torch.randn(mini_batch_size, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)
d_out_fake = D(fake_images)

# 誤差を計算
g_loss = criterion(d_out_fake.view(-1), label_real)

# %% [markdown]
# # DataLoaderの作成

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 64, 64])

# %% [markdown]
# # 学習させる

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # Conv2dとConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


# 初期化の実施
G.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
# モデルを学習させる関数を作成


def train_model(G, D, dataloader, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    # 誤差関数を定義
    criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イテレーションカウンタをセット
    iteration = 1
    logs = []

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('（train）')

        # データローダーからminibatchずつ取り出すループ
        for imges in dataloader:

            # --------------------
            # 1. Discriminatorの学習
            # --------------------
            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            if imges.size()[0] == 1:
                continue

            # GPUが使えるならGPUにデータを送る
            imges = imges.to(device)

            # 正解ラベルと偽ラベルを作成
            # epochの最後のイテレーションはミニバッチの数が少なくなる
            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)

            # 真の画像を判定
            d_out_real = D(imges)

            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake = D(fake_images)

            # 誤差を計算
#             print(d_out_real.view(-1))
#             print(label_real.astype(flout))
            label_real = label_real.type_as(d_out_real.view(-1))
            label_fake = label_fake.type_as(d_out_fake.view(-1))
            d_loss_real = criterion(d_out_real.view(-1), label_real)
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            d_loss = d_loss_real + d_loss_fake

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()

            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generatorの学習
            # --------------------
            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake = D(fake_images)

            # 誤差を計算
            g_loss = criterion(d_out_fake.view(-1), label_real)

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    return G, D

# %%
# 学習・検証を実行する
# 6分ほどかかる
num_epochs = 200
G_update, D_update = train_model(
    G, D, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/200
# -------------
# （train）
# -------------
# epoch 0 || Epoch_D_Loss:0.0715 ||Epoch_G_Loss:0.1923
# timer:  1.3440 sec.
# -------------
# Epoch 1/200
# -------------
# （train）
# -------------
# epoch 1 || Epoch_D_Loss:0.0192 ||Epoch_G_Loss:0.4925
# timer:  0.5824 sec.
# -------------
# Epoch 2/200
# -------------
# （train）
# -------------
# epoch 2 || Epoch_D_Loss:0.2103 ||Epoch_G_Loss:0.3353
# timer:  0.5844 sec.
# -------------
# Epoch 3/200
# -------------
# （train）
# -------------
# epoch 3 || Epoch_D_Loss:0.0305 ||Epoch_G_Loss:0.2616
# timer:  0.5845 sec.
# -------------
# Epoch 4/200
# -------------
# （train）
# -------------
# epoch 4 || Epoch_D_Loss:0.0041 ||Epoch_G_Loss:0.4265
# timer:  0.5804 sec.
# -------------
# Epoch 5/200
# -------------
# （train）
# -------------
# epoch 5 || Epoch_D_Loss:0.2411 ||Epoch_G_Loss:0.1736
# timer:  0.5854 sec.
# -------------
# Epoch 6/200
# -------------
# （train）
# -------------
# epoch 6 || Epoch_D_Loss:0.0938 ||Epoch_G_Loss:0.0830
# timer:  0.5964 sec.
# -------------
# Epoch 7/200
# -------------
# （train）
# -------------
# epoch 7 || Epoch_D_Loss:0.0561 ||Epoch_G_Loss:0.1514
# timer:  0.5884 sec.
# -------------
# Epoch 8/200
# -------------
# （train）
# -------------
# epoch 8 || Epoch_D_Loss:0.0649 ||Epoch_G_Loss:0.2001
# timer:  0.5844 sec.
# -------------
# Epoch 9/200
# -------------
# （train）
# -------------
# epoch 9 || Epoch_D_Loss:0.0119 ||Epoch_G_Loss:0.5214
# timer:  0.5924 sec.
# -------------
# Epoch 10/200
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.2589 ||Epoch_G_Loss:0.1267
# timer:  0.6015 sec.
# -------------
# Epoch 11/200
# -------------
# （train）
# -------------
# epoch 11 || Epoch_D_Loss:0.0333 ||Epoch_G_Loss:0.2377
# timer:  0.6098 sec.
# -------------
# Epoch 12/200
# -------------
# （train）
# -------------
# epoch 12 || Epoch_D_Loss:0.0211 ||Epoch_G_Loss:0.3714
# timer:  0.5824 sec.
# -------------
# Epoch 13/200
# -------------
# （train）
# -------------
# epoch 13 || Epoch_D_Loss:0.1099 ||Epoch_G_Loss:0.3784
# timer:  0.6226 sec.
# -------------
# Epoch 14/200
# -------------
# （train）
# -------------
# epoch 14 || Epoch_D_Loss:0.0031 ||Epoch_G_Loss:0.4916
# timer:  0.6225 sec.
# -------------
# Epoch 15/200
# -------------
# （train）
# -------------
# epoch 15 || Epoch_D_Loss:0.0017 ||Epoch_G_Loss:0.5534
# timer:  0.6149 sec.
# -------------
# Epoch 16/200
# -------------
# （train）
# -------------
# epoch 16 || Epoch_D_Loss:0.1061 ||Epoch_G_Loss:0.4801
# timer:  0.6064 sec.
# -------------
# Epoch 17/200
# -------------
# （train）
# -------------
# epoch 17 || Epoch_D_Loss:0.2806 ||Epoch_G_Loss:0.4890
# timer:  0.6160 sec.
# -------------
# Epoch 18/200
# -------------
# （train）
# -------------
# epoch 18 || Epoch_D_Loss:0.0217 ||Epoch_G_Loss:0.3245
# timer:  0.6167 sec.
# -------------
# Epoch 19/200
# -------------
# （train）
# -------------
# epoch 19 || Epoch_D_Loss:0.0549 ||Epoch_G_Loss:0.3188
# timer:  0.6023 sec.
# -------------
# Epoch 20/200
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.0090 ||Epoch_G_Loss:0.4189
# timer:  0.6010 sec.
# -------------
# Epoch 21/200
# -------------
# （train）
# -------------
# epoch 21 || Epoch_D_Loss:0.1798 ||Epoch_G_Loss:0.4109
# timer:  0.6040 sec.
# -------------
# Epoch 22/200
# -------------
# （train）
# -------------
# epoch 22 || Epoch_D_Loss:0.1104 ||Epoch_G_Loss:0.2930
# timer:  0.6050 sec.
# -------------
# Epoch 23/200
# -------------
# （train）
# -------------
# epoch 23 || Epoch_D_Loss:0.0236 ||Epoch_G_Loss:0.2865
# timer:  0.6039 sec.
# -------------
# Epoch 24/200
# -------------
# （train）
# -------------
# epoch 24 || Epoch_D_Loss:0.0270 ||Epoch_G_Loss:0.4825
# timer:  0.6035 sec.
# -------------
# Epoch 25/200
# -------------
# （train）
# -------------
# epoch 25 || Epoch_D_Loss:0.2298 ||Epoch_G_Loss:0.2269
# timer:  0.6071 sec.
# -------------
# Epoch 26/200
# -------------
# （train）
# -------------
# epoch 26 || Epoch_D_Loss:0.0461 ||Epoch_G_Loss:0.2406
# timer:  0.6056 sec.
# -------------
# Epoch 27/200
# -------------
# （train）
# -------------
# epoch 27 || Epoch_D_Loss:0.0767 ||Epoch_G_Loss:0.2638
# timer:  0.6031 sec.
# -------------
# Epoch 28/200
# -------------
# （train）
# -------------
# epoch 28 || Epoch_D_Loss:0.1346 ||Epoch_G_Loss:0.2227
# timer:  0.6068 sec.
# -------------
# Epoch 29/200
# -------------
# （train）
# -------------
# epoch 29 || Epoch_D_Loss:0.1104 ||Epoch_G_Loss:0.2278
# timer:  0.6061 sec.
# -------------
# Epoch 30/200
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.0877 ||Epoch_G_Loss:0.2395
# timer:  0.6047 sec.
# -------------
# Epoch 31/200
# -------------
# （train）
# -------------
# epoch 31 || Epoch_D_Loss:0.0962 ||Epoch_G_Loss:0.1752
# timer:  0.6032 sec.
# -------------
# Epoch 32/200
# -------------
# （train）
# -------------
# epoch 32 || Epoch_D_Loss:0.1031 ||Epoch_G_Loss:0.1854
# timer:  0.6063 sec.
# -------------
# Epoch 33/200
# -------------
# （train）
# -------------
# epoch 33 || Epoch_D_Loss:0.1265 ||Epoch_G_Loss:0.1617
# timer:  0.6049 sec.
# -------------
# Epoch 34/200
# -------------
# （train）
# -------------
# epoch 34 || Epoch_D_Loss:0.0857 ||Epoch_G_Loss:0.1816
# timer:  0.6090 sec.
# -------------
# Epoch 35/200
# -------------
# （train）
# -------------
# epoch 35 || Epoch_D_Loss:0.1038 ||Epoch_G_Loss:0.2023
# timer:  0.6069 sec.
# -------------
# Epoch 36/200
# -------------
# （train）
# -------------
# epoch 36 || Epoch_D_Loss:0.1163 ||Epoch_G_Loss:0.1707
# timer:  0.6124 sec.
# -------------
# Epoch 37/200
# -------------
# （train）
# -------------
# epoch 37 || Epoch_D_Loss:0.1272 ||Epoch_G_Loss:0.2063
# timer:  0.6049 sec.
# -------------
# Epoch 38/200
# -------------
# （train）
# -------------
# epoch 38 || Epoch_D_Loss:0.0920 ||Epoch_G_Loss:0.1657
# timer:  0.6078 sec.
# -------------
# Epoch 39/200
# -------------
# （train）
# -------------
# epoch 39 || Epoch_D_Loss:0.1026 ||Epoch_G_Loss:0.1679
# timer:  0.6074 sec.
# -------------
# Epoch 40/200
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.1137 ||Epoch_G_Loss:0.1789
# timer:  0.6069 sec.
# -------------
# Epoch 41/200
# -------------
# （train）
# -------------
# epoch 41 || Epoch_D_Loss:0.1067 ||Epoch_G_Loss:0.1874
# timer:  0.6074 sec.
# -------------
# Epoch 42/200
# -------------
# （train）
# -------------
# epoch 42 || Epoch_D_Loss:0.1054 ||Epoch_G_Loss:0.1861
# timer:  0.6104 sec.
# -------------
# Epoch 43/200
# -------------
# （train）
# -------------
# epoch 43 || Epoch_D_Loss:0.1111 ||Epoch_G_Loss:0.1755
# timer:  0.6081 sec.
# -------------
# Epoch 44/200
# -------------
# （train）
# -------------
# epoch 44 || Epoch_D_Loss:0.0882 ||Epoch_G_Loss:0.1662
# timer:  0.6091 sec.
# -------------
# Epoch 45/200
# -------------
# （train）
# -------------
# epoch 45 || Epoch_D_Loss:0.1225 ||Epoch_G_Loss:0.1701
# timer:  0.6072 sec.
# -------------
# Epoch 46/200
# -------------
# （train）
# -------------
# epoch 46 || Epoch_D_Loss:0.1117 ||Epoch_G_Loss:0.1963
# timer:  0.6137 sec.
# -------------
# Epoch 47/200
# -------------
# （train）
# -------------
# epoch 47 || Epoch_D_Loss:0.1214 ||Epoch_G_Loss:0.1185
# timer:  0.6156 sec.
# -------------
# Epoch 48/200
# -------------
# （train）
# -------------
# epoch 48 || Epoch_D_Loss:0.1123 ||Epoch_G_Loss:0.1534
# timer:  0.6086 sec.
# -------------
# Epoch 49/200
# -------------
# （train）
# -------------
# epoch 49 || Epoch_D_Loss:0.1122 ||Epoch_G_Loss:0.1292
# timer:  0.6097 sec.
# -------------
# Epoch 50/200
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.1184 ||Epoch_G_Loss:0.1603
# timer:  0.6091 sec.
# -------------
# Epoch 51/200
# -------------
# （train）
# -------------
# epoch 51 || Epoch_D_Loss:0.1113 ||Epoch_G_Loss:0.1237
# timer:  0.6134 sec.
# -------------
# Epoch 52/200
# -------------
# （train）
# -------------
# epoch 52 || Epoch_D_Loss:0.1244 ||Epoch_G_Loss:0.1358
# timer:  0.6094 sec.
# -------------
# Epoch 53/200
# -------------
# （train）
# -------------
# epoch 53 || Epoch_D_Loss:0.1235 ||Epoch_G_Loss:0.1354
# timer:  0.6131 sec.
# -------------
# Epoch 54/200
# -------------
# （train）
# -------------
# epoch 54 || Epoch_D_Loss:0.1170 ||Epoch_G_Loss:0.1213
# timer:  0.6145 sec.
# -------------
# Epoch 55/200
# -------------
# （train）
# -------------
# epoch 55 || Epoch_D_Loss:0.1215 ||Epoch_G_Loss:0.1402
# timer:  0.6105 sec.
# -------------
# Epoch 56/200
# -------------
# （train）
# -------------
# epoch 56 || Epoch_D_Loss:0.1151 ||Epoch_G_Loss:0.1304
# timer:  0.6129 sec.
# -------------
# Epoch 57/200
# -------------
# （train）
# -------------
# epoch 57 || Epoch_D_Loss:0.1137 ||Epoch_G_Loss:0.1416
# timer:  0.6141 sec.
# -------------
# Epoch 58/200
# -------------
# （train）
# -------------
# epoch 58 || Epoch_D_Loss:0.1296 ||Epoch_G_Loss:0.1391
# timer:  0.6123 sec.
# -------------
# Epoch 59/200
# -------------
# （train）
# -------------
# epoch 59 || Epoch_D_Loss:0.1094 ||Epoch_G_Loss:0.1337
# timer:  0.6104 sec.
# -------------
# Epoch 60/200
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.1150 ||Epoch_G_Loss:0.1322
# timer:  0.6132 sec.
# -------------
# Epoch 61/200
# -------------
# （train）
# -------------
# epoch 61 || Epoch_D_Loss:0.1279 ||Epoch_G_Loss:0.1494
# timer:  0.6132 sec.
# -------------
# Epoch 62/200
# -------------
# （train）
# -------------
# epoch 62 || Epoch_D_Loss:0.0985 ||Epoch_G_Loss:0.1578
# timer:  0.6119 sec.
# -------------
# Epoch 63/200
# -------------
# （train）
# -------------
# epoch 63 || Epoch_D_Loss:0.1046 ||Epoch_G_Loss:0.1285
# timer:  0.6114 sec.
# -------------
# Epoch 64/200
# -------------
# （train）
# -------------
# epoch 64 || Epoch_D_Loss:0.1231 ||Epoch_G_Loss:0.1687
# timer:  0.6165 sec.
# -------------
# Epoch 65/200
# -------------
# （train）
# -------------
# epoch 65 || Epoch_D_Loss:0.0899 ||Epoch_G_Loss:0.1619
# timer:  0.6124 sec.
# -------------
# Epoch 66/200
# -------------
# （train）
# -------------
# epoch 66 || Epoch_D_Loss:0.1192 ||Epoch_G_Loss:0.1584
# timer:  0.6168 sec.
# -------------
# Epoch 67/200
# -------------
# （train）
# -------------
# epoch 67 || Epoch_D_Loss:0.1008 ||Epoch_G_Loss:0.1698
# timer:  0.6172 sec.
# -------------
# Epoch 68/200
# -------------
# （train）
# -------------
# epoch 68 || Epoch_D_Loss:0.0911 ||Epoch_G_Loss:0.1504
# timer:  0.6129 sec.
# -------------
# Epoch 69/200
# -------------
# （train）
# -------------
# epoch 69 || Epoch_D_Loss:0.1004 ||Epoch_G_Loss:0.1846
# timer:  0.6130 sec.
# -------------
# Epoch 70/200
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.1111 ||Epoch_G_Loss:0.1563
# timer:  0.6094 sec.
# -------------
# Epoch 71/200
# -------------
# （train）
# -------------
# epoch 71 || Epoch_D_Loss:0.1096 ||Epoch_G_Loss:0.1587
# timer:  0.6174 sec.
# -------------
# Epoch 72/200
# -------------
# （train）
# -------------
# epoch 72 || Epoch_D_Loss:0.0787 ||Epoch_G_Loss:0.1745
# timer:  0.6142 sec.
# -------------
# Epoch 73/200
# -------------
# （train）
# -------------
# epoch 73 || Epoch_D_Loss:0.1163 ||Epoch_G_Loss:0.1844
# timer:  0.6141 sec.
# -------------
# Epoch 74/200
# -------------
# （train）
# -------------
# epoch 74 || Epoch_D_Loss:0.0887 ||Epoch_G_Loss:0.1575
# timer:  0.6160 sec.
# -------------
# Epoch 75/200
# -------------
# （train）
# -------------
# epoch 75 || Epoch_D_Loss:0.1005 ||Epoch_G_Loss:0.1891
# timer:  0.6170 sec.
# -------------
# Epoch 76/200
# -------------
# （train）
# -------------
# epoch 76 || Epoch_D_Loss:0.0855 ||Epoch_G_Loss:0.1611
# timer:  0.6155 sec.
# -------------
# Epoch 77/200
# -------------
# （train）
# -------------
# epoch 77 || Epoch_D_Loss:0.0943 ||Epoch_G_Loss:0.2087
# timer:  0.6178 sec.
# -------------
# Epoch 78/200
# -------------
# （train）
# -------------
# epoch 78 || Epoch_D_Loss:0.0939 ||Epoch_G_Loss:0.1654
# timer:  0.6145 sec.
# -------------
# Epoch 79/200
# -------------
# （train）
# -------------
# epoch 79 || Epoch_D_Loss:0.0987 ||Epoch_G_Loss:0.1784
# timer:  0.6159 sec.
# -------------
# Epoch 80/200
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.0813 ||Epoch_G_Loss:0.1999
# timer:  0.6093 sec.
# -------------
# Epoch 81/200
# -------------
# （train）
# -------------
# epoch 81 || Epoch_D_Loss:0.0981 ||Epoch_G_Loss:0.2030
# timer:  0.6136 sec.
# -------------
# Epoch 82/200
# -------------
# （train）
# -------------
# epoch 82 || Epoch_D_Loss:0.0889 ||Epoch_G_Loss:0.1629
# timer:  0.6163 sec.
# -------------
# Epoch 83/200
# -------------
# （train）
# -------------
# epoch 83 || Epoch_D_Loss:0.0991 ||Epoch_G_Loss:0.1810
# timer:  0.6167 sec.
# -------------
# Epoch 84/200
# -------------
# （train）
# -------------
# epoch 84 || Epoch_D_Loss:0.0900 ||Epoch_G_Loss:0.1754
# timer:  0.6178 sec.
# -------------
# Epoch 85/200
# -------------
# （train）
# -------------
# epoch 85 || Epoch_D_Loss:0.0834 ||Epoch_G_Loss:0.1907
# timer:  0.6149 sec.
# -------------
# Epoch 86/200
# -------------
# （train）
# -------------
# epoch 86 || Epoch_D_Loss:0.1024 ||Epoch_G_Loss:0.1753
# timer:  0.6137 sec.
# -------------
# Epoch 87/200
# -------------
# （train）
# -------------
# epoch 87 || Epoch_D_Loss:0.0746 ||Epoch_G_Loss:0.1778
# timer:  0.6153 sec.
# -------------
# Epoch 88/200
# -------------
# （train）
# -------------
# epoch 88 || Epoch_D_Loss:0.1036 ||Epoch_G_Loss:0.1887
# timer:  0.6118 sec.
# -------------
# Epoch 89/200
# -------------
# （train）
# -------------
# epoch 89 || Epoch_D_Loss:0.0875 ||Epoch_G_Loss:0.1945
# timer:  0.6136 sec.
# -------------
# Epoch 90/200
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.0902 ||Epoch_G_Loss:0.1908
# timer:  0.6140 sec.
# -------------
# Epoch 91/200
# -------------
# （train）
# -------------
# epoch 91 || Epoch_D_Loss:0.0885 ||Epoch_G_Loss:0.2005
# timer:  0.6155 sec.
# -------------
# Epoch 92/200
# -------------
# （train）
# -------------
# epoch 92 || Epoch_D_Loss:0.0826 ||Epoch_G_Loss:0.1726
# timer:  0.6142 sec.
# -------------
# Epoch 93/200
# -------------
# （train）
# -------------
# epoch 93 || Epoch_D_Loss:0.0940 ||Epoch_G_Loss:0.2057
# timer:  0.6131 sec.
# -------------
# Epoch 94/200
# -------------
# （train）
# -------------
# epoch 94 || Epoch_D_Loss:0.0806 ||Epoch_G_Loss:0.1976
# timer:  0.6125 sec.
# -------------
# Epoch 95/200
# -------------
# （train）
# -------------
# epoch 95 || Epoch_D_Loss:0.0930 ||Epoch_G_Loss:0.2046
# timer:  0.6118 sec.
# -------------
# Epoch 96/200
# -------------
# （train）
# -------------
# epoch 96 || Epoch_D_Loss:0.0789 ||Epoch_G_Loss:0.1972
# timer:  0.6147 sec.
# -------------
# Epoch 97/200
# -------------
# （train）
# -------------
# epoch 97 || Epoch_D_Loss:0.0781 ||Epoch_G_Loss:0.2105
# timer:  0.6153 sec.
# -------------
# Epoch 98/200
# -------------
# （train）
# -------------
# epoch 98 || Epoch_D_Loss:0.0805 ||Epoch_G_Loss:0.1997
# timer:  0.6160 sec.
# -------------
# Epoch 99/200
# -------------
# （train）
# -------------
# epoch 99 || Epoch_D_Loss:0.0801 ||Epoch_G_Loss:0.2087
# timer:  0.6138 sec.
# -------------
# Epoch 100/200
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.0890 ||Epoch_G_Loss:0.2151
# timer:  0.6153 sec.
# -------------
# Epoch 101/200
# -------------
# （train）
# -------------
# epoch 101 || Epoch_D_Loss:0.0849 ||Epoch_G_Loss:0.2146
# timer:  0.6190 sec.
# -------------
# Epoch 102/200
# -------------
# （train）
# -------------
# epoch 102 || Epoch_D_Loss:0.0795 ||Epoch_G_Loss:0.2166
# timer:  0.6158 sec.
# -------------
# Epoch 103/200
# -------------
# （train）
# -------------
# epoch 103 || Epoch_D_Loss:0.0713 ||Epoch_G_Loss:0.2277
# timer:  0.6174 sec.
# -------------
# Epoch 104/200
# -------------
# （train）
# -------------
# epoch 104 || Epoch_D_Loss:0.0777 ||Epoch_G_Loss:0.2093
# timer:  0.6179 sec.
# -------------
# Epoch 105/200
# -------------
# （train）
# -------------
# epoch 105 || Epoch_D_Loss:0.0745 ||Epoch_G_Loss:0.2159
# timer:  0.6190 sec.
# -------------
# Epoch 106/200
# -------------
# （train）
# -------------
# epoch 106 || Epoch_D_Loss:0.0828 ||Epoch_G_Loss:0.2170
# timer:  0.6188 sec.
# -------------
# Epoch 107/200
# -------------
# （train）
# -------------
# epoch 107 || Epoch_D_Loss:0.0597 ||Epoch_G_Loss:0.2300
# timer:  0.6208 sec.
# -------------
# Epoch 108/200
# -------------
# （train）
# -------------
# epoch 108 || Epoch_D_Loss:0.0858 ||Epoch_G_Loss:0.2140
# timer:  0.6172 sec.
# -------------
# Epoch 109/200
# -------------
# （train）
# -------------
# epoch 109 || Epoch_D_Loss:0.0763 ||Epoch_G_Loss:0.2318
# timer:  0.6194 sec.
# -------------
# Epoch 110/200
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.0694 ||Epoch_G_Loss:0.2448
# timer:  0.6203 sec.
# -------------
# Epoch 111/200
# -------------
# （train）
# -------------
# epoch 111 || Epoch_D_Loss:0.0641 ||Epoch_G_Loss:0.2332
# timer:  0.6214 sec.
# -------------
# Epoch 112/200
# -------------
# （train）
# -------------
# epoch 112 || Epoch_D_Loss:0.0734 ||Epoch_G_Loss:0.2318
# timer:  0.6185 sec.
# -------------
# Epoch 113/200
# -------------
# （train）
# -------------
# epoch 113 || Epoch_D_Loss:0.0738 ||Epoch_G_Loss:0.2578
# timer:  0.6155 sec.
# -------------
# Epoch 114/200
# -------------
# （train）
# -------------
# epoch 114 || Epoch_D_Loss:0.0626 ||Epoch_G_Loss:0.2162
# timer:  0.6196 sec.
# -------------
# Epoch 115/200
# -------------
# （train）
# -------------
# epoch 115 || Epoch_D_Loss:0.0711 ||Epoch_G_Loss:0.2732
# timer:  0.6156 sec.
# -------------
# Epoch 116/200
# -------------
# （train）
# -------------
# epoch 116 || Epoch_D_Loss:0.0784 ||Epoch_G_Loss:0.2331
# timer:  0.6238 sec.
# -------------
# Epoch 117/200
# -------------
# （train）
# -------------
# epoch 117 || Epoch_D_Loss:0.0639 ||Epoch_G_Loss:0.2485
# timer:  0.6239 sec.
# -------------
# Epoch 118/200
# -------------
# （train）
# -------------
# epoch 118 || Epoch_D_Loss:0.0705 ||Epoch_G_Loss:0.2307
# timer:  0.6252 sec.
# -------------
# Epoch 119/200
# -------------
# （train）
# -------------
# epoch 119 || Epoch_D_Loss:0.0620 ||Epoch_G_Loss:0.2613
# timer:  0.6222 sec.
# -------------
# Epoch 120/200
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.0750 ||Epoch_G_Loss:0.2325
# timer:  0.6218 sec.
# -------------
# Epoch 121/200
# -------------
# （train）
# -------------
# epoch 121 || Epoch_D_Loss:0.0669 ||Epoch_G_Loss:0.2666
# timer:  0.6252 sec.
# -------------
# Epoch 122/200
# -------------
# （train）
# -------------
# epoch 122 || Epoch_D_Loss:0.0677 ||Epoch_G_Loss:0.2572
# timer:  0.6307 sec.
# -------------
# Epoch 123/200
# -------------
# （train）
# -------------
# epoch 123 || Epoch_D_Loss:0.0634 ||Epoch_G_Loss:0.2429
# timer:  0.6343 sec.
# -------------
# Epoch 124/200
# -------------
# （train）
# -------------
# epoch 124 || Epoch_D_Loss:0.0825 ||Epoch_G_Loss:0.2209
# timer:  0.6229 sec.
# -------------
# Epoch 125/200
# -------------
# （train）
# -------------
# epoch 125 || Epoch_D_Loss:0.0627 ||Epoch_G_Loss:0.2888
# timer:  0.6284 sec.
# -------------
# Epoch 126/200
# -------------
# （train）
# -------------
# epoch 126 || Epoch_D_Loss:0.0613 ||Epoch_G_Loss:0.2492
# timer:  0.6349 sec.
# -------------
# Epoch 127/200
# -------------
# （train）
# -------------
# epoch 127 || Epoch_D_Loss:0.0639 ||Epoch_G_Loss:0.2893
# timer:  0.6218 sec.
# -------------
# Epoch 128/200
# -------------
# （train）
# -------------
# epoch 128 || Epoch_D_Loss:0.0555 ||Epoch_G_Loss:0.2483
# timer:  0.6220 sec.
# -------------
# Epoch 129/200
# -------------
# （train）
# -------------
# epoch 129 || Epoch_D_Loss:0.0712 ||Epoch_G_Loss:0.2881
# timer:  0.6229 sec.
# -------------
# Epoch 130/200
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.0634 ||Epoch_G_Loss:0.2839
# timer:  0.6217 sec.
# -------------
# Epoch 131/200
# -------------
# （train）
# -------------
# epoch 131 || Epoch_D_Loss:0.0419 ||Epoch_G_Loss:0.3235
# timer:  0.6238 sec.
# -------------
# Epoch 132/200
# -------------
# （train）
# -------------
# epoch 132 || Epoch_D_Loss:0.0736 ||Epoch_G_Loss:0.2485
# timer:  0.6212 sec.
# -------------
# Epoch 133/200
# -------------
# （train）
# -------------
# epoch 133 || Epoch_D_Loss:0.0572 ||Epoch_G_Loss:0.2857
# timer:  0.6205 sec.
# -------------
# Epoch 134/200
# -------------
# （train）
# -------------
# epoch 134 || Epoch_D_Loss:0.0708 ||Epoch_G_Loss:0.2619
# timer:  0.6207 sec.
# -------------
# Epoch 135/200
# -------------
# （train）
# -------------
# epoch 135 || Epoch_D_Loss:0.0575 ||Epoch_G_Loss:0.2960
# timer:  0.6236 sec.
# -------------
# Epoch 136/200
# -------------
# （train）
# -------------
# epoch 136 || Epoch_D_Loss:0.0574 ||Epoch_G_Loss:0.2501
# timer:  0.6192 sec.
# -------------
# Epoch 137/200
# -------------
# （train）
# -------------
# epoch 137 || Epoch_D_Loss:0.0599 ||Epoch_G_Loss:0.2942
# timer:  0.6201 sec.
# -------------
# Epoch 138/200
# -------------
# （train）
# -------------
# epoch 138 || Epoch_D_Loss:0.0528 ||Epoch_G_Loss:0.3018
# timer:  0.6189 sec.
# -------------
# Epoch 139/200
# -------------
# （train）
# -------------
# epoch 139 || Epoch_D_Loss:0.0526 ||Epoch_G_Loss:0.3157
# timer:  0.6197 sec.
# -------------
# Epoch 140/200
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.0552 ||Epoch_G_Loss:0.3094
# timer:  0.6213 sec.
# -------------
# Epoch 141/200
# -------------
# （train）
# -------------
# epoch 141 || Epoch_D_Loss:0.0686 ||Epoch_G_Loss:0.3165
# timer:  0.6201 sec.
# -------------
# Epoch 142/200
# -------------
# （train）
# -------------
# epoch 142 || Epoch_D_Loss:0.0495 ||Epoch_G_Loss:0.2537
# timer:  0.6197 sec.
# -------------
# Epoch 143/200
# -------------
# （train）
# -------------
# epoch 143 || Epoch_D_Loss:0.0753 ||Epoch_G_Loss:0.3430
# timer:  0.6197 sec.
# -------------
# Epoch 144/200
# -------------
# （train）
# -------------
# epoch 144 || Epoch_D_Loss:0.0466 ||Epoch_G_Loss:0.2781
# timer:  0.6191 sec.
# -------------
# Epoch 145/200
# -------------
# （train）
# -------------
# epoch 145 || Epoch_D_Loss:0.0377 ||Epoch_G_Loss:0.3468
# timer:  0.6176 sec.
# -------------
# Epoch 146/200
# -------------
# （train）
# -------------
# epoch 146 || Epoch_D_Loss:0.0770 ||Epoch_G_Loss:0.3039
# timer:  0.6190 sec.
# -------------
# Epoch 147/200
# -------------
# （train）
# -------------
# epoch 147 || Epoch_D_Loss:0.0273 ||Epoch_G_Loss:0.3528
# timer:  0.6187 sec.
# -------------
# Epoch 148/200
# -------------
# （train）
# -------------
# epoch 148 || Epoch_D_Loss:0.0671 ||Epoch_G_Loss:0.2850
# timer:  0.6190 sec.
# -------------
# Epoch 149/200
# -------------
# （train）
# -------------
# epoch 149 || Epoch_D_Loss:0.0522 ||Epoch_G_Loss:0.3486
# timer:  0.6194 sec.
# -------------
# Epoch 150/200
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.0524 ||Epoch_G_Loss:0.3187
# timer:  0.6186 sec.
# -------------
# Epoch 151/200
# -------------
# （train）
# -------------
# epoch 151 || Epoch_D_Loss:0.0639 ||Epoch_G_Loss:0.3031
# timer:  0.6209 sec.
# -------------
# Epoch 152/200
# -------------
# （train）
# -------------
# epoch 152 || Epoch_D_Loss:0.0470 ||Epoch_G_Loss:0.3335
# timer:  0.6185 sec.
# -------------
# Epoch 153/200
# -------------
# （train）
# -------------
# epoch 153 || Epoch_D_Loss:0.0474 ||Epoch_G_Loss:0.3845
# timer:  0.6209 sec.
# -------------
# Epoch 154/200
# -------------
# （train）
# -------------
# epoch 154 || Epoch_D_Loss:0.0672 ||Epoch_G_Loss:0.3136
# timer:  0.6192 sec.
# -------------
# Epoch 155/200
# -------------
# （train）
# -------------
# epoch 155 || Epoch_D_Loss:0.0281 ||Epoch_G_Loss:0.3302
# timer:  0.6193 sec.
# -------------
# Epoch 156/200
# -------------
# （train）
# -------------
# epoch 156 || Epoch_D_Loss:0.0642 ||Epoch_G_Loss:0.3341
# timer:  0.6203 sec.
# -------------
# Epoch 157/200
# -------------
# （train）
# -------------
# epoch 157 || Epoch_D_Loss:0.0509 ||Epoch_G_Loss:0.3716
# timer:  0.6162 sec.
# -------------
# Epoch 158/200
# -------------
# （train）
# -------------
# epoch 158 || Epoch_D_Loss:0.0402 ||Epoch_G_Loss:0.3192
# timer:  0.6177 sec.
# -------------
# Epoch 159/200
# -------------
# （train）
# -------------
# epoch 159 || Epoch_D_Loss:0.0565 ||Epoch_G_Loss:0.3446
# timer:  0.6229 sec.
# -------------
# Epoch 160/200
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.0398 ||Epoch_G_Loss:0.3662
# timer:  0.6233 sec.
# -------------
# Epoch 161/200
# -------------
# （train）
# -------------
# epoch 161 || Epoch_D_Loss:0.0572 ||Epoch_G_Loss:0.3313
# timer:  0.6196 sec.
# -------------
# Epoch 162/200
# -------------
# （train）
# -------------
# epoch 162 || Epoch_D_Loss:0.0394 ||Epoch_G_Loss:0.3872
# timer:  0.6213 sec.
# -------------
# Epoch 163/200
# -------------
# （train）
# -------------
# epoch 163 || Epoch_D_Loss:0.0635 ||Epoch_G_Loss:0.2890
# timer:  0.6247 sec.
# -------------
# Epoch 164/200
# -------------
# （train）
# -------------
# epoch 164 || Epoch_D_Loss:0.0474 ||Epoch_G_Loss:0.3890
# timer:  0.6180 sec.
# -------------
# Epoch 165/200
# -------------
# （train）
# -------------
# epoch 165 || Epoch_D_Loss:0.0415 ||Epoch_G_Loss:0.3263
# timer:  0.6235 sec.
# -------------
# Epoch 166/200
# -------------
# （train）
# -------------
# epoch 166 || Epoch_D_Loss:0.0445 ||Epoch_G_Loss:0.3665
# timer:  0.6215 sec.
# -------------
# Epoch 167/200
# -------------
# （train）
# -------------
# epoch 167 || Epoch_D_Loss:0.0580 ||Epoch_G_Loss:0.3604
# timer:  0.6242 sec.
# -------------
# Epoch 168/200
# -------------
# （train）
# -------------
# epoch 168 || Epoch_D_Loss:0.0310 ||Epoch_G_Loss:0.3859
# timer:  0.6219 sec.
# -------------
# Epoch 169/200
# -------------
# （train）
# -------------
# epoch 169 || Epoch_D_Loss:0.0681 ||Epoch_G_Loss:0.3784
# timer:  0.6211 sec.
# -------------
# Epoch 170/200
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.0346 ||Epoch_G_Loss:0.3431
# timer:  0.6210 sec.
# -------------
# Epoch 171/200
# -------------
# （train）
# -------------
# epoch 171 || Epoch_D_Loss:0.0433 ||Epoch_G_Loss:0.3898
# timer:  0.6235 sec.
# -------------
# Epoch 172/200
# -------------
# （train）
# -------------
# epoch 172 || Epoch_D_Loss:0.0434 ||Epoch_G_Loss:0.4014
# timer:  0.6232 sec.
# -------------
# Epoch 173/200
# -------------
# （train）
# -------------
# epoch 173 || Epoch_D_Loss:0.0522 ||Epoch_G_Loss:0.3549
# timer:  0.6307 sec.
# -------------
# Epoch 174/200
# -------------
# （train）
# -------------
# epoch 174 || Epoch_D_Loss:0.0386 ||Epoch_G_Loss:0.3854
# timer:  0.6327 sec.
# -------------
# Epoch 175/200
# -------------
# （train）
# -------------
# epoch 175 || Epoch_D_Loss:0.0375 ||Epoch_G_Loss:0.3903
# timer:  0.6567 sec.
# -------------
# Epoch 176/200
# -------------
# （train）
# -------------
# epoch 176 || Epoch_D_Loss:0.0468 ||Epoch_G_Loss:0.4040
# timer:  0.6277 sec.
# -------------
# Epoch 177/200
# -------------
# （train）
# -------------
# epoch 177 || Epoch_D_Loss:0.0333 ||Epoch_G_Loss:0.3506
# timer:  0.6244 sec.
# -------------
# Epoch 178/200
# -------------
# （train）
# -------------
# epoch 178 || Epoch_D_Loss:0.0420 ||Epoch_G_Loss:0.4152
# timer:  0.6229 sec.
# -------------
# Epoch 179/200
# -------------
# （train）
# -------------
# epoch 179 || Epoch_D_Loss:0.0244 ||Epoch_G_Loss:0.4275
# timer:  0.6196 sec.
# -------------
# Epoch 180/200
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.0476 ||Epoch_G_Loss:0.3795
# timer:  0.6280 sec.
# -------------
# Epoch 181/200
# -------------
# （train）
# -------------
# epoch 181 || Epoch_D_Loss:0.0271 ||Epoch_G_Loss:0.4402
# timer:  0.6204 sec.
# -------------
# Epoch 182/200
# -------------
# （train）
# -------------
# epoch 182 || Epoch_D_Loss:0.0311 ||Epoch_G_Loss:0.4827
# timer:  0.6209 sec.
# -------------
# Epoch 183/200
# -------------
# （train）
# -------------
# epoch 183 || Epoch_D_Loss:0.0534 ||Epoch_G_Loss:0.3137
# timer:  0.6252 sec.
# -------------
# Epoch 184/200
# -------------
# （train）
# -------------
# epoch 184 || Epoch_D_Loss:0.0515 ||Epoch_G_Loss:0.4097
# timer:  0.6164 sec.
# -------------
# Epoch 185/200
# -------------
# （train）
# -------------
# epoch 185 || Epoch_D_Loss:0.0192 ||Epoch_G_Loss:0.4146
# timer:  0.6210 sec.
# -------------
# Epoch 186/200
# -------------
# （train）
# -------------
# epoch 186 || Epoch_D_Loss:0.0452 ||Epoch_G_Loss:0.4105
# timer:  0.6327 sec.
# -------------
# Epoch 187/200
# -------------
# （train）
# -------------
# epoch 187 || Epoch_D_Loss:0.0237 ||Epoch_G_Loss:0.4839
# timer:  0.6305 sec.
# -------------
# Epoch 188/200
# -------------
# （train）
# -------------
# epoch 188 || Epoch_D_Loss:0.0325 ||Epoch_G_Loss:0.3876
# timer:  0.6243 sec.
# -------------
# Epoch 189/200
# -------------
# （train）
# -------------
# epoch 189 || Epoch_D_Loss:0.0315 ||Epoch_G_Loss:0.5461
# timer:  0.6249 sec.
# -------------
# Epoch 190/200
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.0751 ||Epoch_G_Loss:0.2836
# timer:  0.6249 sec.
# -------------
# Epoch 191/200
# -------------
# （train）
# -------------
# epoch 191 || Epoch_D_Loss:0.0194 ||Epoch_G_Loss:0.4210
# timer:  0.6271 sec.
# -------------
# Epoch 192/200
# -------------
# （train）
# -------------
# epoch 192 || Epoch_D_Loss:0.0383 ||Epoch_G_Loss:0.4648
# timer:  0.6183 sec.
# -------------
# Epoch 193/200
# -------------
# （train）
# -------------
# epoch 193 || Epoch_D_Loss:0.0464 ||Epoch_G_Loss:0.4067
# timer:  0.6201 sec.
# -------------
# Epoch 194/200
# -------------
# （train）
# -------------
# epoch 194 || Epoch_D_Loss:0.0144 ||Epoch_G_Loss:0.4988
# timer:  0.6183 sec.
# -------------
# Epoch 195/200
# -------------
# （train）
# -------------
# epoch 195 || Epoch_D_Loss:0.0491 ||Epoch_G_Loss:0.4283
# timer:  0.6179 sec.
# -------------
# Epoch 196/200
# -------------
# （train）
# -------------
# epoch 196 || Epoch_D_Loss:0.0141 ||Epoch_G_Loss:0.4963
# timer:  0.6174 sec.
# -------------
# Epoch 197/200
# -------------
# （train）
# -------------
# epoch 197 || Epoch_D_Loss:0.0528 ||Epoch_G_Loss:0.5192
# timer:  0.6208 sec.
# -------------
# Epoch 198/200
# -------------
# （train）
# -------------
# epoch 198 || Epoch_D_Loss:0.0273 ||Epoch_G_Loss:0.4046
# timer:  0.6193 sec.
# -------------
# Epoch 199/200
# -------------
# （train）
# -------------
# epoch 199 || Epoch_D_Loss:0.0248 ||Epoch_G_Loss:0.4797
# timer:  0.6209 sec.

# %%
# 生成画像と訓練データを可視化する
# 本セルは良い感じの画像が生成されるまで、何度も実行し直しています。

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)

# 画像生成
G_update.eval()
fake_images = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')
