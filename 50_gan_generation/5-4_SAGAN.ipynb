# %% [markdown]
# # 5.4 SAGANの作成
#
# - 本ファイルでは、Self-Attention GANのネットワークを実装と学習をします。

# %% [markdown]
# # 5.4 学習目標
#
# 1.	SAGANを実装できるようになる

# %% [markdown]
# # 事前準備
# 書籍の指示に従い、本章で使用するデータを用意します

# %%
# パッケージのimport
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # Self-Attentionモジュールの実装

# %%
class Self_Attention(nn.Module):
    """ Self-AttentionのLayer"""

    def __init__(self, in_dim):
        super(Self_Attention, self).__init__()

        # 1×1の畳み込み層によるpointwise convolutionを用意
        self.query_conv = nn.Conv2d(
            in_channels=in_dim, out_channels=in_dim//8, kernel_size=1)
        self.key_conv = nn.Conv2d(
            in_channels=in_dim, out_channels=in_dim//8, kernel_size=1)
        self.value_conv = nn.Conv2d(
            in_channels=in_dim, out_channels=in_dim, kernel_size=1)

        # Attention Map作成時の規格化のソフトマックス
        self.softmax = nn.Softmax(dim=-2)

        # 元の入力xとSelf-Attention Mapであるoを足し算するときの係数
        # output = x +gamma*o
        # 最初はgamma=0で、学習させていく
        self.gamma = nn.Parameter(torch.zeros(1))

    def forward(self, x):

        # 入力変数
        X = x

        # 畳み込みをしてから、サイズを変形する。 B,C',W,H→B,C',N へ
        proj_query = self.query_conv(X).view(
            X.shape[0], -1, X.shape[2]*X.shape[3])  # サイズ：B,C',N
        proj_query = proj_query.permute(0, 2, 1)  # 転置操作
        proj_key = self.key_conv(X).view(
            X.shape[0], -1, X.shape[2]*X.shape[3])  # サイズ：B,C',N

        # かけ算
        S = torch.bmm(proj_query, proj_key)  # bmmはバッチごとの行列かけ算です

        # 規格化
        attention_map_T = self.softmax(S)  # 行i方向の和を1にするソフトマックス関数
        attention_map = attention_map_T.permute(0, 2, 1)  # 転置をとる

        # Self-Attention Mapを計算する
        proj_value = self.value_conv(X).view(
            X.shape[0], -1, X.shape[2]*X.shape[3])  # サイズ：B,C,N
        o = torch.bmm(proj_value, attention_map.permute(
            0, 2, 1))  # Attention Mapは転置してかけ算

        # Self-Attention MapであるoのテンソルサイズをXにそろえて、出力にする
        o = o.view(X.shape[0], X.shape[1], X.shape[2], X.shape[3])
        out = x+self.gamma*o

        return out, attention_map

# %% [markdown]
# # Generatorの実装

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.ConvTranspose2d(z_dim, image_size * 8,
                                                      kernel_size=4, stride=1)),
            nn.BatchNorm2d(image_size * 8),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size * 8, image_size * 4,
                                                      kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size * 4),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size * 4, image_size * 2,
                                                      kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size * 2),
            nn.ReLU(inplace=True))

        # Self-Attentin層を追加
        self.self_attntion1 = Self_Attention(in_dim=image_size * 2)

        self.layer4 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size * 2, image_size,
                                                      kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True))

        # Self-Attentin層を追加
        self.self_attntion2 = Self_Attention(in_dim=image_size)

        self.last = nn.Sequential(
            nn.ConvTranspose2d(image_size, 1, kernel_size=4,
                               stride=2, padding=1),
            nn.Tanh())
        # 注意：白黒画像なので出力チャネルは1つだけ


    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)
        out = self.layer3(out)
        out, attention_map1 = self.self_attntion1(out)
        out = self.layer4(out)
        out, attention_map2 = self.self_attntion2(out)
        out = self.last(out)

        return out, attention_map1, attention_map2

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20, image_size=64)

# 入力する乱数
input_z = torch.randn(1, 20)

# テンソルサイズを(1, 20, 1, 1)に変形
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

# 偽画像を出力
fake_images, attention_map1, attention_map2 = G(input_z)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()
# Out:
# findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # Discriminatorの実装

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Discriminator, self).__init__()

        self.layer1 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.Conv2d(1, image_size, kernel_size=4,
                                             stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.Conv2d(image_size, image_size*2, kernel_size=4,
                                             stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.Conv2d(image_size*2, image_size*4, kernel_size=4,
                                             stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))

        # Self-Attentin層を追加
        self.self_attntion1 = Self_Attention(in_dim=image_size*4)

        self.layer4 = nn.Sequential(
            # Spectral Normalizationを追加
            nn.utils.spectral_norm(nn.Conv2d(image_size*4, image_size*8, kernel_size=4,
                                             stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))

        # Self-Attentin層を追加
        self.self_attntion2 = Self_Attention(in_dim=image_size*8)

        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out, attention_map1 = self.self_attntion1(out)
        out = self.layer4(out)
        out, attention_map2 = self.self_attntion2(out)
        out = self.last(out)

        return out, attention_map1, attention_map2

# %%
# 動作確認
D = Discriminator(z_dim=20, image_size=64)

# 偽画像を生成
input_z = torch.randn(1, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images, _, _ = G(input_z)

# 偽画像をDに入力
d_out, attention_map1, attention_map2 = D(fake_images)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[[[0.5001]]]], grad_fn=<SigmoidBackward>)

# %% [markdown]
# # DataLoaderの作成

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 64, 64])

# %% [markdown]
# # 学習させる

# %%
# モデルを学習させる関数を作成


def train_model(G, D, dataloader, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    # 誤差関数を定義 → hinge version of the adversarial lossに変更
    # criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イテレーションカウンタをセット
    iteration = 1
    logs = []

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('（train）')

        # データローダーからminibatchずつ取り出すループ
        for imges in dataloader:

            # --------------------
            # 1. Discriminatorの学習
            # --------------------
            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            if imges.size()[0] == 1:
                continue

            # GPUが使えるならGPUにデータを送る
            imges = imges.to(device)

            # 正解ラベルと偽ラベルを作成
            # epochの最後のイテレーションはミニバッチの数が少なくなる
            mini_batch_size = imges.size()[0]
            #label_real = torch.full((mini_batch_size,), 1).to(device)
            #label_fake = torch.full((mini_batch_size,), 0).to(device)

            # 真の画像を判定
            d_out_real, _, _ = D(imges)

            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images, _, _ = G(input_z)
            d_out_fake, _, _ = D(fake_images)

            # 誤差を計算→hinge version of the adversarial lossに変更
            # d_loss_real = criterion(d_out_real.view(-1), label_real)
            # d_loss_fake = criterion(d_out_fake.view(-1), label_fake)

            d_loss_real = torch.nn.ReLU()(1.0 - d_out_real).mean()
            # 誤差　d_out_realが1以上で誤差0になる。d_out_real>1で、
            # 1.0 - d_out_realが負の場合ReLUで0にする

            d_loss_fake = torch.nn.ReLU()(1.0 + d_out_fake).mean()
            # 誤差　d_out_fakeが-1以下なら誤差0になる。d_out_fake<-1で、
            # 1.0 + d_out_realが負の場合ReLUで0にする

            d_loss = d_loss_real + d_loss_fake

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()

            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generatorの学習
            # --------------------
            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images, _, _ = G(input_z)
            d_out_fake, _, _ = D(fake_images)

            # 誤差を計算→hinge version of the adversarial lossに変更
            #g_loss = criterion(d_out_fake.view(-1), label_real)
            g_loss = - d_out_fake.mean()

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    # print("総イテレーション回数:", iteration)

    return G, D

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # Conv2dとConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


# 初期化の実施
G.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
# 学習・検証を実行する
# 15分ほどかかる
num_epochs = 300
G_update, D_update = train_model(
    G, D, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/300
# -------------
# （train）
# -------------
# epoch 0 || Epoch_D_Loss:0.1507 ||Epoch_G_Loss:0.0789
# timer:  4.3560 sec.
# -------------
# Epoch 1/300
# -------------
# （train）
# -------------
# epoch 1 || Epoch_D_Loss:0.1237 ||Epoch_G_Loss:0.0678
# timer:  1.0000 sec.
# -------------
# Epoch 2/300
# -------------
# （train）
# -------------
# epoch 2 || Epoch_D_Loss:0.1190 ||Epoch_G_Loss:0.0096
# timer:  0.9940 sec.
# -------------
# Epoch 3/300
# -------------
# （train）
# -------------
# epoch 3 || Epoch_D_Loss:0.1304 ||Epoch_G_Loss:0.0197
# timer:  0.9919 sec.
# -------------
# Epoch 4/300
# -------------
# （train）
# -------------
# epoch 4 || Epoch_D_Loss:0.0680 ||Epoch_G_Loss:0.0675
# timer:  0.9908 sec.
# -------------
# Epoch 5/300
# -------------
# （train）
# -------------
# epoch 5 || Epoch_D_Loss:0.0959 ||Epoch_G_Loss:0.0537
# timer:  0.9925 sec.
# -------------
# Epoch 6/300
# -------------
# （train）
# -------------
# epoch 6 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:0.1315
# timer:  1.0065 sec.
# -------------
# Epoch 7/300
# -------------
# （train）
# -------------
# epoch 7 || Epoch_D_Loss:0.0001 ||Epoch_G_Loss:0.1397
# timer:  0.9972 sec.
# -------------
# Epoch 8/300
# -------------
# （train）
# -------------
# epoch 8 || Epoch_D_Loss:0.0004 ||Epoch_G_Loss:0.1676
# timer:  0.9939 sec.
# -------------
# Epoch 9/300
# -------------
# （train）
# -------------
# epoch 9 || Epoch_D_Loss:0.0721 ||Epoch_G_Loss:0.2289
# timer:  0.9932 sec.
# -------------
# Epoch 10/300
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.0049 ||Epoch_G_Loss:0.1939
# timer:  0.9972 sec.
# -------------
# Epoch 11/300
# -------------
# （train）
# -------------
# epoch 11 || Epoch_D_Loss:0.0688 ||Epoch_G_Loss:0.1745
# timer:  0.9947 sec.
# -------------
# Epoch 12/300
# -------------
# （train）
# -------------
# epoch 12 || Epoch_D_Loss:0.0995 ||Epoch_G_Loss:0.1115
# timer:  0.9990 sec.
# -------------
# Epoch 13/300
# -------------
# （train）
# -------------
# epoch 13 || Epoch_D_Loss:0.0692 ||Epoch_G_Loss:0.1393
# timer:  0.9922 sec.
# -------------
# Epoch 14/300
# -------------
# （train）
# -------------
# epoch 14 || Epoch_D_Loss:0.0793 ||Epoch_G_Loss:0.0651
# timer:  0.9932 sec.
# -------------
# Epoch 15/300
# -------------
# （train）
# -------------
# epoch 15 || Epoch_D_Loss:0.0781 ||Epoch_G_Loss:0.0938
# timer:  1.0150 sec.
# -------------
# Epoch 16/300
# -------------
# （train）
# -------------
# epoch 16 || Epoch_D_Loss:0.0531 ||Epoch_G_Loss:0.0846
# timer:  1.0044 sec.
# -------------
# Epoch 17/300
# -------------
# （train）
# -------------
# epoch 17 || Epoch_D_Loss:0.0686 ||Epoch_G_Loss:0.1058
# timer:  1.0176 sec.
# -------------
# Epoch 18/300
# -------------
# （train）
# -------------
# epoch 18 || Epoch_D_Loss:0.0473 ||Epoch_G_Loss:0.1239
# timer:  1.0098 sec.
# -------------
# Epoch 19/300
# -------------
# （train）
# -------------
# epoch 19 || Epoch_D_Loss:0.0102 ||Epoch_G_Loss:0.1644
# timer:  1.0535 sec.
# -------------
# Epoch 20/300
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.1081 ||Epoch_G_Loss:0.0475
# timer:  1.0574 sec.
# -------------
# Epoch 21/300
# -------------
# （train）
# -------------
# epoch 21 || Epoch_D_Loss:0.1050 ||Epoch_G_Loss:0.0859
# timer:  1.0148 sec.
# -------------
# Epoch 22/300
# -------------
# （train）
# -------------
# epoch 22 || Epoch_D_Loss:0.0927 ||Epoch_G_Loss:0.0692
# timer:  1.0130 sec.
# -------------
# Epoch 23/300
# -------------
# （train）
# -------------
# epoch 23 || Epoch_D_Loss:0.1104 ||Epoch_G_Loss:0.0711
# timer:  1.0021 sec.
# -------------
# Epoch 24/300
# -------------
# （train）
# -------------
# epoch 24 || Epoch_D_Loss:0.1008 ||Epoch_G_Loss:0.0651
# timer:  1.0049 sec.
# -------------
# Epoch 25/300
# -------------
# （train）
# -------------
# epoch 25 || Epoch_D_Loss:0.1228 ||Epoch_G_Loss:0.0473
# timer:  1.0228 sec.
# -------------
# Epoch 26/300
# -------------
# （train）
# -------------
# epoch 26 || Epoch_D_Loss:0.1247 ||Epoch_G_Loss:0.0674
# timer:  1.0105 sec.
# -------------
# Epoch 27/300
# -------------
# （train）
# -------------
# epoch 27 || Epoch_D_Loss:0.1168 ||Epoch_G_Loss:0.0185
# timer:  1.0137 sec.
# -------------
# Epoch 28/300
# -------------
# （train）
# -------------
# epoch 28 || Epoch_D_Loss:0.1388 ||Epoch_G_Loss:0.0527
# timer:  1.0143 sec.
# -------------
# Epoch 29/300
# -------------
# （train）
# -------------
# epoch 29 || Epoch_D_Loss:0.1242 ||Epoch_G_Loss:0.0804
# timer:  1.0078 sec.
# -------------
# Epoch 30/300
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.1490 ||Epoch_G_Loss:0.0441
# timer:  1.0151 sec.
# -------------
# Epoch 31/300
# -------------
# （train）
# -------------
# epoch 31 || Epoch_D_Loss:0.1784 ||Epoch_G_Loss:0.0291
# timer:  1.0120 sec.
# -------------
# Epoch 32/300
# -------------
# （train）
# -------------
# epoch 32 || Epoch_D_Loss:0.1527 ||Epoch_G_Loss:0.0586
# timer:  1.0122 sec.
# -------------
# Epoch 33/300
# -------------
# （train）
# -------------
# epoch 33 || Epoch_D_Loss:0.1331 ||Epoch_G_Loss:0.0207
# timer:  1.0127 sec.
# -------------
# Epoch 34/300
# -------------
# （train）
# -------------
# epoch 34 || Epoch_D_Loss:0.1911 ||Epoch_G_Loss:0.0341
# timer:  1.0161 sec.
# -------------
# Epoch 35/300
# -------------
# （train）
# -------------
# epoch 35 || Epoch_D_Loss:0.1553 ||Epoch_G_Loss:0.0526
# timer:  1.0099 sec.
# -------------
# Epoch 36/300
# -------------
# （train）
# -------------
# epoch 36 || Epoch_D_Loss:0.1751 ||Epoch_G_Loss:0.0411
# timer:  1.0185 sec.
# -------------
# Epoch 37/300
# -------------
# （train）
# -------------
# epoch 37 || Epoch_D_Loss:0.1934 ||Epoch_G_Loss:0.0180
# timer:  1.0125 sec.
# -------------
# Epoch 38/300
# -------------
# （train）
# -------------
# epoch 38 || Epoch_D_Loss:0.1734 ||Epoch_G_Loss:0.0493
# timer:  1.0095 sec.
# -------------
# Epoch 39/300
# -------------
# （train）
# -------------
# epoch 39 || Epoch_D_Loss:0.1627 ||Epoch_G_Loss:0.0547
# timer:  1.0105 sec.
# -------------
# Epoch 40/300
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.2136 ||Epoch_G_Loss:0.0198
# timer:  1.0099 sec.
# -------------
# Epoch 41/300
# -------------
# （train）
# -------------
# epoch 41 || Epoch_D_Loss:0.1742 ||Epoch_G_Loss:0.0589
# timer:  1.0100 sec.
# -------------
# Epoch 42/300
# -------------
# （train）
# -------------
# epoch 42 || Epoch_D_Loss:0.1788 ||Epoch_G_Loss:0.0434
# timer:  1.0122 sec.
# -------------
# Epoch 43/300
# -------------
# （train）
# -------------
# epoch 43 || Epoch_D_Loss:0.1918 ||Epoch_G_Loss:0.0346
# timer:  1.0139 sec.
# -------------
# Epoch 44/300
# -------------
# （train）
# -------------
# epoch 44 || Epoch_D_Loss:0.1759 ||Epoch_G_Loss:0.0512
# timer:  1.0100 sec.
# -------------
# Epoch 45/300
# -------------
# （train）
# -------------
# epoch 45 || Epoch_D_Loss:0.1951 ||Epoch_G_Loss:0.0678
# timer:  1.0138 sec.
# -------------
# Epoch 46/300
# -------------
# （train）
# -------------
# epoch 46 || Epoch_D_Loss:0.2089 ||Epoch_G_Loss:0.0530
# timer:  1.0139 sec.
# -------------
# Epoch 47/300
# -------------
# （train）
# -------------
# epoch 47 || Epoch_D_Loss:0.1872 ||Epoch_G_Loss:0.0603
# timer:  1.0166 sec.
# -------------
# Epoch 48/300
# -------------
# （train）
# -------------
# epoch 48 || Epoch_D_Loss:0.2008 ||Epoch_G_Loss:-0.0033
# timer:  1.0102 sec.
# -------------
# Epoch 49/300
# -------------
# （train）
# -------------
# epoch 49 || Epoch_D_Loss:0.1853 ||Epoch_G_Loss:0.0313
# timer:  1.0144 sec.
# -------------
# Epoch 50/300
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.2104 ||Epoch_G_Loss:0.0086
# timer:  1.0111 sec.
# -------------
# Epoch 51/300
# -------------
# （train）
# -------------
# epoch 51 || Epoch_D_Loss:0.1808 ||Epoch_G_Loss:0.0398
# timer:  1.0138 sec.
# -------------
# Epoch 52/300
# -------------
# （train）
# -------------
# epoch 52 || Epoch_D_Loss:0.2088 ||Epoch_G_Loss:0.0372
# timer:  1.0180 sec.
# -------------
# Epoch 53/300
# -------------
# （train）
# -------------
# epoch 53 || Epoch_D_Loss:0.1794 ||Epoch_G_Loss:0.0485
# timer:  1.0167 sec.
# -------------
# Epoch 54/300
# -------------
# （train）
# -------------
# epoch 54 || Epoch_D_Loss:0.1759 ||Epoch_G_Loss:0.0137
# timer:  1.0197 sec.
# -------------
# Epoch 55/300
# -------------
# （train）
# -------------
# epoch 55 || Epoch_D_Loss:0.2005 ||Epoch_G_Loss:0.0517
# timer:  1.0183 sec.
# -------------
# Epoch 56/300
# -------------
# （train）
# -------------
# epoch 56 || Epoch_D_Loss:0.1898 ||Epoch_G_Loss:0.0509
# timer:  1.0163 sec.
# -------------
# Epoch 57/300
# -------------
# （train）
# -------------
# epoch 57 || Epoch_D_Loss:0.1788 ||Epoch_G_Loss:0.0500
# timer:  1.0137 sec.
# -------------
# Epoch 58/300
# -------------
# （train）
# -------------
# epoch 58 || Epoch_D_Loss:0.1986 ||Epoch_G_Loss:0.0023
# timer:  1.0166 sec.
# -------------
# Epoch 59/300
# -------------
# （train）
# -------------
# epoch 59 || Epoch_D_Loss:0.1855 ||Epoch_G_Loss:0.0270
# timer:  1.0165 sec.
# -------------
# Epoch 60/300
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.1891 ||Epoch_G_Loss:0.0321
# timer:  1.0184 sec.
# -------------
# Epoch 61/300
# -------------
# （train）
# -------------
# epoch 61 || Epoch_D_Loss:0.1719 ||Epoch_G_Loss:0.0509
# timer:  1.0177 sec.
# -------------
# Epoch 62/300
# -------------
# （train）
# -------------
# epoch 62 || Epoch_D_Loss:0.1956 ||Epoch_G_Loss:0.0424
# timer:  1.0195 sec.
# -------------
# Epoch 63/300
# -------------
# （train）
# -------------
# epoch 63 || Epoch_D_Loss:0.1838 ||Epoch_G_Loss:0.0351
# timer:  1.0223 sec.
# -------------
# Epoch 64/300
# -------------
# （train）
# -------------
# epoch 64 || Epoch_D_Loss:0.1657 ||Epoch_G_Loss:0.0510
# timer:  1.0189 sec.
# -------------
# Epoch 65/300
# -------------
# （train）
# -------------
# epoch 65 || Epoch_D_Loss:0.1886 ||Epoch_G_Loss:0.0174
# timer:  1.0197 sec.
# -------------
# Epoch 66/300
# -------------
# （train）
# -------------
# epoch 66 || Epoch_D_Loss:0.1757 ||Epoch_G_Loss:0.0351
# timer:  1.0246 sec.
# -------------
# Epoch 67/300
# -------------
# （train）
# -------------
# epoch 67 || Epoch_D_Loss:0.1700 ||Epoch_G_Loss:0.0430
# timer:  1.0197 sec.
# -------------
# Epoch 68/300
# -------------
# （train）
# -------------
# epoch 68 || Epoch_D_Loss:0.1971 ||Epoch_G_Loss:0.0698
# timer:  1.0213 sec.
# -------------
# Epoch 69/300
# -------------
# （train）
# -------------
# epoch 69 || Epoch_D_Loss:0.1773 ||Epoch_G_Loss:0.0343
# timer:  1.0236 sec.
# -------------
# Epoch 70/300
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.1714 ||Epoch_G_Loss:0.0497
# timer:  1.0239 sec.
# -------------
# Epoch 71/300
# -------------
# （train）
# -------------
# epoch 71 || Epoch_D_Loss:0.1759 ||Epoch_G_Loss:0.0421
# timer:  1.0242 sec.
# -------------
# Epoch 72/300
# -------------
# （train）
# -------------
# epoch 72 || Epoch_D_Loss:0.1927 ||Epoch_G_Loss:0.0176
# timer:  1.0249 sec.
# -------------
# Epoch 73/300
# -------------
# （train）
# -------------
# epoch 73 || Epoch_D_Loss:0.1843 ||Epoch_G_Loss:0.0323
# timer:  1.0238 sec.
# -------------
# Epoch 74/300
# -------------
# （train）
# -------------
# epoch 74 || Epoch_D_Loss:0.1842 ||Epoch_G_Loss:0.0295
# timer:  1.0236 sec.
# -------------
# Epoch 75/300
# -------------
# （train）
# -------------
# epoch 75 || Epoch_D_Loss:0.1733 ||Epoch_G_Loss:0.0333
# timer:  1.0186 sec.
# -------------
# Epoch 76/300
# -------------
# （train）
# -------------
# epoch 76 || Epoch_D_Loss:0.1703 ||Epoch_G_Loss:0.0682
# timer:  1.0255 sec.
# -------------
# Epoch 77/300
# -------------
# （train）
# -------------
# epoch 77 || Epoch_D_Loss:0.1935 ||Epoch_G_Loss:0.0462
# timer:  1.0316 sec.
# -------------
# Epoch 78/300
# -------------
# （train）
# -------------
# epoch 78 || Epoch_D_Loss:0.1849 ||Epoch_G_Loss:0.0181
# timer:  1.0292 sec.
# -------------
# Epoch 79/300
# -------------
# （train）
# -------------
# epoch 79 || Epoch_D_Loss:0.1821 ||Epoch_G_Loss:0.0312
# timer:  1.0275 sec.
# -------------
# Epoch 80/300
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.1955 ||Epoch_G_Loss:0.0406
# timer:  1.0261 sec.
# -------------
# Epoch 81/300
# -------------
# （train）
# -------------
# epoch 81 || Epoch_D_Loss:0.1862 ||Epoch_G_Loss:0.0151
# timer:  1.0257 sec.
# -------------
# Epoch 82/300
# -------------
# （train）
# -------------
# epoch 82 || Epoch_D_Loss:0.1765 ||Epoch_G_Loss:0.0546
# timer:  1.0243 sec.
# -------------
# Epoch 83/300
# -------------
# （train）
# -------------
# epoch 83 || Epoch_D_Loss:0.2011 ||Epoch_G_Loss:-0.0014
# timer:  1.0240 sec.
# -------------
# Epoch 84/300
# -------------
# （train）
# -------------
# epoch 84 || Epoch_D_Loss:0.1682 ||Epoch_G_Loss:0.0361
# timer:  1.0285 sec.
# -------------
# Epoch 85/300
# -------------
# （train）
# -------------
# epoch 85 || Epoch_D_Loss:0.1889 ||Epoch_G_Loss:0.0410
# timer:  1.0274 sec.
# -------------
# Epoch 86/300
# -------------
# （train）
# -------------
# epoch 86 || Epoch_D_Loss:0.1906 ||Epoch_G_Loss:0.0184
# timer:  1.0265 sec.
# -------------
# Epoch 87/300
# -------------
# （train）
# -------------
# epoch 87 || Epoch_D_Loss:0.1934 ||Epoch_G_Loss:0.0158
# timer:  1.0781 sec.
# -------------
# Epoch 88/300
# -------------
# （train）
# -------------
# epoch 88 || Epoch_D_Loss:0.1654 ||Epoch_G_Loss:0.0477
# timer:  1.0844 sec.
# -------------
# Epoch 89/300
# -------------
# （train）
# -------------
# epoch 89 || Epoch_D_Loss:0.2009 ||Epoch_G_Loss:0.0364
# timer:  1.0958 sec.
# -------------
# Epoch 90/300
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.1760 ||Epoch_G_Loss:0.0356
# timer:  1.0763 sec.
# -------------
# Epoch 91/300
# -------------
# （train）
# -------------
# epoch 91 || Epoch_D_Loss:0.1919 ||Epoch_G_Loss:0.0296
# timer:  1.0381 sec.
# -------------
# Epoch 92/300
# -------------
# （train）
# -------------
# epoch 92 || Epoch_D_Loss:0.1683 ||Epoch_G_Loss:0.0565
# timer:  1.0287 sec.
# -------------
# Epoch 93/300
# -------------
# （train）
# -------------
# epoch 93 || Epoch_D_Loss:0.1887 ||Epoch_G_Loss:-0.0117
# timer:  1.0312 sec.
# -------------
# Epoch 94/300
# -------------
# （train）
# -------------
# epoch 94 || Epoch_D_Loss:0.1884 ||Epoch_G_Loss:0.0226
# timer:  1.0283 sec.
# -------------
# Epoch 95/300
# -------------
# （train）
# -------------
# epoch 95 || Epoch_D_Loss:0.1750 ||Epoch_G_Loss:0.0499
# timer:  1.0230 sec.
# -------------
# Epoch 96/300
# -------------
# （train）
# -------------
# epoch 96 || Epoch_D_Loss:0.2071 ||Epoch_G_Loss:0.0199
# timer:  1.0258 sec.
# -------------
# Epoch 97/300
# -------------
# （train）
# -------------
# epoch 97 || Epoch_D_Loss:0.1785 ||Epoch_G_Loss:0.0400
# timer:  1.0243 sec.
# -------------
# Epoch 98/300
# -------------
# （train）
# -------------
# epoch 98 || Epoch_D_Loss:0.1850 ||Epoch_G_Loss:0.0315
# timer:  1.0301 sec.
# -------------
# Epoch 99/300
# -------------
# （train）
# -------------
# epoch 99 || Epoch_D_Loss:0.1768 ||Epoch_G_Loss:0.0427
# timer:  1.0405 sec.
# -------------
# Epoch 100/300
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.1795 ||Epoch_G_Loss:0.0443
# timer:  1.0498 sec.
# -------------
# Epoch 101/300
# -------------
# （train）
# -------------
# epoch 101 || Epoch_D_Loss:0.1776 ||Epoch_G_Loss:0.0313
# timer:  1.0245 sec.
# -------------
# Epoch 102/300
# -------------
# （train）
# -------------
# epoch 102 || Epoch_D_Loss:0.1858 ||Epoch_G_Loss:0.0290
# timer:  1.0199 sec.
# -------------
# Epoch 103/300
# -------------
# （train）
# -------------
# epoch 103 || Epoch_D_Loss:0.1897 ||Epoch_G_Loss:0.0157
# timer:  1.0241 sec.
# -------------
# Epoch 104/300
# -------------
# （train）
# -------------
# epoch 104 || Epoch_D_Loss:0.1759 ||Epoch_G_Loss:0.0235
# timer:  1.1119 sec.
# -------------
# Epoch 105/300
# -------------
# （train）
# -------------
# epoch 105 || Epoch_D_Loss:0.1790 ||Epoch_G_Loss:0.0348
# timer:  1.0738 sec.
# -------------
# Epoch 106/300
# -------------
# （train）
# -------------
# epoch 106 || Epoch_D_Loss:0.1808 ||Epoch_G_Loss:0.0326
# timer:  1.0422 sec.
# -------------
# Epoch 107/300
# -------------
# （train）
# -------------
# epoch 107 || Epoch_D_Loss:0.1815 ||Epoch_G_Loss:0.0080
# timer:  1.0312 sec.
# -------------
# Epoch 108/300
# -------------
# （train）
# -------------
# epoch 108 || Epoch_D_Loss:0.1847 ||Epoch_G_Loss:0.0329
# timer:  1.0249 sec.
# -------------
# Epoch 109/300
# -------------
# （train）
# -------------
# epoch 109 || Epoch_D_Loss:0.1849 ||Epoch_G_Loss:0.0337
# timer:  1.0251 sec.
# -------------
# Epoch 110/300
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.1618 ||Epoch_G_Loss:0.0628
# timer:  1.0260 sec.
# -------------
# Epoch 111/300
# -------------
# （train）
# -------------
# epoch 111 || Epoch_D_Loss:0.2066 ||Epoch_G_Loss:0.0545
# timer:  1.0224 sec.
# -------------
# Epoch 112/300
# -------------
# （train）
# -------------
# epoch 112 || Epoch_D_Loss:0.1763 ||Epoch_G_Loss:0.0435
# timer:  1.0719 sec.
# -------------
# Epoch 113/300
# -------------
# （train）
# -------------
# epoch 113 || Epoch_D_Loss:0.1771 ||Epoch_G_Loss:0.0222
# timer:  1.1502 sec.
# -------------
# Epoch 114/300
# -------------
# （train）
# -------------
# epoch 114 || Epoch_D_Loss:0.1869 ||Epoch_G_Loss:0.0320
# timer:  1.1378 sec.
# -------------
# Epoch 115/300
# -------------
# （train）
# -------------
# epoch 115 || Epoch_D_Loss:0.1708 ||Epoch_G_Loss:0.0435
# timer:  1.1088 sec.
# -------------
# Epoch 116/300
# -------------
# （train）
# -------------
# epoch 116 || Epoch_D_Loss:0.1738 ||Epoch_G_Loss:0.0237
# timer:  1.1033 sec.
# -------------
# Epoch 117/300
# -------------
# （train）
# -------------
# epoch 117 || Epoch_D_Loss:0.1862 ||Epoch_G_Loss:0.0276
# timer:  1.0760 sec.
# -------------
# Epoch 118/300
# -------------
# （train）
# -------------
# epoch 118 || Epoch_D_Loss:0.1695 ||Epoch_G_Loss:0.0401
# timer:  1.0495 sec.
# -------------
# Epoch 119/300
# -------------
# （train）
# -------------
# epoch 119 || Epoch_D_Loss:0.1814 ||Epoch_G_Loss:0.0147
# timer:  1.0546 sec.
# -------------
# Epoch 120/300
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.1821 ||Epoch_G_Loss:0.0182
# timer:  1.0369 sec.
# -------------
# Epoch 121/300
# -------------
# （train）
# -------------
# epoch 121 || Epoch_D_Loss:0.1822 ||Epoch_G_Loss:0.0306
# timer:  1.0471 sec.
# -------------
# Epoch 122/300
# -------------
# （train）
# -------------
# epoch 122 || Epoch_D_Loss:0.1635 ||Epoch_G_Loss:0.0478
# timer:  1.0476 sec.
# -------------
# Epoch 123/300
# -------------
# （train）
# -------------
# epoch 123 || Epoch_D_Loss:0.1796 ||Epoch_G_Loss:0.0421
# timer:  1.0902 sec.
# -------------
# Epoch 124/300
# -------------
# （train）
# -------------
# epoch 124 || Epoch_D_Loss:0.1725 ||Epoch_G_Loss:0.0261
# timer:  1.0410 sec.
# -------------
# Epoch 125/300
# -------------
# （train）
# -------------
# epoch 125 || Epoch_D_Loss:0.1727 ||Epoch_G_Loss:0.0465
# timer:  1.0499 sec.
# -------------
# Epoch 126/300
# -------------
# （train）
# -------------
# epoch 126 || Epoch_D_Loss:0.1620 ||Epoch_G_Loss:0.0331
# timer:  1.0411 sec.
# -------------
# Epoch 127/300
# -------------
# （train）
# -------------
# epoch 127 || Epoch_D_Loss:0.1680 ||Epoch_G_Loss:0.0209
# timer:  1.0622 sec.
# -------------
# Epoch 128/300
# -------------
# （train）
# -------------
# epoch 128 || Epoch_D_Loss:0.1667 ||Epoch_G_Loss:0.0399
# timer:  1.0989 sec.
# -------------
# Epoch 129/300
# -------------
# （train）
# -------------
# epoch 129 || Epoch_D_Loss:0.1753 ||Epoch_G_Loss:0.0392
# timer:  1.0417 sec.
# -------------
# Epoch 130/300
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.1691 ||Epoch_G_Loss:0.0165
# timer:  1.0373 sec.
# -------------
# Epoch 131/300
# -------------
# （train）
# -------------
# epoch 131 || Epoch_D_Loss:0.1703 ||Epoch_G_Loss:0.0341
# timer:  1.0461 sec.
# -------------
# Epoch 132/300
# -------------
# （train）
# -------------
# epoch 132 || Epoch_D_Loss:0.1651 ||Epoch_G_Loss:0.0302
# timer:  1.0430 sec.
# -------------
# Epoch 133/300
# -------------
# （train）
# -------------
# epoch 133 || Epoch_D_Loss:0.1728 ||Epoch_G_Loss:0.0260
# timer:  1.0451 sec.
# -------------
# Epoch 134/300
# -------------
# （train）
# -------------
# epoch 134 || Epoch_D_Loss:0.1461 ||Epoch_G_Loss:0.0798
# timer:  1.0457 sec.
# -------------
# Epoch 135/300
# -------------
# （train）
# -------------
# epoch 135 || Epoch_D_Loss:0.1752 ||Epoch_G_Loss:0.0294
# timer:  1.0447 sec.
# -------------
# Epoch 136/300
# -------------
# （train）
# -------------
# epoch 136 || Epoch_D_Loss:0.1682 ||Epoch_G_Loss:0.0408
# timer:  1.0475 sec.
# -------------
# Epoch 137/300
# -------------
# （train）
# -------------
# epoch 137 || Epoch_D_Loss:0.1644 ||Epoch_G_Loss:0.0256
# timer:  1.0447 sec.
# -------------
# Epoch 138/300
# -------------
# （train）
# -------------
# epoch 138 || Epoch_D_Loss:0.1645 ||Epoch_G_Loss:0.0506
# timer:  1.0385 sec.
# -------------
# Epoch 139/300
# -------------
# （train）
# -------------
# epoch 139 || Epoch_D_Loss:0.1765 ||Epoch_G_Loss:0.0444
# timer:  1.0456 sec.
# -------------
# Epoch 140/300
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.1698 ||Epoch_G_Loss:0.0466
# timer:  1.0491 sec.
# -------------
# Epoch 141/300
# -------------
# （train）
# -------------
# epoch 141 || Epoch_D_Loss:0.1680 ||Epoch_G_Loss:0.0416
# timer:  1.0460 sec.
# -------------
# Epoch 142/300
# -------------
# （train）
# -------------
# epoch 142 || Epoch_D_Loss:0.1645 ||Epoch_G_Loss:0.0473
# timer:  1.0461 sec.
# -------------
# Epoch 143/300
# -------------
# （train）
# -------------
# epoch 143 || Epoch_D_Loss:0.1629 ||Epoch_G_Loss:0.0392
# timer:  1.0421 sec.
# -------------
# Epoch 144/300
# -------------
# （train）
# -------------
# epoch 144 || Epoch_D_Loss:0.1632 ||Epoch_G_Loss:0.0465
# timer:  1.0523 sec.
# -------------
# Epoch 145/300
# -------------
# （train）
# -------------
# epoch 145 || Epoch_D_Loss:0.1573 ||Epoch_G_Loss:0.0379
# timer:  1.0340 sec.
# -------------
# Epoch 146/300
# -------------
# （train）
# -------------
# epoch 146 || Epoch_D_Loss:0.1485 ||Epoch_G_Loss:0.0451
# timer:  1.0507 sec.
# -------------
# Epoch 147/300
# -------------
# （train）
# -------------
# epoch 147 || Epoch_D_Loss:0.1734 ||Epoch_G_Loss:0.0345
# timer:  1.0367 sec.
# -------------
# Epoch 148/300
# -------------
# （train）
# -------------
# epoch 148 || Epoch_D_Loss:0.1550 ||Epoch_G_Loss:0.0368
# timer:  1.0430 sec.
# -------------
# Epoch 149/300
# -------------
# （train）
# -------------
# epoch 149 || Epoch_D_Loss:0.1568 ||Epoch_G_Loss:0.0564
# timer:  1.0496 sec.
# -------------
# Epoch 150/300
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.1656 ||Epoch_G_Loss:0.0262
# timer:  1.0500 sec.
# -------------
# Epoch 151/300
# -------------
# （train）
# -------------
# epoch 151 || Epoch_D_Loss:0.1720 ||Epoch_G_Loss:0.0441
# timer:  1.0355 sec.
# -------------
# Epoch 152/300
# -------------
# （train）
# -------------
# epoch 152 || Epoch_D_Loss:0.1568 ||Epoch_G_Loss:0.0483
# timer:  1.0555 sec.
# -------------
# Epoch 153/300
# -------------
# （train）
# -------------
# epoch 153 || Epoch_D_Loss:0.1605 ||Epoch_G_Loss:0.0513
# timer:  1.0452 sec.
# -------------
# Epoch 154/300
# -------------
# （train）
# -------------
# epoch 154 || Epoch_D_Loss:0.1581 ||Epoch_G_Loss:0.0409
# timer:  1.0488 sec.
# -------------
# Epoch 155/300
# -------------
# （train）
# -------------
# epoch 155 || Epoch_D_Loss:0.1498 ||Epoch_G_Loss:0.0594
# timer:  1.0440 sec.
# -------------
# Epoch 156/300
# -------------
# （train）
# -------------
# epoch 156 || Epoch_D_Loss:0.1504 ||Epoch_G_Loss:0.0755
# timer:  1.0486 sec.
# -------------
# Epoch 157/300
# -------------
# （train）
# -------------
# epoch 157 || Epoch_D_Loss:0.1686 ||Epoch_G_Loss:0.0305
# timer:  1.0513 sec.
# -------------
# Epoch 158/300
# -------------
# （train）
# -------------
# epoch 158 || Epoch_D_Loss:0.1506 ||Epoch_G_Loss:0.0426
# timer:  1.0520 sec.
# -------------
# Epoch 159/300
# -------------
# （train）
# -------------
# epoch 159 || Epoch_D_Loss:0.1547 ||Epoch_G_Loss:0.0414
# timer:  1.0416 sec.
# -------------
# Epoch 160/300
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.1634 ||Epoch_G_Loss:0.0643
# timer:  1.0402 sec.
# -------------
# Epoch 161/300
# -------------
# （train）
# -------------
# epoch 161 || Epoch_D_Loss:0.1617 ||Epoch_G_Loss:0.0509
# timer:  1.0465 sec.
# -------------
# Epoch 162/300
# -------------
# （train）
# -------------
# epoch 162 || Epoch_D_Loss:0.1460 ||Epoch_G_Loss:0.0593
# timer:  1.0539 sec.
# -------------
# Epoch 163/300
# -------------
# （train）
# -------------
# epoch 163 || Epoch_D_Loss:0.1490 ||Epoch_G_Loss:0.0578
# timer:  1.0404 sec.
# -------------
# Epoch 164/300
# -------------
# （train）
# -------------
# epoch 164 || Epoch_D_Loss:0.1605 ||Epoch_G_Loss:0.0233
# timer:  1.0456 sec.
# -------------
# Epoch 165/300
# -------------
# （train）
# -------------
# epoch 165 || Epoch_D_Loss:0.1465 ||Epoch_G_Loss:0.0497
# timer:  1.0470 sec.
# -------------
# Epoch 166/300
# -------------
# （train）
# -------------
# epoch 166 || Epoch_D_Loss:0.1480 ||Epoch_G_Loss:0.0484
# timer:  1.0552 sec.
# -------------
# Epoch 167/300
# -------------
# （train）
# -------------
# epoch 167 || Epoch_D_Loss:0.1535 ||Epoch_G_Loss:0.0670
# timer:  1.0349 sec.
# -------------
# Epoch 168/300
# -------------
# （train）
# -------------
# epoch 168 || Epoch_D_Loss:0.1546 ||Epoch_G_Loss:0.0438
# timer:  1.0637 sec.
# -------------
# Epoch 169/300
# -------------
# （train）
# -------------
# epoch 169 || Epoch_D_Loss:0.1399 ||Epoch_G_Loss:0.0615
# timer:  1.0446 sec.
# -------------
# Epoch 170/300
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.1524 ||Epoch_G_Loss:0.0673
# timer:  1.0495 sec.
# -------------
# Epoch 171/300
# -------------
# （train）
# -------------
# epoch 171 || Epoch_D_Loss:0.1388 ||Epoch_G_Loss:0.0710
# timer:  1.0522 sec.
# -------------
# Epoch 172/300
# -------------
# （train）
# -------------
# epoch 172 || Epoch_D_Loss:0.1582 ||Epoch_G_Loss:0.0388
# timer:  1.0402 sec.
# -------------
# Epoch 173/300
# -------------
# （train）
# -------------
# epoch 173 || Epoch_D_Loss:0.1361 ||Epoch_G_Loss:0.0579
# timer:  1.0512 sec.
# -------------
# Epoch 174/300
# -------------
# （train）
# -------------
# epoch 174 || Epoch_D_Loss:0.1423 ||Epoch_G_Loss:0.0626
# timer:  1.0403 sec.
# -------------
# Epoch 175/300
# -------------
# （train）
# -------------
# epoch 175 || Epoch_D_Loss:0.1462 ||Epoch_G_Loss:0.0715
# timer:  1.0534 sec.
# -------------
# Epoch 176/300
# -------------
# （train）
# -------------
# epoch 176 || Epoch_D_Loss:0.1432 ||Epoch_G_Loss:0.0459
# timer:  1.0670 sec.
# -------------
# Epoch 177/300
# -------------
# （train）
# -------------
# epoch 177 || Epoch_D_Loss:0.1388 ||Epoch_G_Loss:0.0613
# timer:  1.0554 sec.
# -------------
# Epoch 178/300
# -------------
# （train）
# -------------
# epoch 178 || Epoch_D_Loss:0.1328 ||Epoch_G_Loss:0.0526
# timer:  1.0496 sec.
# -------------
# Epoch 179/300
# -------------
# （train）
# -------------
# epoch 179 || Epoch_D_Loss:0.1361 ||Epoch_G_Loss:0.0645
# timer:  1.0433 sec.
# -------------
# Epoch 180/300
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.1427 ||Epoch_G_Loss:0.0733
# timer:  1.0416 sec.
# -------------
# Epoch 181/300
# -------------
# （train）
# -------------
# epoch 181 || Epoch_D_Loss:0.1405 ||Epoch_G_Loss:0.0720
# timer:  1.0649 sec.
# -------------
# Epoch 182/300
# -------------
# （train）
# -------------
# epoch 182 || Epoch_D_Loss:0.1344 ||Epoch_G_Loss:0.0622
# timer:  1.0496 sec.
# -------------
# Epoch 183/300
# -------------
# （train）
# -------------
# epoch 183 || Epoch_D_Loss:0.1337 ||Epoch_G_Loss:0.0662
# timer:  1.0516 sec.
# -------------
# Epoch 184/300
# -------------
# （train）
# -------------
# epoch 184 || Epoch_D_Loss:0.1346 ||Epoch_G_Loss:0.0545
# timer:  1.0581 sec.
# -------------
# Epoch 185/300
# -------------
# （train）
# -------------
# epoch 185 || Epoch_D_Loss:0.1363 ||Epoch_G_Loss:0.0781
# timer:  1.0399 sec.
# -------------
# Epoch 186/300
# -------------
# （train）
# -------------
# epoch 186 || Epoch_D_Loss:0.1291 ||Epoch_G_Loss:0.0853
# timer:  1.0549 sec.
# -------------
# Epoch 187/300
# -------------
# （train）
# -------------
# epoch 187 || Epoch_D_Loss:0.1472 ||Epoch_G_Loss:0.0505
# timer:  1.0516 sec.
# -------------
# Epoch 188/300
# -------------
# （train）
# -------------
# epoch 188 || Epoch_D_Loss:0.1246 ||Epoch_G_Loss:0.0581
# timer:  1.0519 sec.
# -------------
# Epoch 189/300
# -------------
# （train）
# -------------
# epoch 189 || Epoch_D_Loss:0.1299 ||Epoch_G_Loss:0.0716
# timer:  1.0615 sec.
# -------------
# Epoch 190/300
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.1354 ||Epoch_G_Loss:0.0810
# timer:  1.0527 sec.
# -------------
# Epoch 191/300
# -------------
# （train）
# -------------
# epoch 191 || Epoch_D_Loss:0.1284 ||Epoch_G_Loss:0.0761
# timer:  1.0457 sec.
# -------------
# Epoch 192/300
# -------------
# （train）
# -------------
# epoch 192 || Epoch_D_Loss:0.1303 ||Epoch_G_Loss:0.0583
# timer:  1.0578 sec.
# -------------
# Epoch 193/300
# -------------
# （train）
# -------------
# epoch 193 || Epoch_D_Loss:0.1277 ||Epoch_G_Loss:0.0875
# timer:  1.0402 sec.
# -------------
# Epoch 194/300
# -------------
# （train）
# -------------
# epoch 194 || Epoch_D_Loss:0.1272 ||Epoch_G_Loss:0.0612
# timer:  1.0610 sec.
# -------------
# Epoch 195/300
# -------------
# （train）
# -------------
# epoch 195 || Epoch_D_Loss:0.1264 ||Epoch_G_Loss:0.0741
# timer:  1.0544 sec.
# -------------
# Epoch 196/300
# -------------
# （train）
# -------------
# epoch 196 || Epoch_D_Loss:0.1261 ||Epoch_G_Loss:0.0660
# timer:  1.0626 sec.
# -------------
# Epoch 197/300
# -------------
# （train）
# -------------
# epoch 197 || Epoch_D_Loss:0.1258 ||Epoch_G_Loss:0.0716
# timer:  1.0641 sec.
# -------------
# Epoch 198/300
# -------------
# （train）
# -------------
# epoch 198 || Epoch_D_Loss:0.1286 ||Epoch_G_Loss:0.0726
# timer:  1.0451 sec.
# -------------
# Epoch 199/300
# -------------
# （train）
# -------------
# epoch 199 || Epoch_D_Loss:0.1262 ||Epoch_G_Loss:0.0794
# timer:  1.0516 sec.
# -------------
# Epoch 200/300
# -------------
# （train）
# -------------
# epoch 200 || Epoch_D_Loss:0.1135 ||Epoch_G_Loss:0.0886
# timer:  1.0629 sec.
# -------------
# Epoch 201/300
# -------------
# （train）
# -------------
# epoch 201 || Epoch_D_Loss:0.1269 ||Epoch_G_Loss:0.0690
# timer:  1.0634 sec.
# -------------
# Epoch 202/300
# -------------
# （train）
# -------------
# epoch 202 || Epoch_D_Loss:0.1310 ||Epoch_G_Loss:0.0831
# timer:  1.0583 sec.
# -------------
# Epoch 203/300
# -------------
# （train）
# -------------
# epoch 203 || Epoch_D_Loss:0.1209 ||Epoch_G_Loss:0.0757
# timer:  1.0477 sec.
# -------------
# Epoch 204/300
# -------------
# （train）
# -------------
# epoch 204 || Epoch_D_Loss:0.1138 ||Epoch_G_Loss:0.0913
# timer:  1.0588 sec.
# -------------
# Epoch 205/300
# -------------
# （train）
# -------------
# epoch 205 || Epoch_D_Loss:0.1154 ||Epoch_G_Loss:0.0648
# timer:  1.0466 sec.
# -------------
# Epoch 206/300
# -------------
# （train）
# -------------
# epoch 206 || Epoch_D_Loss:0.1141 ||Epoch_G_Loss:0.0938
# timer:  1.0585 sec.
# -------------
# Epoch 207/300
# -------------
# （train）
# -------------
# epoch 207 || Epoch_D_Loss:0.1108 ||Epoch_G_Loss:0.0904
# timer:  1.0435 sec.
# -------------
# Epoch 208/300
# -------------
# （train）
# -------------
# epoch 208 || Epoch_D_Loss:0.1158 ||Epoch_G_Loss:0.0768
# timer:  1.0579 sec.
# -------------
# Epoch 209/300
# -------------
# （train）
# -------------
# epoch 209 || Epoch_D_Loss:0.1211 ||Epoch_G_Loss:0.0844
# timer:  1.0559 sec.
# -------------
# Epoch 210/300
# -------------
# （train）
# -------------
# epoch 210 || Epoch_D_Loss:0.1078 ||Epoch_G_Loss:0.0970
# timer:  1.0562 sec.
# -------------
# Epoch 211/300
# -------------
# （train）
# -------------
# epoch 211 || Epoch_D_Loss:0.1128 ||Epoch_G_Loss:0.0847
# timer:  1.0474 sec.
# -------------
# Epoch 212/300
# -------------
# （train）
# -------------
# epoch 212 || Epoch_D_Loss:0.1156 ||Epoch_G_Loss:0.0961
# timer:  1.0464 sec.
# -------------
# Epoch 213/300
# -------------
# （train）
# -------------
# epoch 213 || Epoch_D_Loss:0.1109 ||Epoch_G_Loss:0.0773
# timer:  1.0637 sec.
# -------------
# Epoch 214/300
# -------------
# （train）
# -------------
# epoch 214 || Epoch_D_Loss:0.1110 ||Epoch_G_Loss:0.1026
# timer:  1.0410 sec.
# -------------
# Epoch 215/300
# -------------
# （train）
# -------------
# epoch 215 || Epoch_D_Loss:0.1121 ||Epoch_G_Loss:0.0853
# timer:  1.0518 sec.
# -------------
# Epoch 216/300
# -------------
# （train）
# -------------
# epoch 216 || Epoch_D_Loss:0.1289 ||Epoch_G_Loss:0.0893
# timer:  1.0504 sec.
# -------------
# Epoch 217/300
# -------------
# （train）
# -------------
# epoch 217 || Epoch_D_Loss:0.0997 ||Epoch_G_Loss:0.1005
# timer:  1.0536 sec.
# -------------
# Epoch 218/300
# -------------
# （train）
# -------------
# epoch 218 || Epoch_D_Loss:0.1079 ||Epoch_G_Loss:0.0915
# timer:  1.0497 sec.
# -------------
# Epoch 219/300
# -------------
# （train）
# -------------
# epoch 219 || Epoch_D_Loss:0.1057 ||Epoch_G_Loss:0.1048
# timer:  1.0571 sec.
# -------------
# Epoch 220/300
# -------------
# （train）
# -------------
# epoch 220 || Epoch_D_Loss:0.1041 ||Epoch_G_Loss:0.0854
# timer:  1.0429 sec.
# -------------
# Epoch 221/300
# -------------
# （train）
# -------------
# epoch 221 || Epoch_D_Loss:0.1072 ||Epoch_G_Loss:0.1157
# timer:  1.0560 sec.
# -------------
# Epoch 222/300
# -------------
# （train）
# -------------
# epoch 222 || Epoch_D_Loss:0.1086 ||Epoch_G_Loss:0.0884
# timer:  1.0638 sec.
# -------------
# Epoch 223/300
# -------------
# （train）
# -------------
# epoch 223 || Epoch_D_Loss:0.1121 ||Epoch_G_Loss:0.1088
# timer:  1.0511 sec.
# -------------
# Epoch 224/300
# -------------
# （train）
# -------------
# epoch 224 || Epoch_D_Loss:0.0976 ||Epoch_G_Loss:0.0917
# timer:  1.0700 sec.
# -------------
# Epoch 225/300
# -------------
# （train）
# -------------
# epoch 225 || Epoch_D_Loss:0.1037 ||Epoch_G_Loss:0.1161
# timer:  1.0614 sec.
# -------------
# Epoch 226/300
# -------------
# （train）
# -------------
# epoch 226 || Epoch_D_Loss:0.0901 ||Epoch_G_Loss:0.1002
# timer:  0.9652 sec.
# -------------
# Epoch 227/300
# -------------
# （train）
# -------------
# epoch 227 || Epoch_D_Loss:0.0975 ||Epoch_G_Loss:0.1297
# timer:  0.9626 sec.
# -------------
# Epoch 228/300
# -------------
# （train）
# -------------
# epoch 228 || Epoch_D_Loss:0.0974 ||Epoch_G_Loss:0.1145
# timer:  0.9908 sec.
# -------------
# Epoch 229/300
# -------------
# （train）
# -------------
# epoch 229 || Epoch_D_Loss:0.0942 ||Epoch_G_Loss:0.1048
# timer:  0.9758 sec.
# -------------
# Epoch 230/300
# -------------
# （train）
# -------------
# epoch 230 || Epoch_D_Loss:0.0997 ||Epoch_G_Loss:0.0968
# timer:  0.9759 sec.
# -------------
# Epoch 231/300
# -------------
# （train）
# -------------
# epoch 231 || Epoch_D_Loss:0.0851 ||Epoch_G_Loss:0.1166
# timer:  0.9625 sec.
# -------------
# Epoch 232/300
# -------------
# （train）
# -------------
# epoch 232 || Epoch_D_Loss:0.0952 ||Epoch_G_Loss:0.1092
# timer:  0.9699 sec.
# -------------
# Epoch 233/300
# -------------
# （train）
# -------------
# epoch 233 || Epoch_D_Loss:0.0987 ||Epoch_G_Loss:0.1192
# timer:  0.9692 sec.
# -------------
# Epoch 234/300
# -------------
# （train）
# -------------
# epoch 234 || Epoch_D_Loss:0.0911 ||Epoch_G_Loss:0.1227
# timer:  0.9745 sec.
# -------------
# Epoch 235/300
# -------------
# （train）
# -------------
# epoch 235 || Epoch_D_Loss:0.0819 ||Epoch_G_Loss:0.1240
# timer:  0.9654 sec.
# -------------
# Epoch 236/300
# -------------
# （train）
# -------------
# epoch 236 || Epoch_D_Loss:0.0922 ||Epoch_G_Loss:0.1234
# timer:  0.9708 sec.
# -------------
# Epoch 237/300
# -------------
# （train）
# -------------
# epoch 237 || Epoch_D_Loss:0.0884 ||Epoch_G_Loss:0.1238
# timer:  0.9694 sec.
# -------------
# Epoch 238/300
# -------------
# （train）
# -------------
# epoch 238 || Epoch_D_Loss:0.0892 ||Epoch_G_Loss:0.1374
# timer:  0.9734 sec.
# -------------
# Epoch 239/300
# -------------
# （train）
# -------------
# epoch 239 || Epoch_D_Loss:0.0917 ||Epoch_G_Loss:0.1123
# timer:  0.9764 sec.
# -------------
# Epoch 240/300
# -------------
# （train）
# -------------
# epoch 240 || Epoch_D_Loss:0.0914 ||Epoch_G_Loss:0.1305
# timer:  0.9704 sec.
# -------------
# Epoch 241/300
# -------------
# （train）
# -------------
# epoch 241 || Epoch_D_Loss:0.0886 ||Epoch_G_Loss:0.1118
# timer:  0.9694 sec.
# -------------
# Epoch 242/300
# -------------
# （train）
# -------------
# epoch 242 || Epoch_D_Loss:0.0832 ||Epoch_G_Loss:0.1352
# timer:  0.9764 sec.
# -------------
# Epoch 243/300
# -------------
# （train）
# -------------
# epoch 243 || Epoch_D_Loss:0.0892 ||Epoch_G_Loss:0.1227
# timer:  0.9664 sec.
# -------------
# Epoch 244/300
# -------------
# （train）
# -------------
# epoch 244 || Epoch_D_Loss:0.0799 ||Epoch_G_Loss:0.1382
# timer:  0.9674 sec.
# -------------
# Epoch 245/300
# -------------
# （train）
# -------------
# epoch 245 || Epoch_D_Loss:0.0876 ||Epoch_G_Loss:0.1046
# timer:  0.9684 sec.
# -------------
# Epoch 246/300
# -------------
# （train）
# -------------
# epoch 246 || Epoch_D_Loss:0.0867 ||Epoch_G_Loss:0.1347
# timer:  0.9724 sec.
# -------------
# Epoch 247/300
# -------------
# （train）
# -------------
# epoch 247 || Epoch_D_Loss:0.0530 ||Epoch_G_Loss:0.1291
# timer:  0.9674 sec.
# -------------
# Epoch 248/300
# -------------
# （train）
# -------------
# epoch 248 || Epoch_D_Loss:0.1042 ||Epoch_G_Loss:0.1279
# timer:  0.9654 sec.
# -------------
# Epoch 249/300
# -------------
# （train）
# -------------
# epoch 249 || Epoch_D_Loss:0.0836 ||Epoch_G_Loss:0.1275
# timer:  0.9754 sec.
# -------------
# Epoch 250/300
# -------------
# （train）
# -------------
# epoch 250 || Epoch_D_Loss:0.0747 ||Epoch_G_Loss:0.1540
# timer:  0.9724 sec.
# -------------
# Epoch 251/300
# -------------
# （train）
# -------------
# epoch 251 || Epoch_D_Loss:0.0681 ||Epoch_G_Loss:0.1424
# timer:  0.9594 sec.
# -------------
# Epoch 252/300
# -------------
# （train）
# -------------
# epoch 252 || Epoch_D_Loss:0.0848 ||Epoch_G_Loss:0.1265
# timer:  0.9614 sec.
# -------------
# Epoch 253/300
# -------------
# （train）
# -------------
# epoch 253 || Epoch_D_Loss:0.0856 ||Epoch_G_Loss:0.1350
# timer:  0.9694 sec.
# -------------
# Epoch 254/300
# -------------
# （train）
# -------------
# epoch 254 || Epoch_D_Loss:0.0493 ||Epoch_G_Loss:0.1628
# timer:  0.9714 sec.
# -------------
# Epoch 255/300
# -------------
# （train）
# -------------
# epoch 255 || Epoch_D_Loss:0.0894 ||Epoch_G_Loss:0.1323
# timer:  0.9734 sec.
# -------------
# Epoch 256/300
# -------------
# （train）
# -------------
# epoch 256 || Epoch_D_Loss:0.0798 ||Epoch_G_Loss:0.1665
# timer:  0.9724 sec.
# -------------
# Epoch 257/300
# -------------
# （train）
# -------------
# epoch 257 || Epoch_D_Loss:0.0810 ||Epoch_G_Loss:0.1269
# timer:  0.9714 sec.
# -------------
# Epoch 258/300
# -------------
# （train）
# -------------
# epoch 258 || Epoch_D_Loss:0.0649 ||Epoch_G_Loss:0.1590
# timer:  0.9764 sec.
# -------------
# Epoch 259/300
# -------------
# （train）
# -------------
# epoch 259 || Epoch_D_Loss:0.0810 ||Epoch_G_Loss:0.1465
# timer:  0.9614 sec.
# -------------
# Epoch 260/300
# -------------
# （train）
# -------------
# epoch 260 || Epoch_D_Loss:0.0715 ||Epoch_G_Loss:0.1484
# timer:  0.9704 sec.
# -------------
# Epoch 261/300
# -------------
# （train）
# -------------
# epoch 261 || Epoch_D_Loss:0.0685 ||Epoch_G_Loss:0.1436
# timer:  0.9734 sec.
# -------------
# Epoch 262/300
# -------------
# （train）
# -------------
# epoch 262 || Epoch_D_Loss:0.0742 ||Epoch_G_Loss:0.1654
# timer:  0.9674 sec.
# -------------
# Epoch 263/300
# -------------
# （train）
# -------------
# epoch 263 || Epoch_D_Loss:0.0587 ||Epoch_G_Loss:0.1325
# timer:  0.9684 sec.
# -------------
# Epoch 264/300
# -------------
# （train）
# -------------
# epoch 264 || Epoch_D_Loss:0.0774 ||Epoch_G_Loss:0.1611
# timer:  0.9724 sec.
# -------------
# Epoch 265/300
# -------------
# （train）
# -------------
# epoch 265 || Epoch_D_Loss:0.0696 ||Epoch_G_Loss:0.1479
# timer:  0.9634 sec.
# -------------
# Epoch 266/300
# -------------
# （train）
# -------------
# epoch 266 || Epoch_D_Loss:0.0680 ||Epoch_G_Loss:0.1638
# timer:  0.9684 sec.
# -------------
# Epoch 267/300
# -------------
# （train）
# -------------
# epoch 267 || Epoch_D_Loss:0.0821 ||Epoch_G_Loss:0.1722
# timer:  0.9654 sec.
# -------------
# Epoch 268/300
# -------------
# （train）
# -------------
# epoch 268 || Epoch_D_Loss:0.0549 ||Epoch_G_Loss:0.1816
# timer:  0.9684 sec.
# -------------
# Epoch 269/300
# -------------
# （train）
# -------------
# epoch 269 || Epoch_D_Loss:0.0722 ||Epoch_G_Loss:0.1540
# timer:  0.9724 sec.
# -------------
# Epoch 270/300
# -------------
# （train）
# -------------
# epoch 270 || Epoch_D_Loss:0.0751 ||Epoch_G_Loss:0.1749
# timer:  0.9754 sec.
# -------------
# Epoch 271/300
# -------------
# （train）
# -------------
# epoch 271 || Epoch_D_Loss:0.0564 ||Epoch_G_Loss:0.1373
# timer:  0.9714 sec.
# -------------
# Epoch 272/300
# -------------
# （train）
# -------------
# epoch 272 || Epoch_D_Loss:0.0670 ||Epoch_G_Loss:0.1824
# timer:  0.9694 sec.
# -------------
# Epoch 273/300
# -------------
# （train）
# -------------
# epoch 273 || Epoch_D_Loss:0.0700 ||Epoch_G_Loss:0.1418
# timer:  0.9684 sec.
# -------------
# Epoch 274/300
# -------------
# （train）
# -------------
# epoch 274 || Epoch_D_Loss:0.0576 ||Epoch_G_Loss:0.1656
# timer:  0.9764 sec.
# -------------
# Epoch 275/300
# -------------
# （train）
# -------------
# epoch 275 || Epoch_D_Loss:0.0660 ||Epoch_G_Loss:0.1491
# timer:  0.9704 sec.
# -------------
# Epoch 276/300
# -------------
# （train）
# -------------
# epoch 276 || Epoch_D_Loss:0.0606 ||Epoch_G_Loss:0.1776
# timer:  0.9704 sec.
# -------------
# Epoch 277/300
# -------------
# （train）
# -------------
# epoch 277 || Epoch_D_Loss:0.0663 ||Epoch_G_Loss:0.1827
# timer:  0.9744 sec.
# -------------
# Epoch 278/300
# -------------
# （train）
# -------------
# epoch 278 || Epoch_D_Loss:0.0574 ||Epoch_G_Loss:0.1580
# timer:  0.9644 sec.
# -------------
# Epoch 279/300
# -------------
# （train）
# -------------
# epoch 279 || Epoch_D_Loss:0.0581 ||Epoch_G_Loss:0.1647
# timer:  0.9706 sec.
# -------------
# Epoch 280/300
# -------------
# （train）
# -------------
# epoch 280 || Epoch_D_Loss:0.0599 ||Epoch_G_Loss:0.1725
# timer:  0.9671 sec.
# -------------
# Epoch 281/300
# -------------
# （train）
# -------------
# epoch 281 || Epoch_D_Loss:0.0627 ||Epoch_G_Loss:0.1778
# timer:  0.9624 sec.
# -------------
# Epoch 282/300
# -------------
# （train）
# -------------
# epoch 282 || Epoch_D_Loss:0.0562 ||Epoch_G_Loss:0.1644
# timer:  0.9644 sec.
# -------------
# Epoch 283/300
# -------------
# （train）
# -------------
# epoch 283 || Epoch_D_Loss:0.0656 ||Epoch_G_Loss:0.1620
# timer:  0.9655 sec.
# -------------
# Epoch 284/300
# -------------
# （train）
# -------------
# epoch 284 || Epoch_D_Loss:0.0556 ||Epoch_G_Loss:0.1612
# timer:  0.9724 sec.
# -------------
# Epoch 285/300
# -------------
# （train）
# -------------
# epoch 285 || Epoch_D_Loss:0.0624 ||Epoch_G_Loss:0.1939
# timer:  0.9634 sec.
# -------------
# Epoch 286/300
# -------------
# （train）
# -------------
# epoch 286 || Epoch_D_Loss:0.0469 ||Epoch_G_Loss:0.1587
# timer:  0.9744 sec.
# -------------
# Epoch 287/300
# -------------
# （train）
# -------------
# epoch 287 || Epoch_D_Loss:0.0574 ||Epoch_G_Loss:0.1930
# timer:  0.9724 sec.
# -------------
# Epoch 288/300
# -------------
# （train）
# -------------
# epoch 288 || Epoch_D_Loss:0.0672 ||Epoch_G_Loss:0.1948
# timer:  0.9664 sec.
# -------------
# Epoch 289/300
# -------------
# （train）
# -------------
# epoch 289 || Epoch_D_Loss:0.0479 ||Epoch_G_Loss:0.1839
# timer:  0.9684 sec.
# -------------
# Epoch 290/300
# -------------
# （train）
# -------------
# epoch 290 || Epoch_D_Loss:0.0563 ||Epoch_G_Loss:0.1743
# timer:  0.9714 sec.
# -------------
# Epoch 291/300
# -------------
# （train）
# -------------
# epoch 291 || Epoch_D_Loss:0.0472 ||Epoch_G_Loss:0.1886
# timer:  0.9694 sec.
# -------------
# Epoch 292/300
# -------------
# （train）
# -------------
# epoch 292 || Epoch_D_Loss:0.0552 ||Epoch_G_Loss:0.1786
# timer:  0.9674 sec.
# -------------
# Epoch 293/300
# -------------
# （train）
# -------------
# epoch 293 || Epoch_D_Loss:0.0483 ||Epoch_G_Loss:0.1901
# timer:  0.9654 sec.
# -------------
# Epoch 294/300
# -------------
# （train）
# -------------
# epoch 294 || Epoch_D_Loss:0.0510 ||Epoch_G_Loss:0.1759
# timer:  0.9614 sec.
# -------------
# Epoch 295/300
# -------------
# （train）
# -------------
# epoch 295 || Epoch_D_Loss:0.0528 ||Epoch_G_Loss:0.1645
# timer:  0.9704 sec.
# -------------
# Epoch 296/300
# -------------
# （train）
# -------------
# epoch 296 || Epoch_D_Loss:0.0655 ||Epoch_G_Loss:0.1749
# timer:  0.9644 sec.
# -------------
# Epoch 297/300
# -------------
# （train）
# -------------
# epoch 297 || Epoch_D_Loss:0.0281 ||Epoch_G_Loss:0.1874
# timer:  0.9724 sec.
# -------------
# Epoch 298/300
# -------------
# （train）
# -------------
# epoch 298 || Epoch_D_Loss:0.0489 ||Epoch_G_Loss:0.1778
# timer:  0.9674 sec.
# -------------
# Epoch 299/300
# -------------
# （train）
# -------------
# epoch 299 || Epoch_D_Loss:0.0503 ||Epoch_G_Loss:0.2066
# timer:  0.9714 sec.

# %%
# 生成画像と訓練データを可視化する
# 本セルは、良い感じの画像が生成されるまで、何度か実行をし直しています

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)

# 画像生成
G_update.eval()
fake_images, am1, am2 = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %%
# Attentiom Mapを出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):

    # 上段に生成した画像データを
    plt.subplot(2, 5, i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

    # 下段にAttentin Map1の画像中央のピクセルのデータを
    plt.subplot(2, 5, 5+i+1)
    am = am1[i].view(16, 16, 16, 16)
    am = am[7][7]  # 中央に着目
    plt.imshow(am.cpu().detach().numpy(), 'Reds')
